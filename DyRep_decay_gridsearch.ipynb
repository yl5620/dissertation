# %%
import numpy as np
import datetime
import torch
import torch.utils
from datetime import timezone


class EventsDataset(torch.utils.data.Dataset):
    '''
    Base class for event datasets
    '''
    def __init__(self, TZ=None):
        self.TZ = TZ  # timezone.utc

        # Implement here these fields (see examples in actual datasets):
        # self.FIRST_DATE = datetime()
        # self.TEST_TIMESLOTS = []
        # self.N_nodes = 100
        # self.A_initial = np.random.randint(0, 2, size=(self.N_nodes, self.N_nodes))
        # self.A_last = np.random.randint(0, 2, size=(self.N_nodes, self.N_nodes))
        #
        # self.all_events = []
        # self.n_events = len(self.all_events)
        #
        # self.event_types = ['communication event']
        # self.event_types_num = {'association event': 0}
        # k = 1  # k >= 1 for communication events
        # for t in self.event_types:
        #     self.event_types_num[t] = k
        #     k += 1


    def get_Adjacency(self, multirelations=False):
        return None, None, None

    def __len__(self):
        return self.n_events

    def __getitem__(self, index):

        tpl = self.all_events[index]
        u, v, rel, time_cur = tpl

        # Compute time delta in seconds (t_p - \bar{t}_p_j) that will be fed to W_t
        time_delta_uv = np.zeros((2, 4))  # two nodes x 4 values

        # most recent previous time for all nodes
        time_bar = self.time_bar.copy()
        assert u != v, (tpl, rel)

        u = int(u)
        v = int(v)
        
        for c, j in enumerate([u, v]):
            t = datetime.datetime.fromtimestamp(self.time_bar[j][0], tz=self.TZ)
            if t.toordinal() >= self.FIRST_DATE.toordinal():  # assume no events before FIRST_DATE
                td = time_cur - t
                time_delta_uv[c] = np.array([td.days,  # total number of days, still can be a big number
                                             td.seconds // 3600,  # hours, max 24
                                             (td.seconds // 60) % 60,  # minutes, max 60
                                             td.seconds % 60],  # seconds, max 60
                                            np.float64)
                # assert time_delta_uv.min() >= 0, (index, tpl, time_delta_uv[c], node_global_time[j])
            else:
                raise ValueError('unexpected result', t, self.FIRST_DATE)
            self.time_bar[j] = time_cur.timestamp()  # last time stamp for nodes u and v

        k = self.event_types_num[rel]

        # sanity checks
        assert np.float64(time_cur.timestamp()) == time_cur.timestamp(), (
        np.float64(time_cur.timestamp()), time_cur.timestamp())
        time_cur = np.float64(time_cur.timestamp())
        time_bar = time_bar.astype(np.float64)
        time_cur = torch.from_numpy(np.array([time_cur])).double()
        assert time_bar.max() <= time_cur, (time_bar.max(), time_cur)
        return u, v, time_delta_uv, k, time_bar, time_cur

# %%
import numpy as np
import pandas as pd
import datetime


class SyntheticDataset(EventsDataset):

    def __init__(self, split, data_dir=None, link_feat=False):
        super(SyntheticDataset, self).__init__()

        self.rnd = np.random.RandomState(1111)

        graph_df = pd.read_csv(data_dir)
        graph_df = graph_df.sort_values('time')
        test_time = np.quantile(graph_df.time, 0.70)
        sources = graph_df.u.values
        destinations = graph_df.v.values
        event_type = graph_df.k.values

        # if not all_comms:
        #     visited = set()
        #     for idx, (source, des) in enumerate(zip(sources, destinations)):
        #         if (source,des) not in visited:
        #             event_type[idx]=0
        #             visited.add((source,des))

        timestamps = graph_df.time.values
        timestamps_date = np.array(list(map(lambda x: datetime.datetime.fromtimestamp(int(x), tz=None), timestamps)))

        train_mask = timestamps<=test_time
        test_mask = timestamps>test_time

        all_events = list(zip(sources, destinations, event_type, timestamps_date))

        if split == 'train':
            self.all_events = np.array(all_events)[train_mask].tolist()
        elif split == 'test':
            self.all_events = np.array(all_events)[test_mask].tolist()
        else:
            raise ValueError('invalid split', split)

        self.FIRST_DATE = datetime.datetime.fromtimestamp(0)
        self.END_DATE = timestamps_date[-1]
        self.TEST_TIMESLOTS = [datetime.datetime(1970, 1, 1, tzinfo=self.TZ)]

        self.N_nodes = max(sources.max(),destinations.max())+1

        self.n_events = len(self.all_events)

        self.event_types_num = {0: 0, 1:1}
        self.time_bar = np.full(self.N_nodes, self.FIRST_DATE.timestamp())

        self.assoc_types = [0]

        self.A_initial = np.zeros((self.N_nodes, self.N_nodes))

        # random_source = self.rnd.choice(np.unique(sources), size=500, replace=False)
        # random_des =self.rnd.choice(np.unique(destinations), size=500, replace=False)
        #
        # for i, j  in zip(random_source, random_des):
        #     self.A_initial[i,j] = 1
        #     self.A_initial[j,i] = 1

        print('\nA_initial', np.sum(self.A_initial))


    def get_Adjacency(self, multirelations=False):
        if multirelations:
            print('warning: only one relation type, so multirelations are ignored')
        return self.A_initial

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

class DyRep(nn.Module):
    def __init__(self,
                 node_embeddings,
                 A_initial=None,
                 N_surv_samples=5,
                 n_hidden=32,
                 N_hops=2,
                 decay_rate = 0,
                 sparse=False,
                 node_degree_global=None,
                 rnd=np.random.RandomState(111)):
        super(DyRep, self).__init__()
    
        # initialisations
        self.opt = True
        self.exp = True
        self.rnd = rnd
        self.n_hidden = n_hidden
        self.sparse = sparse
        self.N_surv_samples = N_surv_samples
        self.node_degree_global = node_degree_global
        self.N_nodes = A_initial.shape[0]
        if A_initial is not None and len(A_initial.shape) == 2:
            A_initial = A_initial[:, :, None]
        self.n_assoc_types = 1
        self.N_hops = N_hops
        self.decay_rate = decay_rate

        self.initialize(node_embeddings, A_initial)
        self.W_h = nn.Linear(in_features=n_hidden, out_features=n_hidden)
        self.W_struct = nn.Linear(n_hidden * self.n_assoc_types, n_hidden)
        self.W_rec = nn.Linear(n_hidden, n_hidden)
        self.W_t = nn.Linear(4, n_hidden)

        n_types = 2  # associative and communicative
        d1 = self.n_hidden + (0)
        d2 = self.n_hidden + (0)

        d1 += self.n_hidden
        d2 += self.n_hidden
        self.omega = nn.ModuleList([nn.Linear(d1, 1), nn.Linear(d2, 1)])

        self.psi = nn.Parameter(0.5 * torch.ones(n_types)) 

        self.init_weights()

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                # print('before Xavier', m.weight.data.shape, m.weight.data.min(), m.weight.data.max())
                nn.init.xavier_normal_(m.weight.data)

    def generate_S_from_A(self):
        if isinstance(self.A, np.ndarray):
            self.A = torch.tensor(self.A, dtype=torch.float32)  # Convert A to a tensor if it's a numpy array
        S = self.A.new_empty(self.N_nodes, self.N_nodes, self.n_assoc_types).fill_(0)
        for rel in range(self.n_assoc_types):
            D = torch.sum(self.A[:, :, rel], dim=1).float()
            for i, v in enumerate(torch.nonzero(D, as_tuple=False).squeeze()):
                u = torch.nonzero(self.A[v, :, rel].squeeze(), as_tuple=False).squeeze()
                S[v, u, rel] = 1. / D[v]
        self.S = S
        # Check that values in each row of S add up to 1
        for rel in range(self.n_assoc_types):
            S = self.S[:, :, rel]
            assert torch.sum(S[self.A[:, :, rel] == 0]) < 1e-5, torch.sum(S[self.A[:, :, rel] == 0])

    def initialize(self,node_embeddings, A_initial,keepS=False):
        print('initialize model''s node embeddings and adjacency matrices for %d nodes' % self.N_nodes)
        # Initial embeddings
        if node_embeddings is not None:
            z = np.pad(node_embeddings, ((0, 0), (0, self.n_hidden - node_embeddings.shape[1])), 'constant')
            z = torch.from_numpy(z).float()

        if A_initial is None:
            print('initial random prediction of A')
            A = torch.zeros(self.N_nodes, self.N_nodes, self.n_assoc_types + int(self.sparse))

            for i in range(self.N_nodes):
                for j in range(i + 1, self.N_nodes):
                    if self.sparse:
                        if self.n_assoc_types == 1:
                            pvals = [0.95, 0.05]
                        elif self.n_assoc_types == 2:
                            pvals = [0.9, 0.05, 0.05]
                        elif self.n_assoc_types == 3:
                            pvals = [0.91, 0.03, 0.03, 0.03]
                        elif self.n_assoc_types == 4:
                            pvals = [0.9, 0.025, 0.025, 0.025, 0.025]
                        else:
                            raise NotImplementedError(self.n_assoc_types)
                        ind = np.nonzero(np.random.multinomial(1, pvals))[0][0]
                    else:
                        ind = np.random.randint(0, self.n_assoc_types, size=1)
                    A[i, j, ind] = 1
                    A[j, i, ind] = 1
            assert torch.sum(torch.isnan(A)) == 0, (torch.sum(torch.isnan(A)), A)
            if self.sparse:
                A = A[:, :, 1:]

        else:
            print('A_initial', A_initial.shape)
            A = torch.from_numpy(A_initial).float()
            if len(A.shape) == 2:
                A = A.unsqueeze(2)

        # make these variables part of the model
        self.register_buffer('z', z)
        self.register_buffer('A', A)

        self.A = A  
        if not keepS:
            self.generate_S_from_A()

        self.Lambda_dict = torch.zeros(5000)
        self.time_keys = []

        self.t_p = 0  # global counter of iterations
    
    def check_S(self):
        for rel in range(self.n_assoc_types):
            rows = torch.nonzero(torch.sum(self.A[:, :, rel], dim=1).float())
            # check that the sum in all rows equal 1
            assert torch.all(torch.abs(torch.sum(self.S[:, :, rel], dim=1)[rows] - 1) < 1e-1), torch.abs(torch.sum(self.S[:, :, rel], dim=1)[rows] - 1)

    
    def g_fn(self,z_cat, k, edge_type=None, z2=None):
        if z2 is not None:
            z_cat = torch.cat((z_cat, z2), dim=1)
        else:
            raise NotImplementedError('')
        g = z_cat.new(len(z_cat), 1).fill_(0)
        idx = k <= 0
        if torch.sum(idx) > 0:
            if edge_type is not None:
                z_cat1 = torch.cat((z_cat[idx], edge_type[idx, :self.n_assoc_types]), dim=1)
            else:
                z_cat1 = z_cat[idx]
            g[idx] = self.omega[0](z_cat1)
        idx = k > 0
        if torch.sum(idx) > 0:
            if edge_type is not None:
                z_cat1 = torch.cat((z_cat[idx], edge_type[idx, self.n_assoc_types:]), dim=1)
            else:
                z_cat1 = z_cat[idx]
            g[idx] = self.omega[1](z_cat1)

        g = g.flatten()
        return g
    
    def intensity_rate_lambda(self,z_u, z_v, k):
        z_u = z_u.view(-1, self.n_hidden).contiguous()
        z_v = z_v.view(-1, self.n_hidden).contiguous()
        edge_type = None
        g = 0.5 * (self.g_fn(z_u, (k > 0).long(), edge_type=edge_type, z2=z_v) + self.g_fn(z_v, (k > 0).long(),edge_type=edge_type, z2=z_u))  # make it symmetric, because most events are symmetric
        psi = self.psi[(k > 0).long()]
        g_psi = torch.clamp(g / (psi + 1e-7), -75, 75)  # to prevent overflow
        Lambda = psi * (torch.log(1 + torch.exp(-g_psi)) + g_psi)
        return Lambda
    
    def update_node_embed(self,prev_embed, node1, node2, time_delta_uv):
        # z contains all node embeddings of previous time \bar{t}
        # S also corresponds to previous time stamp, because it's not updated yet based on this event

        node_embed = prev_embed

        node_degree = {} # we need degrees to update S
        z_new = prev_embed.clone()  # to allow in place changes while keeping gradients
        
        #precompute the N-hop neighbors
        A_float = self.A.squeeze(-1).float()
        A_power = torch.eye(A_float.shape[0])
        extended_neighbors = [A_power.clone()]
        for _ in range(self.N_hops):
            A_power = torch.mm(A_power, A_float)
            extended_neighbors.append((A_power>0).clone())
        h_u_struct = prev_embed.new_zeros((2, self.n_hidden, self.n_assoc_types))
        for c, (v, u, delta_t) in enumerate(zip([node1, node2], [node2, node1], time_delta_uv)):  # i is the other node involved in the event
            node_degree[u] = np.zeros(self.n_assoc_types)
            for rel in range(self.n_assoc_types):
                Neighb_u = torch.zeros(self.A.shape[1],dtype=torch.bool)
                for i in range(1,self.N_hops+1):
                    Neighb_u |=  extended_neighbors[i][u,:] >0
                
                N_neighb = torch.sum(Neighb_u).item()  # number of neighbors for node u
                node_degree[u][rel] = N_neighb
                if N_neighb > 0:  # node has no neighbors
                    h_prev_i = self.W_h(node_embed[Neighb_u]).view(N_neighb, self.n_hidden)
                    # attention over neighbors
                    if time_delta_uv.ndim == 2 and time_delta_uv.size(0) == 2:
                        time_delta_uv_expanded = time_delta_uv[0].unsqueeze(0).repeat(N_neighb, 1)
                    else:
                        time_delta_uv_expanded = time_delta_uv[Neighb_u]
                    decay_factor = torch.exp(-self.decay_rate * time_delta_uv_expanded)
                    S_expanded = self.S[u, Neighb_u, rel].unsqueeze(1)
                    attention_scores = decay_factor * torch.exp(time_delta_uv_expanded + S_expanded)
                    # # for debugging
                    # print("decay_factor shape:", decay_factor.shape)
                    # print("time_delta_uv_expanded shape:", time_delta_uv_expanded.shape)
                    # print("S matrix slice shape:", self.S[u, Neighb_u, rel].shape)
                    q_ui = attention_scores.mean(dim=1, keepdim=True)
                    q_ui_expanded = q_ui.expand(-1, self.n_hidden)
                    h_u_struct[c, :, rel] = torch.max(torch.sigmoid(q_ui_expanded * h_prev_i), dim=0)[0].view(1, self.n_hidden)
                    # q_ui = decay_factor * torch.exp(time_delta_uv_expanded + self.S[u, Neighb_u, rel].unsqueeze(1))
                    # q_ui = q_ui / (torch.sum(q_ui + 1e-7, dim=0, keepdim=True))
                    # h_u_struct[c, :, rel] = torch.max(torch.sigmoid(q_ui * h_prev_i), dim=0)[0].view(1, self.n_hidden)

        h1 = self.W_struct(h_u_struct.view(2, self.n_hidden * self.n_assoc_types))

        h2 = self.W_rec(node_embed[[node1, node2], :].view(2, -1))

        h3 = self.W_t(time_delta_uv.float()).view(2, self.n_hidden)

        z_new[[node1, node2], :] = torch.sigmoid(h1 + h2 + h3)
        return node_degree, z_new
    
    def update_S_A(self, u, v, k, node_degree, lambda_uv_t):
        if k <= 0 :  # Association event
            # do not update in case of latent graph
            self.A[u, v, np.abs(k)] = self.A[v, u, np.abs(k)] = 1  # 0 for CloseFriends, k = -1 for the second relation, so it's abs(k) matrix in self.A
        A = self.A
        indices = torch.arange(self.N_nodes)
        for rel in range(self.n_assoc_types):
            if k > 0 and A[u, v, rel] == 0:  # Communication event, no Association exists
                continue  # do not update S and A
            else:
                for j, i in zip([u, v], [v, u]):
                    # i is the "other node involved in the event"
                    try:
                        degree = node_degree[j]
                    except:
                        print(list(node_degree.keys()))
                        raise
                    y = self.S[j, :, rel]
                    # assert torch.sum(torch.isnan(y)) == 0, ('b', j, degree[rel], node_degree_global[rel][j.item()], y)
                    b = 0 if degree[rel] == 0 else 1. / (float(degree[rel]) + 1e-7)
                    if k > 0 and A[u, v, rel] > 0:  # Communication event, Association exists
                        y[i] = b + lambda_uv_t
                    elif k <= 0 and A[u, v, rel] > 0:  # Association event
                        if self.node_degree_global[rel][j] == 0:
                            b_prime = 0
                        else:
                            b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
                        x = b_prime - b
                        y[i] = b + lambda_uv_t
                        w = (y != 0) & (indices != int(i))
                        y[w] = y[w] - x
                    y /= (torch.sum(y) + 1e-7)  # normalize
                    self.S[j, :, rel] = y
        return 
    
    # conditional density calculation to predict the next event (the probability of the next event for each pair of nodes)
    def cond_density(self,time_bar,u, v):
        N = self.N_nodes
        if not self.time_keys:  # Checks if time_keys is empty
            print("Warning: time_keys is empty. No operations performed.")
            return torch.zeros((2, self.N_nodes)) 
        s = self.Lambda_dict.new_zeros((2, N))
        #normalize lambda values by dividing by the number of events
        Lambda_sum = torch.cumsum(self.Lambda_dict.flip(0), 0).flip(0)  / len(self.Lambda_dict)
        time_keys_min = self.time_keys[0]
        time_keys_max = self.time_keys[-1]

        indices = []
        l_indices = []
        t_bar_min = torch.min(time_bar[[u, v]]).item()
        if t_bar_min < time_keys_min:
            start_ind_min = 0
        elif t_bar_min > time_keys_max:
            # it means t_bar will always be larger, so there is no history for these nodes
            return s
        else:
            start_ind_min = self.time_keys.index(int(t_bar_min))

        # print("time_bar shape:", time_bar.shape)
        # print("Expanded and reshaped time_bar shape:", time_bar[[u, v]].view(1, 2).expand(N, -1).t().contiguous().view(2 * N, 1).shape)
        # print("Repeated time_bar shape:", time_bar.repeat(2, 1).shape)
        # Reshape expanded and reshaped time_bar
        expanded_time_bar = time_bar[[u, v]].view(1, 2).expand(N, -1).t().contiguous().view(2 * N, 1)
        # Adjust repeated time_bar to match the expanded shape
        adjusted_repeated_time_bar = time_bar.repeat(2, 1).view(2 * N, 1)
        # Now concatenate along dimension 1 (should work as both tensors are (168, 1))
        max_pairs = torch.max(torch.cat((expanded_time_bar, adjusted_repeated_time_bar), dim=1), dim=1)[0].view(2, N).long()
        # max_pairs = torch.max(torch.cat((time_bar[[u, v]].view(1, 2).expand(N, -1).t().contiguous().view(2 * N, 1),
        #                                     time_bar.repeat(2, 1)), dim=1), dim=1)[0].view(2, N).long().data.cpu().numpy()  # 2,N

        # compute cond density for all pairs of u and some i, then of v and some i
        c1, c2 = 0, 0
        for c, j in enumerate([u, v]):  # range(i + 1, N):
            for i in range(N):
                if i == j:
                    continue
                # most recent timestamp of either u or v
                t_bar = max_pairs[c, i]
                c2 += 1

                if t_bar < time_keys_min:
                    start_ind = 0  # it means t_bar is beyond the history we kept, so use maximum period saved
                elif t_bar > time_keys_max:
                    continue  # it means t_bar is current event, so there is no history for this pair of nodes
                else:
                    # t_bar is somewhere in between time_keys_min and time_keys_min
                    start_ind = self.time_keys.index(t_bar, start_ind_min)

                indices.append((c, i))
                l_indices.append(start_ind)

        indices = np.array(indices)
        l_indices = np.array(l_indices)
        s[indices[:, 0], indices[:, 1]] = Lambda_sum[l_indices]

        return s
    
    # forward pass
    def forward(self,data):
        # opt is batch_update
        data[2] = data[2].float()
        data[4] = data[4].double()
        data[5] = data[5].double()
        u, v, k = data[0], data[1], data[3]
        time_delta_uv = data[2]
        time_bar = data[4]
        time_cur = data[5]
        event_types = k
        # u, v, time_delta_uv, event_types, time_bar, time_cur = data
        B = len(u)
        assert len(event_types) == B, (len(event_types), B)
        N = self.N_nodes

        A_pred, Surv = None, None
        A_pred = self.A.new_zeros(B, N, N).fill_(0)
        Surv = self.A.new_zeros(B, N, N).fill_(0)

        if self.opt:
            embeddings1, embeddings2, node_degrees = [], [], []
            embeddings_non1, embeddings_non2 = [], []
        else:
            lambda_uv_t, lambda_uv_t_non_events = [], []

        assert torch.min(time_delta_uv) >= 0, ('events must be in chronological order', torch.min(time_delta_uv))

        time_mn = torch.from_numpy(np.array([0, 0, 0, 0])).float().view(1, 1, 4)
        time_sd = torch.from_numpy(np.array([50, 7, 15, 15])).float().view(1, 1, 4)
        time_delta_uv = (time_delta_uv - time_mn) / time_sd

        reg = []

        S_batch = []

        z_all = []

        u_all = u.data.cpu().numpy()
        v_all = v.data.cpu().numpy()


        for it, k in enumerate(event_types):
            # k = 0: association event (rare)
            # k = 1,2,3: communication event (frequent)

            u_it, v_it = u_all[it], v_all[it]
            z_prev = self.z if it == 0 else z_all[it - 1]

            # 1. Compute intensity rate lambda based on node embeddings at previous time step (Eq. 1)
            if self.opt:
                # store node embeddings, compute lambda and S,A later based on the entire batch
                embeddings1.append(z_prev[u_it])
                embeddings2.append(z_prev[v_it])
            else:
                # accumulate intensity rate of events for this batch based on new embeddings
                lambda_uv_t.append(self.intensity_rate_lambda(z_prev[u_it], z_prev[v_it], torch.zeros(1).long() + k))
                # intensity_rate_lambda(z_u, z_v, k,n_hidden,psi,n_assoc_types,omega,edge_type=None)


            # 2. Update node embeddings
            node_degree, z_new = self.update_node_embed(z_prev, u_it, v_it, time_delta_uv[it])  # / 3600.)  # hours
            # update_node_embed(prev_embed, node1, node2, time_delta_uv, n_hidden,n_assoc_types, S, A, W_h, W_struct, W_rec, W_t)
            if self.opt:
                node_degrees.append(node_degree)


            # 3. Update S and A
            if not self.opt:
                # we can update S and A based on current pair of nodes even during test time,
                # because S, A are not used in further steps for this iteration
                self.update_S_A(u_it, v_it, k.item(), node_degree, lambda_uv_t[it])  #
                # update_S_A(A,S, u,v, k, node_degree, lambda_uv_t, N_nodes,n_assoc_types,node_degree_global)

            # update most recent degrees of nodes used to update S
            assert self.node_degree_global is not None
            for j in [u_it, v_it]:
                for rel in range(self.n_assoc_types):
                    self.node_degree_global[rel][j] = node_degree[j][rel]


            # Non events loss
            # this is not important for test time, but we still compute these losses for debugging purposes
            # get random nodes except for u_it, v_it
            # 4. compute lambda for sampled events that do not happen -> to compute survival probability in loss
            uv_others = self.rnd.choice(np.delete(np.arange(N), [u_it, v_it]), size= self.N_surv_samples * 2, replace=False)
                # assert len(np.unique(uv_others)) == len(uv_others), ('nodes must be unique', uv_others)
            for q in range(self.N_surv_samples):
                assert u_it != uv_others[q], (u_it, uv_others[q])
                assert v_it != uv_others[self.N_surv_samples + q], (v_it, uv_others[self.N_surv_samples + q])
                if self.opt:
                    embeddings_non1.extend([z_prev[u_it], z_prev[uv_others[self.N_surv_samples + q]]])
                    embeddings_non2.extend([z_prev[uv_others[q]], z_prev[v_it]])
                else:
                    for k_ in range(2):
                        lambda_uv_t_non_events.append(
                            self.intensity_rate_lambda(z_prev[u_it],
                                                        z_prev[uv_others[q]], torch.zeros(1).long() + k_))
                        lambda_uv_t_non_events.append(
                            self.intensity_rate_lambda(z_prev[uv_others[self.N_surv_samples + q]],
                                                        z_prev[v_it],
                                                        torch.zeros(1).long() + k_))


            # 5. compute conditional density for all possible pairs
            # here it's important NOT to use any information that the event between nodes u,v has happened
            # so, we use node embeddings of the previous time step: z_prev
            with torch.no_grad():
                z_cat = torch.cat((z_prev[u_it].detach().unsqueeze(0).expand(N, -1),
                                    z_prev[v_it].detach().unsqueeze(0).expand(N, -1)), dim=0)
                Lambda = self.intensity_rate_lambda(z_cat, z_prev.detach().repeat(2, 1),
                                                    torch.zeros(len(z_cat)).long() + k).detach()
                
                A_pred[it, u_it, :] = Lambda[:N]
                A_pred[it, v_it, :] = Lambda[N:]

                assert torch.sum(torch.isnan(A_pred[it])) == 0, (it, torch.sum(torch.isnan(A_pred[it])))
                # Compute the survival term (See page 3 in the paper)
                # we only need to compute the term for rows u_it and v_it in our matrix s to save time
                # because we will compute rank only for nodes u_it and v_it
                s1 = self.cond_density(time_bar[it], u_it, v_it)
                # cond_density(time_bar, u, v, N_nodes, Lambda_dict, time_keys)
                Surv[it, [u_it, v_it], :] = s1

                time_key = int(time_cur[it].item())
                idx = np.delete(np.arange(N), [u_it, v_it])  # nonevents for node u
                idx = np.concatenate((idx, idx + N))   # concat with nonevents for node v

                if len(self.time_keys) >= len(self.Lambda_dict):
                    # shift in time (remove the oldest record)
                    time_keys = np.array(self.time_keys)
                    time_keys[:-1] = time_keys[1:]
                    self.time_keys = list(time_keys[:-1])  # remove last
                    self.Lambda_dict[:-1] = self.Lambda_dict.clone()[1:]
                    self.Lambda_dict[-1] = 0

                self.Lambda_dict[len(self.time_keys)] = Lambda[idx].sum().detach()  # total intensity of non events for the current time step
                self.time_keys.append(time_key)

            # Once we made predictions for the training and test sample, we can update node embeddings
            z_all.append(z_new)
            # update S

            self.A = self.S
            S_batch.append(self.S.data.cpu().numpy())

            self.t_p += 1

        self.z = z_new  # update node embeddings

        # Batch update
        if self.opt:
            lambda_uv_t = self.intensity_rate_lambda(torch.stack(embeddings1, dim=0),
                                                        torch.stack(embeddings2, dim=0), event_types)
            non_events = len(embeddings_non1)
            n_types = 2
            lambda_uv_t_non_events = torch.zeros(non_events * n_types)
            embeddings_non1 = torch.stack(embeddings_non1, dim=0)
            embeddings_non2 = torch.stack(embeddings_non2, dim=0)
            idx = None
            empty_t = torch.zeros(non_events, dtype=torch.long)
            types_lst = torch.arange(n_types)
            for k in types_lst:
                if idx is None:
                    idx = np.arange(non_events)
                else:
                    idx += non_events
                lambda_uv_t_non_events[idx] = self.intensity_rate_lambda(embeddings_non1, embeddings_non2, empty_t + k)

            # update only once per batch
            for it, k in enumerate(event_types):
                u_it, v_it = u_all[it], v_all[it]
                self.update_S_A(u_it, v_it, k.item(), node_degrees[it], lambda_uv_t[it].item())
                # def update_S_A(A,S, u, v, k, node_degree, lambda_uv_t, N_nodes,n_assoc_types,node_degree_global)

        else:
            lambda_uv_t = torch.cat(lambda_uv_t)
            lambda_uv_t_non_events = torch.cat(lambda_uv_t_non_events)


        if len(reg) > 1:
            reg = [torch.stack(reg).mean()]

        return lambda_uv_t, lambda_uv_t_non_events / self.N_surv_samples, [A_pred, Surv], reg

# %%
import torch
from torch.utils.data import DataLoader

# %%
def MAR(A_pred, u, v, k, Survival_term):
    '''Computes mean average ranking for a batch of events'''
    ranks = []
    hits_10 = []
    N = len(A_pred)
    Survival_term = torch.exp(-Survival_term)
    A_pred *= Survival_term
    assert torch.sum(torch.isnan(A_pred)) == 0, (torch.sum(torch.isnan(A_pred)), Survival_term.min(), Survival_term.max())

    A_pred = A_pred.data.cpu().numpy()


    assert N == len(u) == len(v) == len(k), (N, len(u), len(v), len(k))
    for b in range(N):
        u_it, v_it = u[b].item(), v[b].item()
        assert u_it != v_it, (u_it, v_it, k[b])
        A = A_pred[b].squeeze()
        # remove same node
        idx1 = list(np.argsort(A[u_it])[::-1])
        idx1.remove(u_it)
        idx2 = list(np.argsort(A[v_it])[::-1])
        idx2.remove(v_it)
        rank1 = np.where(np.array(idx1) == v_it) # get nodes most likely connected to u[b] and find out the rank of v[b] among those nodes
        rank2 = np.where(np.array(idx2) == u_it)  # get nodes most likely connected to v[b] and find out the rank of u[b] among those nodes
        assert len(rank1) == len(rank2) == 1, (len(rank1), len(rank2))
        hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
        rank = np.mean([rank1[0], rank2[0]])
        assert isinstance(rank, np.float64), (rank, rank1, rank2, u_it, v_it, idx1, idx2)
        ranks.append(rank)
    return ranks, hits_10

# %%
def initialize_state(dataset, model, node_embeddings, keepS=False):
    Adj_all = dataset.get_Adjacency()[0]

    if not isinstance(Adj_all, list):
        Adj_all = [Adj_all]

    # Ensure it is a list of adjacency matrices
    if Adj_all[0].ndim == 1 and Adj_all[0].size == dataset.N_nodes:
        # If it's a vector that should be a diagonal of a matrix
        Adj_matrix = np.zeros((dataset.N_nodes, dataset.N_nodes))
        np.fill_diagonal(Adj_matrix, Adj_all[0])
        Adj_all[0] = Adj_matrix[:, :, None]  # Convert to 3D by adding a new axis

    node_degree_global = []
    for rel, A in enumerate(Adj_all):
        node_degree_global.append(np.sum(A, axis=1))  # Sum over columns to get degrees

    time_bar = np.zeros((dataset.N_nodes, 1)) + dataset.FIRST_DATE.timestamp()

    model.initialize(node_embeddings=node_embeddings, A_initial=Adj_all[0], keepS=keepS)

    return time_bar, node_degree_global

# %%
import numpy as np
import torch

def grid_search_decay_rate(data_dir, decay_rates, epochs):
    """
    Performs grid search to find the best decay_rate for the model based on the lowest average test loss.
    
    Args:
        model (torch.nn.Module): The PyTorch model.
        train_loader (DataLoader): DataLoader for the training data.
        test_loader (DataLoader): DataLoader for the testing data.
        decay_rates (list of float): List of decay rates to evaluate.
        epochs (int): Number of epochs to train the model for each decay rate.
        initial_embeddings (Tensor): Initial node embeddings to reset model for each decay rate test.
        device (str): Device on which to perform computations ('cpu' or 'cuda').

    Returns:
        best_decay_rate (float): The decay rate yielding the lowest test loss.
        best_loss (float): The lowest test loss achieved.
    """
    best_loss = float('inf')
    best_decay_rate = None

    train_set = SyntheticDataset('train', data_dir=data_dir)
    test_set = SyntheticDataset('test',  data_dir=data_dir)
    initial_embeddings = np.random.randn (train_set.N_nodes, 32)
    A_initial = train_set.get_Adjacency()
    
    N_nodes = A_initial.shape[0]
    if A_initial.ndim == 1 and A_initial.size == N_nodes * N_nodes:
        A_initial = A_initial.reshape(N_nodes, N_nodes)[:, :, None]  # Reshape and add relationship type dimension
    elif A_initial.ndim == 1:  # If it's just a vector that doesn't match the expected size
        # Initialize A_initial as a zero matrix with an extra dimension for types
        A_initial = np.zeros((N_nodes, N_nodes, 1))
    n_assoc_types,n_event_types = 1, 1
    n_relations = n_assoc_types + n_event_types

    Adj_all = train_set.get_Adjacency()[0]

    if not isinstance(Adj_all, list):
        Adj_all = [Adj_all]

    node_degree_global = []
    for rel, A in enumerate(Adj_all):
        node_degree_global.append(np.zeros(A.shape[0]))
        for u in range(A.shape[0]):
            node_degree_global[rel][u] = np.sum(A[u])

    Adj_all = Adj_all[0]
    
    for decay_rate in decay_rates:
        print(f"Testing decay_rate: {decay_rate}")
        
        # Reset model for each decay rate test
    
        test_loss = []
        
        model = DyRep(
        node_embeddings=initial_embeddings,
        A_initial=A_initial,
        n_hidden=32,
        node_degree_global=node_degree_global,
        N_hops=2,
        decay_rate=decay_rate,
        )
        params_main = []
        for name, param in model.named_parameters():
            if param.requires_grad:
                params_main.append(param)
        train_loader = DataLoader(train_set, batch_size=200, shuffle=False)
        test_loader = DataLoader(test_set, batch_size=200, shuffle=False)
        optimizer = torch.optim.Adam([{"params": params_main, "weight_decay":0}], lr=0.0002, betas=(0.5, 0.999))
        scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, '10', gamma=0.5)
        time_bar = np.zeros((N_nodes, 1)) + train_set.FIRST_DATE.timestamp()
        import copy
        def get_temporal_variables():
            variables = {}
            variables['time_bar'] = copy.deepcopy(time_bar)
            variables['node_degree_global'] = copy.deepcopy(node_degree_global)
            variables['time_keys'] = copy.deepcopy(model.time_keys)
            variables['z'] = model.z.clone()
            variables['S'] = model.S.clone()
            variables['A'] = model.A.clone()
            variables['Lambda_dict'] = model.Lambda_dict.clone()
            return variables
        def set_temporal_variables(variables, model, train_loader, test_loader):
            time_bar = copy.deepcopy(variables['time_bar'])
            train_loader.dataset.time_bar = time_bar
            test_loader.dataset.time_bar = time_bar
            model.node_degree_global = copy.deepcopy(variables['node_degree_global'])
            model.time_keys = copy.deepcopy(variables['time_keys'])
            model.z = variables['z'].clone()
            model.S = variables['S'].clone()
            model.A = variables['A'].clone()
            model.Lambda_dict = variables['Lambda_dict'].clone()
            return time_bar
        import time
        def test(model, n_test_batches=10, epoch=0):
            model.eval()
            loss = 0
            losses =[ [np.Inf, 0], [np.Inf, 0] ]
            n_samples = 0
            # Time slots with 10 days intervals as in the DyRep paper
            timeslots = [t.toordinal() for t in test_loader.dataset.TEST_TIMESLOTS]
            event_types = list(test_loader.dataset.event_types_num.keys()) #['comm', 'assoc']
            # sort it by k
            for event_t in test_loader.dataset.event_types_num:
                event_types[test_loader.dataset.event_types_num[event_t]] = event_t

            event_types += ['Com']

            mar, hits_10 = {}, {}
            for event_t in event_types:
                mar[event_t] = []
                hits_10[event_t] = []
                for c, slot in enumerate(timeslots):
                    mar[event_t].append([])
                    hits_10[event_t].append([])


            start = time.time()
            with torch.no_grad():
                
                import datetime
                #from datetime import datetime, timezone 
                for batch_idx, data in enumerate(test_loader):
                    data[2] = data[2].float()
                    data[4] = data[4].double()
                    data[5] = data[5].double()
                    output = model(data)
                    loss += (-torch.sum(torch.log(output[0]) + 1e-10) + torch.sum(output[1])).item()
                    for i in range(len(losses)):
                        m1 = output[i].min()
                        m2 = output[i].max()
                        if m1 < losses[i][0]:
                            losses[i][0] = m1
                        if m2 > losses[i][1]:
                            losses[i][1] = m2
                    n_samples += 1
                    A_pred, Survival_term = output[2]
                    u, v, k = data[0], data[1], data[3]

                    time_cur = data[5]
                    m, h = MAR(A_pred, u, v, k, Survival_term=Survival_term)
                    assert len(time_cur) == len(m) == len(h) == len(k)
                    for t, m, h, k_ in zip(time_cur, m, h, k):
                        d = datetime.datetime.fromtimestamp(t.item()).toordinal()
                        event_t = event_types[k_.item()]
                        for c, slot in enumerate(timeslots):
                            if d <= slot:
                                mar[event_t][c].append(m)
                                hits_10[event_t][c].append(h)
                                if k_ > 0:
                                    mar['Com'][c].append(m)
                                    hits_10['Com'][c].append(h)
                                if c > 0:
                                    assert slot > timeslots[c-1] and d > timeslots[c-1], (d, slot, timeslots[c-1])
                                break

                    if batch_idx % 10 == 0:
                        print('test', batch_idx)

                    if n_test_batches is not None and batch_idx >= n_test_batches - 1:
                        break

            time_iter = time.time() - start

            print('\nTEST batch={}/{}, loss={:.3f}, psi={}, loss1 min/max={:.4f}/{:.4f}, '
                'loss2 min/max={:.4f}/{:.4f}, integral time stamps={}, sec/iter={:.4f}'.
                format(batch_idx + 1, len(test_loader), (loss / n_samples),
                        [model.psi[c].item() for c in range(len(model.psi))],
                        losses[0][0], losses[0][1], losses[1][0], losses[1][1],
                        len(model.Lambda_dict), time_iter / (batch_idx + 1)))

            # Report results for different time slots in the test set
            for c, slot in enumerate(timeslots):
                s = 'Slot {}: '.format(c)
                for event_t in event_types:
                    sfx = '' if event_t == event_types[-1] else ', '
                    if len(mar[event_t][c]) > 0:
                        s += '{} ({} events): MAR={:.2f}+-{:.2f}, HITS_10={:.3f}+-{:.3f}'.\
                            format(event_t, len(mar[event_t][c]), np.mean(mar[event_t][c]), np.std(mar[event_t][c]),
                                    np.mean(hits_10[event_t][c]), np.std(hits_10[event_t][c]))
                    else:
                        s += '{} (no events)'.format(event_t)
                    s += sfx
                print(s)

            mar_all, hits_10_all = {}, {}
            for event_t in event_types:
                mar_all[event_t] = []
                hits_10_all[event_t] = []
                for c, slot in enumerate(timeslots):
                    mar_all[event_t].extend(mar[event_t][c])
                    hits_10_all[event_t].extend(hits_10[event_t][c])

            s = 'Epoch {}: results per event type for all test time slots: \n'.format(epoch)
            print(''.join(['-']*100))
            for event_t in event_types:
                if len(mar_all[event_t]) > 0:
                    s += '====== {:10s}\t ({:7s} events): \tMAR={:.2f}+-{:.2f}\t HITS_10={:.3f}+-{:.3f}'.format(
                        str(event_t),  # Ensure event_t is a string
                        str(len(mar_all[event_t])),  # Ensure this is also a string if it isn't already
                        np.mean(mar_all[event_t]),
                        np.std(mar_all[event_t]),
                        np.mean(hits_10_all[event_t]),
                        np.std(hits_10_all[event_t])
                    )
                else:
                    s += '====== {:10s}\t (no events)'.format(str(event_t))  # Ensure event_t is a string
                if event_t != event_types[-1]:
                    s += '\n'
            print(s)
            print(''.join(['-'] * 100))

            return mar_all, hits_10_all, loss / n_samples
        epoch_start = 1
        batch_size = 200
        weight = 1
        log_interval = 20
        # Train and test the model for a specified number of epochs
        for epoch in range(epoch_start, epochs + 1):
            if epoch > epoch_start:
                time_bar, node_degree_global = initialize_state(
                    dataset=train_loader.dataset,
                    model=model,
                    node_embeddings=initial_embeddings,
                    keepS=epoch > 1  # Only keep states after the first epoch if needed
                )
                model.node_degree_global = node_degree_global
                
            # Setting the global time_bar for the datasets
            train_loader.dataset.time_bar = time_bar
            test_loader.dataset.time_bar = time_bar

            start = time.time()

            for batch_idx, data_batch in enumerate(train_loader):
                # if batch_idx <= batch_start:
                #   continue

                model.train()
                optimizer.zero_grad()

                # Ensure the data is in the correct format
                data_batch[2] = data_batch[2].float()
                data_batch[4] = data_batch[4].double()
                data_batch[5] = data_batch[5].double()

                output = model(data_batch)
                losses = [-torch.sum(torch.log(output[0]) + 1e-10), weight * torch.sum(output[1])]

                # KL losses (if there are additional items in output to process as losses)
                if len(output) > 3 and output[-1] is not None:
                    losses.extend(output[-1])

                loss = torch.sum(torch.stack(losses)) / batch_size
                loss.backward()
                nn.utils.clip_grad_value_(model.parameters(), 100)
                optimizer.step()

                # Clamping psi to prevent numerical overflow
                model.psi.data = torch.clamp(model.psi.data, 1e-1, 1e+3)

                time_iter = time.time() - start

                # Detach computational graph to prevent unwanted backprop
                model.z = model.z.detach()
                model.S = model.S.detach()

                if (batch_idx + 1) % log_interval == 0 or batch_idx == len(train_loader) - 1:

                    # Save state before testing
                    variables = get_temporal_variables()
                    #print('time', datetime.datetime.fromtimestamp(np.max(time_bar)))

                    # Testing and collecting results
                    result = test(model, n_test_batches=None if batch_idx == len(train_loader) - 1 else 10, epoch=epoch)
                    test_loss.append(result[2])

                    # Restore state after testing
                    time_bar = set_temporal_variables(variables, model, train_loader, test_loader)
            avg_test_loss = sum(test_loss) / len(test_loss)
            print(f"Epoch {epoch}, Decay Rate {decay_rate}, Test Loss: {avg_test_loss}")
            scheduler.step()
    
        if avg_test_loss < best_loss:
            best_loss = avg_test_loss
            best_decay_rate = decay_rate

    return best_decay_rate, best_loss

# %%
decay_rates = np.linspace(0.01, 1.0, 20)  # Example range of decay rates
best_decay_rate, best_loss = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.1.csv', decay_rates=decay_rates, epochs=5)
print(f"Best decay_rate: {best_decay_rate} with loss: {best_loss}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0.01
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=311.929, psi=[0.5004544854164124, 0.49977365136146545], loss1 min/max=0.4838/0.4913, loss2 min/max=0.0189/0.0987, integral time stamps=5000, sec/iter=0.3221
# Slot 0: 0 (no events), 1 (662 events): MAR=9.10+-3.95, HITS_10=0.522+-0.361, Com (662 events): MAR=9.10+-3.95, HITS_10=0.522+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.522+-0.361
# ====== Com       	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.522+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.01, Test Loss: 311.929162979126
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=315.714, psi=[0.5009748339653015, 0.4994206130504608], loss1 min/max=0.4871/0.4928, loss2 min/max=0.0212/0.0989, integral time stamps=5000, sec/iter=0.3039
# Slot 0: 0 (no events), 1 (662 events): MAR=9.09+-3.97, HITS_10=0.524+-0.360, Com (662 events): MAR=9.09+-3.97, HITS_10=0.524+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.09+-3.97	 HITS_10=0.524+-0.360
# ====== Com       	 (662     events): 	MAR=9.09+-3.97	 HITS_10=0.524+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.01, Test Loss: 313.8215322494507
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=319.990, psi=[0.5015186071395874, 0.49901819229125977], loss1 min/max=0.4872/0.4929, loss2 min/max=0.0238/0.0991, integral time stamps=5000, sec/iter=0.3020
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-4.00, HITS_10=0.521+-0.362, Com (662 events): MAR=9.12+-4.00, HITS_10=0.521+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-4.00	 HITS_10=0.521+-0.362
# ====== Com       	 (662     events): 	MAR=9.12+-4.00	 HITS_10=0.521+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.01, Test Loss: 315.8775221506755
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=324.775, psi=[0.5020625591278076, 0.4986012876033783], loss1 min/max=0.4869/0.4928, loss2 min/max=0.0267/0.0990, integral time stamps=5000, sec/iter=0.3108
# Slot 0: 0 (no events), 1 (662 events): MAR=9.13+-4.01, HITS_10=0.521+-0.359, Com (662 events): MAR=9.13+-4.01, HITS_10=0.521+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.13+-4.01	 HITS_10=0.521+-0.359
# ====== Com       	 (662     events): 	MAR=9.13+-4.01	 HITS_10=0.521+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.01, Test Loss: 318.1019825935364
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=330.070, psi=[0.5025979280471802, 0.4981772303581238], loss1 min/max=0.4865/0.4924, loss2 min/max=0.0298/0.0990, integral time stamps=5000, sec/iter=0.3032
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-4.00, HITS_10=0.522+-0.364, Com (662 events): MAR=9.12+-4.00, HITS_10=0.522+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-4.00	 HITS_10=0.522+-0.364
# ====== Com       	 (662     events): 	MAR=9.12+-4.00	 HITS_10=0.522+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.01, Test Loss: 320.4955741882324
# Testing decay_rate: 0.06210526315789474
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=419.086, psi=[0.5004478096961975, 0.5000044703483582], loss1 min/max=0.4540/0.4650, loss2 min/max=0.0830/0.0932, integral time stamps=5000, sec/iter=0.3046
# Slot 0: 0 (no events), 1 (662 events): MAR=9.30+-3.97, HITS_10=0.486+-0.362, Com (662 events): MAR=9.30+-3.97, HITS_10=0.486+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.30+-3.97	 HITS_10=0.486+-0.362
# ====== Com       	 (662     events): 	MAR=9.30+-3.97	 HITS_10=0.486+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.06210526315789474, Test Loss: 419.08641815185547
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=429.948, psi=[0.5009514093399048, 0.49991729855537415], loss1 min/max=0.4598/0.4693, loss2 min/max=0.0896/0.0940, integral time stamps=5000, sec/iter=0.2992
# Slot 0: 0 (no events), 1 (662 events): MAR=9.28+-3.97, HITS_10=0.491+-0.361, Com (662 events): MAR=9.28+-3.97, HITS_10=0.491+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.28+-3.97	 HITS_10=0.491+-0.361
# ====== Com       	 (662     events): 	MAR=9.28+-3.97	 HITS_10=0.491+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.06210526315789474, Test Loss: 424.5170307159424
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=441.406, psi=[0.501471221446991, 0.4997737407684326], loss1 min/max=0.4613/0.4708, loss2 min/max=0.0925/0.0991, integral time stamps=5000, sec/iter=0.3000
# Slot 0: 0 (no events), 1 (662 events): MAR=9.28+-3.98, HITS_10=0.491+-0.361, Com (662 events): MAR=9.28+-3.98, HITS_10=0.491+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.28+-3.98	 HITS_10=0.491+-0.361
# ====== Com       	 (662     events): 	MAR=9.28+-3.98	 HITS_10=0.491+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.06210526315789474, Test Loss: 430.1465301513672
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=453.362, psi=[0.5019848942756653, 0.49960893392562866], loss1 min/max=0.4617/0.4713, loss2 min/max=0.0925/0.1064, integral time stamps=5000, sec/iter=0.3221
# Slot 0: 0 (no events), 1 (662 events): MAR=9.29+-3.98, HITS_10=0.492+-0.361, Com (662 events): MAR=9.29+-3.98, HITS_10=0.492+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.29+-3.98	 HITS_10=0.492+-0.361
# ====== Com       	 (662     events): 	MAR=9.29+-3.98	 HITS_10=0.492+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.06210526315789474, Test Loss: 435.9503345489502
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=465.708, psi=[0.5024843811988831, 0.4994364380836487], loss1 min/max=0.4617/0.4714, loss2 min/max=0.0925/0.1142, integral time stamps=5000, sec/iter=0.3011
# Slot 0: 0 (no events), 1 (662 events): MAR=9.28+-3.99, HITS_10=0.494+-0.364, Com (662 events): MAR=9.28+-3.99, HITS_10=0.494+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.28+-3.99	 HITS_10=0.494+-0.364
# ====== Com       	 (662     events): 	MAR=9.28+-3.99	 HITS_10=0.494+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.06210526315789474, Test Loss: 441.90191040039065
# Testing decay_rate: 0.11421052631578947
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=357.071, psi=[0.5004529356956482, 0.5011934041976929], loss1 min/max=0.1829/0.1859, loss2 min/max=0.0099/0.0372, integral time stamps=5000, sec/iter=0.2987
# Slot 0: 0 (no events), 1 (662 events): MAR=8.86+-4.27, HITS_10=0.529+-0.385, Com (662 events): MAR=8.86+-4.27, HITS_10=0.529+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.86+-4.27	 HITS_10=0.529+-0.385
# ====== Com       	 (662     events): 	MAR=8.86+-4.27	 HITS_10=0.529+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.11421052631578947, Test Loss: 357.070987701416
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=342.691, psi=[0.5009666085243225, 0.5024316310882568], loss1 min/max=0.2153/0.2183, loss2 min/max=0.0108/0.0437, integral time stamps=5000, sec/iter=0.2999
# Slot 0: 0 (no events), 1 (662 events): MAR=8.82+-4.29, HITS_10=0.534+-0.383, Com (662 events): MAR=8.82+-4.29, HITS_10=0.534+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.82+-4.29	 HITS_10=0.534+-0.383
# ====== Com       	 (662     events): 	MAR=8.82+-4.29	 HITS_10=0.534+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.11421052631578947, Test Loss: 349.8808765411377
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=332.322, psi=[0.5015135407447815, 0.5034828186035156], loss1 min/max=0.2474/0.2506, loss2 min/max=0.0118/0.0501, integral time stamps=5000, sec/iter=0.2996
# Slot 0: 0 (no events), 1 (662 events): MAR=8.79+-4.31, HITS_10=0.542+-0.381, Com (662 events): MAR=8.79+-4.31, HITS_10=0.542+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.79+-4.31	 HITS_10=0.542+-0.381
# ====== Com       	 (662     events): 	MAR=8.79+-4.31	 HITS_10=0.542+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.11421052631578947, Test Loss: 344.0278015136719
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=325.256, psi=[0.5020692348480225, 0.5043619275093079], loss1 min/max=0.2783/0.2816, loss2 min/max=0.0130/0.0564, integral time stamps=5000, sec/iter=0.3029
# Slot 0: 0 (no events), 1 (662 events): MAR=8.80+-4.32, HITS_10=0.539+-0.384, Com (662 events): MAR=8.80+-4.32, HITS_10=0.539+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.80+-4.32	 HITS_10=0.539+-0.384
# ====== Com       	 (662     events): 	MAR=8.80+-4.32	 HITS_10=0.539+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.11421052631578947, Test Loss: 339.3347554206848
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=320.872, psi=[0.50262451171875, 0.5050857067108154], loss1 min/max=0.3070/0.3104, loss2 min/max=0.0143/0.0622, integral time stamps=5000, sec/iter=0.3011
# Slot 0: 0 (no events), 1 (662 events): MAR=8.82+-4.29, HITS_10=0.533+-0.387, Com (662 events): MAR=8.82+-4.29, HITS_10=0.533+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.82+-4.29	 HITS_10=0.533+-0.387
# ====== Com       	 (662     events): 	MAR=8.82+-4.29	 HITS_10=0.533+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.11421052631578947, Test Loss: 335.64227867126465
# Testing decay_rate: 0.16631578947368422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=605.857, psi=[0.5004579424858093, 0.5012212991714478], loss1 min/max=0.1510/0.1550, loss2 min/max=0.0301/0.1486, integral time stamps=5000, sec/iter=0.3146
# Slot 0: 0 (no events), 1 (662 events): MAR=8.77+-4.22, HITS_10=0.542+-0.382, Com (662 events): MAR=8.77+-4.22, HITS_10=0.542+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.77+-4.22	 HITS_10=0.542+-0.382
# ====== Com       	 (662     events): 	MAR=8.77+-4.22	 HITS_10=0.542+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.16631578947368422, Test Loss: 605.8567886352539
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=590.696, psi=[0.5010481476783752, 0.5024786591529846], loss1 min/max=0.1868/0.1914, loss2 min/max=0.0373/0.1534, integral time stamps=5000, sec/iter=0.3065
# Slot 0: 0 (no events), 1 (662 events): MAR=8.75+-4.18, HITS_10=0.537+-0.378, Com (662 events): MAR=8.75+-4.18, HITS_10=0.537+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.75+-4.18	 HITS_10=0.537+-0.378
# ====== Com       	 (662     events): 	MAR=8.75+-4.18	 HITS_10=0.537+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.16631578947368422, Test Loss: 598.2766189575195
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=581.870, psi=[0.501634955406189, 0.5035273432731628], loss1 min/max=0.2245/0.2297, loss2 min/max=0.0448/0.1587, integral time stamps=5000, sec/iter=0.3146
# Slot 0: 0 (no events), 1 (662 events): MAR=8.78+-4.19, HITS_10=0.539+-0.378, Com (662 events): MAR=8.78+-4.19, HITS_10=0.539+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.78+-4.19	 HITS_10=0.539+-0.378
# ====== Com       	 (662     events): 	MAR=8.78+-4.19	 HITS_10=0.539+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.16631578947368422, Test Loss: 592.8077952067057
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=578.514, psi=[0.502210259437561, 0.5043809413909912], loss1 min/max=0.2619/0.2679, loss2 min/max=0.0522/0.1644, integral time stamps=5000, sec/iter=0.3043
# Slot 0: 0 (no events), 1 (662 events): MAR=8.79+-4.19, HITS_10=0.545+-0.382, Com (662 events): MAR=8.79+-4.19, HITS_10=0.545+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.79+-4.19	 HITS_10=0.545+-0.382
# ====== Com       	 (662     events): 	MAR=8.79+-4.19	 HITS_10=0.545+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.16631578947368422, Test Loss: 589.234245300293
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=579.603, psi=[0.5027711987495422, 0.5050586462020874], loss1 min/max=0.2974/0.3039, loss2 min/max=0.0593/0.1705, integral time stamps=5000, sec/iter=0.3071
# Slot 0: 0 (no events), 1 (662 events): MAR=8.78+-4.17, HITS_10=0.546+-0.378, Com (662 events): MAR=8.78+-4.17, HITS_10=0.546+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.78+-4.17	 HITS_10=0.546+-0.378
# ====== Com       	 (662     events): 	MAR=8.78+-4.17	 HITS_10=0.546+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.16631578947368422, Test Loss: 587.308088684082
# Testing decay_rate: 0.21842105263157896
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=481.725, psi=[0.5004634857177734, 0.49847713112831116], loss1 min/max=1.0447/1.0636, loss2 min/max=0.0834/0.2138, integral time stamps=5000, sec/iter=0.3075
# Slot 0: 0 (no events), 1 (662 events): MAR=9.20+-4.02, HITS_10=0.505+-0.366, Com (662 events): MAR=9.20+-4.02, HITS_10=0.505+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.20+-4.02	 HITS_10=0.505+-0.366
# ====== Com       	 (662     events): 	MAR=9.20+-4.02	 HITS_10=0.505+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.21842105263157896, Test Loss: 481.7247085571289
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=466.042, psi=[0.5010504126548767, 0.49687111377716064], loss1 min/max=0.9173/0.9355, loss2 min/max=0.0866/0.1881, integral time stamps=5000, sec/iter=0.3035
# Slot 0: 0 (no events), 1 (662 events): MAR=9.20+-4.02, HITS_10=0.509+-0.364, Com (662 events): MAR=9.20+-4.02, HITS_10=0.509+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.20+-4.02	 HITS_10=0.509+-0.364
# ====== Com       	 (662     events): 	MAR=9.20+-4.02	 HITS_10=0.509+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.21842105263157896, Test Loss: 473.8831901550293
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=456.277, psi=[0.5016422271728516, 0.49527761340141296], loss1 min/max=0.8094/0.8265, loss2 min/max=0.0903/0.1662, integral time stamps=5000, sec/iter=0.3039
# Slot 0: 0 (no events), 1 (662 events): MAR=9.20+-4.01, HITS_10=0.509+-0.370, Com (662 events): MAR=9.20+-4.01, HITS_10=0.509+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.20+-4.01	 HITS_10=0.509+-0.370
# ====== Com       	 (662     events): 	MAR=9.20+-4.01	 HITS_10=0.509+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.21842105263157896, Test Loss: 468.0143191019694
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=451.755, psi=[0.5022280812263489, 0.49375754594802856], loss1 min/max=0.7194/0.7354, loss2 min/max=0.0937/0.1475, integral time stamps=5000, sec/iter=0.3077
# Slot 0: 0 (no events), 1 (662 events): MAR=9.23+-4.03, HITS_10=0.508+-0.371, Com (662 events): MAR=9.23+-4.03, HITS_10=0.508+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.23+-4.03	 HITS_10=0.508+-0.371
# ====== Com       	 (662     events): 	MAR=9.23+-4.03	 HITS_10=0.508+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.21842105263157896, Test Loss: 463.94954204559326
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=451.767, psi=[0.5028032064437866, 0.4923692047595978], loss1 min/max=0.6482/0.6628, loss2 min/max=0.0978/0.1332, integral time stamps=5000, sec/iter=0.3246
# Slot 0: 0 (no events), 1 (662 events): MAR=9.22+-4.03, HITS_10=0.505+-0.370, Com (662 events): MAR=9.22+-4.03, HITS_10=0.505+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.22+-4.03	 HITS_10=0.505+-0.370
# ====== Com       	 (662     events): 	MAR=9.22+-4.03	 HITS_10=0.505+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.21842105263157896, Test Loss: 461.51300888061525
# Testing decay_rate: 0.2705263157894737
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=314.092, psi=[0.5004498362541199, 0.49923935532569885], loss1 min/max=0.5326/0.5375, loss2 min/max=0.0201/0.1075, integral time stamps=5000, sec/iter=0.3030
# Slot 0: 0 (no events), 1 (662 events): MAR=9.04+-4.07, HITS_10=0.521+-0.374, Com (662 events): MAR=9.04+-4.07, HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.04+-4.07	 HITS_10=0.521+-0.374
# ====== Com       	 (662     events): 	MAR=9.04+-4.07	 HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.2705263157894737, Test Loss: 314.0924129486084
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=316.121, psi=[0.500949501991272, 0.4986511170864105], loss1 min/max=0.5009/0.5025, loss2 min/max=0.0215/0.1006, integral time stamps=5000, sec/iter=0.3243
# Slot 0: 0 (no events), 1 (662 events): MAR=9.09+-4.03, HITS_10=0.525+-0.372, Com (662 events): MAR=9.09+-4.03, HITS_10=0.525+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.09+-4.03	 HITS_10=0.525+-0.372
# ====== Com       	 (662     events): 	MAR=9.09+-4.03	 HITS_10=0.525+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.2705263157894737, Test Loss: 315.1069440841675
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=319.394, psi=[0.5014854073524475, 0.4982205629348755], loss1 min/max=0.4853/0.4875, loss2 min/max=0.0234/0.0976, integral time stamps=5000, sec/iter=0.3435
# Slot 0: 0 (no events), 1 (662 events): MAR=9.11+-4.00, HITS_10=0.525+-0.365, Com (662 events): MAR=9.11+-4.00, HITS_10=0.525+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.11+-4.00	 HITS_10=0.525+-0.365
# ====== Com       	 (662     events): 	MAR=9.11+-4.00	 HITS_10=0.525+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.2705263157894737, Test Loss: 316.5359471638997
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=323.333, psi=[0.5020288228988647, 0.4978775084018707], loss1 min/max=0.4785/0.4815, loss2 min/max=0.0257/0.0964, integral time stamps=5000, sec/iter=0.3004
# Slot 0: 0 (no events), 1 (662 events): MAR=9.10+-3.99, HITS_10=0.526+-0.363, Com (662 events): MAR=9.10+-3.99, HITS_10=0.526+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.10+-3.99	 HITS_10=0.526+-0.363
# ====== Com       	 (662     events): 	MAR=9.10+-3.99	 HITS_10=0.526+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.2705263157894737, Test Loss: 318.235089302063
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=327.740, psi=[0.5025681853294373, 0.4975748062133789], loss1 min/max=0.4756/0.4790, loss2 min/max=0.0283/0.0958, integral time stamps=5000, sec/iter=0.2982
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-3.97, HITS_10=0.520+-0.366, Com (662 events): MAR=9.12+-3.97, HITS_10=0.520+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-3.97	 HITS_10=0.520+-0.366
# ====== Com       	 (662     events): 	MAR=9.12+-3.97	 HITS_10=0.520+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.2705263157894737, Test Loss: 320.1360908508301
# Testing decay_rate: 0.32263157894736844
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=401.389, psi=[0.5004573464393616, 0.5012049674987793], loss1 min/max=0.1693/0.1735, loss2 min/max=0.0322/0.0347, integral time stamps=5000, sec/iter=0.2998
# Slot 0: 0 (no events), 1 (662 events): MAR=9.23+-4.04, HITS_10=0.513+-0.372, Com (662 events): MAR=9.23+-4.04, HITS_10=0.513+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.23+-4.04	 HITS_10=0.513+-0.372
# ====== Com       	 (662     events): 	MAR=9.23+-4.04	 HITS_10=0.513+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.32263157894736844, Test Loss: 401.38887786865234
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=386.431, psi=[0.5010031461715698, 0.5024471879005432], loss1 min/max=0.2038/0.2083, loss2 min/max=0.0345/0.0417, integral time stamps=5000, sec/iter=0.2989
# Slot 0: 0 (no events), 1 (662 events): MAR=9.25+-4.02, HITS_10=0.507+-0.370, Com (662 events): MAR=9.25+-4.02, HITS_10=0.507+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.25+-4.02	 HITS_10=0.507+-0.370
# ====== Com       	 (662     events): 	MAR=9.25+-4.02	 HITS_10=0.507+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.32263157894736844, Test Loss: 393.909969329834
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=376.517, psi=[0.5015677213668823, 0.5034911632537842], loss1 min/max=0.2385/0.2433, loss2 min/max=0.0371/0.0487, integral time stamps=5000, sec/iter=0.3183
# Slot 0: 0 (no events), 1 (662 events): MAR=9.24+-4.01, HITS_10=0.511+-0.367, Com (662 events): MAR=9.24+-4.01, HITS_10=0.511+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.24+-4.01	 HITS_10=0.511+-0.367
# ====== Com       	 (662     events): 	MAR=9.24+-4.01	 HITS_10=0.511+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.32263157894736844, Test Loss: 388.11243438720703
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=370.732, psi=[0.5021317005157471, 0.5043537616729736], loss1 min/max=0.2721/0.2771, loss2 min/max=0.0399/0.0555, integral time stamps=5000, sec/iter=0.2976
# Slot 0: 0 (no events), 1 (662 events): MAR=9.24+-4.03, HITS_10=0.509+-0.367, Com (662 events): MAR=9.24+-4.03, HITS_10=0.509+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.24+-4.03	 HITS_10=0.509+-0.367
# ====== Com       	 (662     events): 	MAR=9.24+-4.03	 HITS_10=0.509+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.32263157894736844, Test Loss: 383.7672882080078
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=368.252, psi=[0.5026882290840149, 0.5050532221794128], loss1 min/max=0.3033/0.3085, loss2 min/max=0.0428/0.0618, integral time stamps=5000, sec/iter=0.2987
# Slot 0: 0 (no events), 1 (662 events): MAR=9.23+-4.03, HITS_10=0.511+-0.369, Com (662 events): MAR=9.23+-4.03, HITS_10=0.511+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.23+-4.03	 HITS_10=0.511+-0.369
# ====== Com       	 (662     events): 	MAR=9.23+-4.03	 HITS_10=0.511+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.32263157894736844, Test Loss: 380.6641670227051
# Testing decay_rate: 0.37473684210526315
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=427.550, psi=[0.5004457831382751, 0.5011439919471741], loss1 min/max=0.2243/0.2319, loss2 min/max=0.0449/0.0655, integral time stamps=5000, sec/iter=0.2991
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-3.92, HITS_10=0.523+-0.364, Com (662 events): MAR=9.12+-3.92, HITS_10=0.523+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-3.92	 HITS_10=0.523+-0.364
# ====== Com       	 (662     events): 	MAR=9.12+-3.92	 HITS_10=0.523+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.37473684210526315, Test Loss: 427.55028915405273
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=418.284, psi=[0.5009320974349976, 0.5022684335708618], loss1 min/max=0.2654/0.2736, loss2 min/max=0.0530/0.0682, integral time stamps=5000, sec/iter=0.2999
# Slot 0: 0 (no events), 1 (662 events): MAR=9.11+-3.91, HITS_10=0.523+-0.360, Com (662 events): MAR=9.11+-3.91, HITS_10=0.523+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.11+-3.91	 HITS_10=0.523+-0.360
# ====== Com       	 (662     events): 	MAR=9.11+-3.91	 HITS_10=0.523+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.37473684210526315, Test Loss: 422.91730880737305
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=414.155, psi=[0.5014556646347046, 0.5031546950340271], loss1 min/max=0.3035/0.3122, loss2 min/max=0.0607/0.0713, integral time stamps=5000, sec/iter=0.2999
# Slot 0: 0 (no events), 1 (662 events): MAR=9.11+-3.93, HITS_10=0.523+-0.364, Com (662 events): MAR=9.11+-3.93, HITS_10=0.523+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.11+-3.93	 HITS_10=0.523+-0.364
# ====== Com       	 (662     events): 	MAR=9.11+-3.93	 HITS_10=0.523+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.37473684210526315, Test Loss: 419.9964739481608
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=413.771, psi=[0.5019890666007996, 0.5038356184959412], loss1 min/max=0.3368/0.3459, loss2 min/max=0.0673/0.0746, integral time stamps=5000, sec/iter=0.3128
# Slot 0: 0 (no events), 1 (662 events): MAR=9.10+-3.95, HITS_10=0.523+-0.366, Com (662 events): MAR=9.10+-3.95, HITS_10=0.523+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.523+-0.366
# ====== Com       	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.523+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.37473684210526315, Test Loss: 418.4401788711548
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=416.003, psi=[0.5025216341018677, 0.5043474435806274], loss1 min/max=0.3647/0.3739, loss2 min/max=0.0729/0.0782, integral time stamps=5000, sec/iter=0.3038
# Slot 0: 0 (no events), 1 (662 events): MAR=9.10+-3.95, HITS_10=0.521+-0.365, Com (662 events): MAR=9.10+-3.95, HITS_10=0.521+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.521+-0.365
# ====== Com       	 (662     events): 	MAR=9.10+-3.95	 HITS_10=0.521+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.37473684210526315, Test Loss: 417.95269241333006
# Testing decay_rate: 0.4268421052631579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=1035.195, psi=[0.5004178881645203, 0.5016688108444214], loss1 min/max=0.0344/0.0356, loss2 min/max=0.0069/0.2851, integral time stamps=5000, sec/iter=0.3058
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-4.04, HITS_10=0.512+-0.367, Com (662 events): MAR=9.12+-4.04, HITS_10=0.512+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-4.04	 HITS_10=0.512+-0.367
# ====== Com       	 (662     events): 	MAR=9.12+-4.04	 HITS_10=0.512+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4268421052631579, Test Loss: 1035.1949768066406
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=988.787, psi=[0.5008400678634644, 0.5030986666679382], loss1 min/max=0.0457/0.0473, loss2 min/max=0.0091/0.2831, integral time stamps=5000, sec/iter=0.3047
# Slot 0: 0 (no events), 1 (662 events): MAR=9.11+-4.05, HITS_10=0.518+-0.366, Com (662 events): MAR=9.11+-4.05, HITS_10=0.518+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.11+-4.05	 HITS_10=0.518+-0.366
# ====== Com       	 (662     events): 	MAR=9.11+-4.05	 HITS_10=0.518+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4268421052631579, Test Loss: 1011.991153717041
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=946.613, psi=[0.501322329044342, 0.5044189095497131], loss1 min/max=0.0600/0.0620, loss2 min/max=0.0120/0.2817, integral time stamps=5000, sec/iter=0.3109
# Slot 0: 0 (no events), 1 (662 events): MAR=9.10+-4.03, HITS_10=0.515+-0.363, Com (662 events): MAR=9.10+-4.03, HITS_10=0.515+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.10+-4.03	 HITS_10=0.515+-0.363
# ====== Com       	 (662     events): 	MAR=9.10+-4.03	 HITS_10=0.515+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4268421052631579, Test Loss: 990.198382059733
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=908.791, psi=[0.501835823059082, 0.5056264400482178], loss1 min/max=0.0776/0.0802, loss2 min/max=0.0155/0.2809, integral time stamps=5000, sec/iter=0.3099
# Slot 0: 0 (no events), 1 (662 events): MAR=9.07+-4.05, HITS_10=0.514+-0.361, Com (662 events): MAR=9.07+-4.05, HITS_10=0.514+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.07+-4.05	 HITS_10=0.514+-0.361
# ====== Com       	 (662     events): 	MAR=9.07+-4.05	 HITS_10=0.514+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.4268421052631579, Test Loss: 969.846529006958
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=875.771, psi=[0.5023680329322815, 0.5067148804664612], loss1 min/max=0.0987/0.1020, loss2 min/max=0.0197/0.2806, integral time stamps=5000, sec/iter=0.3036
# Slot 0: 0 (no events), 1 (662 events): MAR=9.04+-4.03, HITS_10=0.521+-0.363, Com (662 events): MAR=9.04+-4.03, HITS_10=0.521+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.04+-4.03	 HITS_10=0.521+-0.363
# ====== Com       	 (662     events): 	MAR=9.04+-4.03	 HITS_10=0.521+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.4268421052631579, Test Loss: 951.0313369750977
# Testing decay_rate: 0.4789473684210527
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=356.699, psi=[0.5004500150680542, 0.49961450695991516], loss1 min/max=0.4916/0.5028, loss2 min/max=0.0454/0.1020, integral time stamps=5000, sec/iter=0.3039
# Slot 0: 0 (no events), 1 (662 events): MAR=9.13+-3.88, HITS_10=0.513+-0.357, Com (662 events): MAR=9.13+-3.88, HITS_10=0.513+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.13+-3.88	 HITS_10=0.513+-0.357
# ====== Com       	 (662     events): 	MAR=9.13+-3.88	 HITS_10=0.513+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4789473684210527, Test Loss: 356.6992950439453
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=363.564, psi=[0.5009406208992004, 0.4992409944534302], loss1 min/max=0.4838/0.4948, loss2 min/max=0.0496/0.1004, integral time stamps=5000, sec/iter=0.3186
# Slot 0: 0 (no events), 1 (662 events): MAR=9.11+-3.87, HITS_10=0.517+-0.357, Com (662 events): MAR=9.11+-3.87, HITS_10=0.517+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.11+-3.87	 HITS_10=0.517+-0.357
# ====== Com       	 (662     events): 	MAR=9.11+-3.87	 HITS_10=0.517+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4789473684210527, Test Loss: 360.131778717041
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=371.501, psi=[0.501458466053009, 0.4988880753517151], loss1 min/max=0.4791/0.4905, loss2 min/max=0.0545/0.0991, integral time stamps=5000, sec/iter=0.3045
# Slot 0: 0 (no events), 1 (662 events): MAR=9.12+-3.87, HITS_10=0.518+-0.356, Com (662 events): MAR=9.12+-3.87, HITS_10=0.518+-0.356
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.12+-3.87	 HITS_10=0.518+-0.356
# ====== Com       	 (662     events): 	MAR=9.12+-3.87	 HITS_10=0.518+-0.356
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4789473684210527, Test Loss: 363.92138671875
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# ...
# ====== 1         	 (662     events): 	MAR=8.99+-4.09	 HITS_10=0.528+-0.374
# ====== Com       	 (662     events): 	MAR=8.99+-4.09	 HITS_10=0.528+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8436842105263158, Test Loss: 587.5280389785767
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=618.767, psi=[0.5024577975273132, 0.49765312671661377], loss1 min/max=0.4704/0.4750, loss2 min/max=0.0940/0.2053, integral time stamps=5000, sec/iter=0.3102
# Slot 0: 0 (no events), 1 (662 events): MAR=8.97+-4.11, HITS_10=0.532+-0.374, Com (662 events): MAR=8.97+-4.11, HITS_10=0.532+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.97+-4.11	 HITS_10=0.532+-0.374
# ====== Com       	 (662     events): 	MAR=8.97+-4.11	 HITS_10=0.532+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8436842105263158, Test Loss: 593.7758445739746
# Testing decay_rate: 0.8957894736842106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=412.993, psi=[0.5004521012306213, 0.49872642755508423], loss1 min/max=0.8389/0.8504, loss2 min/max=0.0628/0.1710, integral time stamps=5000, sec/iter=0.3079
# Slot 0: 0 (no events), 1 (662 events): MAR=9.22+-4.03, HITS_10=0.512+-0.359, Com (662 events): MAR=9.22+-4.03, HITS_10=0.512+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.22+-4.03	 HITS_10=0.512+-0.359
# ====== Com       	 (662     events): 	MAR=9.22+-4.03	 HITS_10=0.512+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.8957894736842106, Test Loss: 412.99271392822266
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=408.152, psi=[0.5009880661964417, 0.4973767101764679], loss1 min/max=0.7487/0.7583, loss2 min/max=0.0669/0.1521, integral time stamps=5000, sec/iter=0.3100
# Slot 0: 0 (no events), 1 (662 events): MAR=9.21+-4.06, HITS_10=0.511+-0.361, Com (662 events): MAR=9.21+-4.06, HITS_10=0.511+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.21+-4.06	 HITS_10=0.511+-0.361
# ====== Com       	 (662     events): 	MAR=9.21+-4.06	 HITS_10=0.511+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.8957894736842106, Test Loss: 410.5723075866699
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=407.556, psi=[0.5015420317649841, 0.49606773257255554], loss1 min/max=0.6737/0.6823, loss2 min/max=0.0710/0.1367, integral time stamps=5000, sec/iter=0.3090
# Slot 0: 0 (no events), 1 (662 events): MAR=9.23+-4.06, HITS_10=0.508+-0.362, Com (662 events): MAR=9.23+-4.06, HITS_10=0.508+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.23+-4.06	 HITS_10=0.508+-0.362
# ====== Com       	 (662     events): 	MAR=9.23+-4.06	 HITS_10=0.508+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.8957894736842106, Test Loss: 409.5667673746745
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=410.421, psi=[0.502093493938446, 0.4948776066303253], loss1 min/max=0.6135/0.6211, loss2 min/max=0.0755/0.1245, integral time stamps=5000, sec/iter=0.3147
# Slot 0: 0 (no events), 1 (662 events): MAR=9.23+-4.05, HITS_10=0.516+-0.365, Com (662 events): MAR=9.23+-4.05, HITS_10=0.516+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.23+-4.05	 HITS_10=0.516+-0.365
# ====== Com       	 (662     events): 	MAR=9.23+-4.05	 HITS_10=0.516+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8957894736842106, Test Loss: 409.78029441833496
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=415.885, psi=[0.5026347637176514, 0.49385005235671997], loss1 min/max=0.5667/0.5736, loss2 min/max=0.0804/0.1150, integral time stamps=5000, sec/iter=0.3097
# Slot 0: 0 (no events), 1 (662 events): MAR=9.24+-4.05, HITS_10=0.510+-0.366, Com (662 events): MAR=9.24+-4.05, HITS_10=0.510+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.24+-4.05	 HITS_10=0.510+-0.366
# ====== Com       	 (662     events): 	MAR=9.24+-4.05	 HITS_10=0.510+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8957894736842106, Test Loss: 411.00122528076173
# Testing decay_rate: 0.9478947368421053
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=297.041, psi=[0.5004618167877197, 0.4990074336528778], loss1 min/max=0.5889/0.5974, loss2 min/max=0.0086/0.1202, integral time stamps=5000, sec/iter=0.3108
# Slot 0: 0 (no events), 1 (662 events): MAR=9.27+-4.00, HITS_10=0.492+-0.371, Com (662 events): MAR=9.27+-4.00, HITS_10=0.492+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.27+-4.00	 HITS_10=0.492+-0.371
# ====== Com       	 (662     events): 	MAR=9.27+-4.00	 HITS_10=0.492+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.9478947368421053, Test Loss: 297.0408744812012
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=296.311, psi=[0.5010214447975159, 0.4981171786785126], loss1 min/max=0.5410/0.5493, loss2 min/max=0.0093/0.1109, integral time stamps=5000, sec/iter=0.3122
# Slot 0: 0 (no events), 1 (662 events): MAR=9.31+-3.99, HITS_10=0.492+-0.373, Com (662 events): MAR=9.31+-3.99, HITS_10=0.492+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.31+-3.99	 HITS_10=0.492+-0.373
# ====== Com       	 (662     events): 	MAR=9.31+-3.99	 HITS_10=0.492+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.9478947368421053, Test Loss: 296.67569732666016
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=297.177, psi=[0.5016016364097595, 0.49741244316101074], loss1 min/max=0.5097/0.5177, loss2 min/max=0.0101/0.1042, integral time stamps=5000, sec/iter=0.3403
# Slot 0: 0 (no events), 1 (662 events): MAR=9.32+-3.98, HITS_10=0.490+-0.372, Com (662 events): MAR=9.32+-3.98, HITS_10=0.490+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.32+-3.98	 HITS_10=0.490+-0.372
# ====== Com       	 (662     events): 	MAR=9.32+-3.98	 HITS_10=0.490+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.9478947368421053, Test Loss: 296.8428039550781
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=298.843, psi=[0.5021841526031494, 0.49687981605529785], loss1 min/max=0.4900/0.4984, loss2 min/max=0.0111/0.1006, integral time stamps=5000, sec/iter=0.3055
# Slot 0: 0 (no events), 1 (662 events): MAR=9.31+-3.96, HITS_10=0.492+-0.369, Com (662 events): MAR=9.31+-3.96, HITS_10=0.492+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.31+-3.96	 HITS_10=0.492+-0.369
# ====== Com       	 (662     events): 	MAR=9.31+-3.96	 HITS_10=0.492+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.9478947368421053, Test Loss: 297.34274768829346
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=300.909, psi=[0.5027620196342468, 0.49647340178489685], loss1 min/max=0.4783/0.4872, loss2 min/max=0.0123/0.0984, integral time stamps=5000, sec/iter=0.3092
# Slot 0: 0 (no events), 1 (662 events): MAR=9.31+-3.97, HITS_10=0.492+-0.371, Com (662 events): MAR=9.31+-3.97, HITS_10=0.492+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=9.31+-3.97	 HITS_10=0.492+-0.371
# ====== Com       	 (662     events): 	MAR=9.31+-3.97	 HITS_10=0.492+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.9478947368421053, Test Loss: 298.05599212646484
# Testing decay_rate: 1.0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=509.356, psi=[0.5004401206970215, 0.4985176622867584], loss1 min/max=1.1003/1.1237, loss2 min/max=0.0944/0.2248, integral time stamps=5000, sec/iter=0.3051
# Slot 0: 0 (no events), 1 (662 events): MAR=8.89+-4.47, HITS_10=0.539+-0.387, Com (662 events): MAR=8.89+-4.47, HITS_10=0.539+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.89+-4.47	 HITS_10=0.539+-0.387
# ====== Com       	 (662     events): 	MAR=8.89+-4.47	 HITS_10=0.539+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 1.0, Test Loss: 509.3562469482422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=492.306, psi=[0.5008856058120728, 0.4969199299812317], loss1 min/max=0.9801/1.0024, loss2 min/max=0.0966/0.2005, integral time stamps=5000, sec/iter=0.3170
# Slot 0: 0 (no events), 1 (662 events): MAR=8.91+-4.45, HITS_10=0.534+-0.385, Com (662 events): MAR=8.91+-4.45, HITS_10=0.534+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.91+-4.45	 HITS_10=0.534+-0.385
# ====== Com       	 (662     events): 	MAR=8.91+-4.45	 HITS_10=0.534+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 1.0, Test Loss: 500.8312225341797
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=480.450, psi=[0.5013809204101562, 0.49529141187667847], loss1 min/max=0.8752/0.8961, loss2 min/max=0.0992/0.1793, integral time stamps=5000, sec/iter=0.3078
# Slot 0: 0 (no events), 1 (662 events): MAR=8.93+-4.45, HITS_10=0.531+-0.387, Com (662 events): MAR=8.93+-4.45, HITS_10=0.531+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.93+-4.45	 HITS_10=0.531+-0.387
# ====== Com       	 (662     events): 	MAR=8.93+-4.45	 HITS_10=0.531+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 1.0, Test Loss: 494.03738530476886
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=473.300, psi=[0.5018957853317261, 0.4936910569667816], loss1 min/max=0.7853/0.8045, loss2 min/max=0.1023/0.1610, integral time stamps=5000, sec/iter=0.3105
# Slot 0: 0 (no events), 1 (662 events): MAR=8.95+-4.46, HITS_10=0.525+-0.388, Com (662 events): MAR=8.95+-4.46, HITS_10=0.525+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.95+-4.46	 HITS_10=0.525+-0.388
# ====== Com       	 (662     events): 	MAR=8.95+-4.46	 HITS_10=0.525+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 1.0, Test Loss: 488.8530397415161
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=470.407, psi=[0.5024166703224182, 0.4921703338623047], loss1 min/max=0.7096/0.7271, loss2 min/max=0.1054/0.1455, integral time stamps=5000, sec/iter=0.3045
# Slot 0: 0 (no events), 1 (662 events): MAR=8.94+-4.43, HITS_10=0.526+-0.387, Com (662 events): MAR=8.94+-4.43, HITS_10=0.526+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.94+-4.43	 HITS_10=0.526+-0.387
# ====== Com       	 (662     events): 	MAR=8.94+-4.43	 HITS_10=0.526+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 1.0, Test Loss: 485.163809967041
# Best decay_rate: 0.9478947368421053 with loss: 298.05599212646484

# %%
decay = 0
best_loss_1 = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.1.csv', decay_rates=[decay], epochs=5)
best_loss_2 = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.2.csv', decay_rates=[decay], epochs=5)
best_loss_3 = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.3.csv', decay_rates=[decay], epochs=5)
best_loss_4 = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.4.csv', decay_rates=[decay], epochs=5)
best_loss_5 = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.5.csv', decay_rates=[decay], epochs=5)
print(f"Best loss for decay rate {decay} with data 0.1: {best_loss_1}")
print(f"Best loss for decay rate {decay} with data 0.2: {best_loss_2}")
print(f"Best loss for decay rate {decay} with data 0.3: {best_loss_3}")
print(f"Best loss for decay rate {decay} with data 0.4: {best_loss_4}")
print(f"Best loss for decay rate {decay} with data 0.5: {best_loss_5}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=390.815, psi=[0.5004507303237915, 0.5012272000312805], loss1 min/max=0.1363/0.1393, loss2 min/max=0.0106/0.0279, integral time stamps=5000, sec/iter=0.3863
# Slot 0: 0 (no events), 1 (662 events): MAR=8.94+-4.37, HITS_10=0.531+-0.389, Com (662 events): MAR=8.94+-4.37, HITS_10=0.531+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.94+-4.37	 HITS_10=0.531+-0.389
# ====== Com       	 (662     events): 	MAR=8.94+-4.37	 HITS_10=0.531+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0, Test Loss: 390.8154525756836
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=370.494, psi=[0.5009487867355347, 0.5025245547294617], loss1 min/max=0.1661/0.1694, loss2 min/max=0.0118/0.0339, integral time stamps=5000, sec/iter=0.3724
# Slot 0: 0 (no events), 1 (662 events): MAR=8.93+-4.38, HITS_10=0.530+-0.388, Com (662 events): MAR=8.93+-4.38, HITS_10=0.530+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.93+-4.38	 HITS_10=0.530+-0.388
# ====== Com       	 (662     events): 	MAR=8.93+-4.38	 HITS_10=0.530+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0, Test Loss: 380.65457916259766
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=354.877, psi=[0.5014803409576416, 0.5036458969116211], loss1 min/max=0.1977/0.2012, loss2 min/max=0.0133/0.0403, integral time stamps=5000, sec/iter=0.2949
# Slot 0: 0 (no events), 1 (662 events): MAR=8.95+-4.38, HITS_10=0.525+-0.388, Com (662 events): MAR=8.95+-4.38, HITS_10=0.525+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.95+-4.38	 HITS_10=0.525+-0.388
# ====== Com       	 (662     events): 	MAR=8.95+-4.38	 HITS_10=0.525+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0, Test Loss: 372.0622151692708
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=343.417, psi=[0.5020201802253723, 0.5045999884605408], loss1 min/max=0.2300/0.2336, loss2 min/max=0.0149/0.0468, integral time stamps=5000, sec/iter=0.2946
# Slot 0: 0 (no events), 1 (662 events): MAR=8.93+-4.39, HITS_10=0.529+-0.386, Com (662 events): MAR=8.93+-4.39, HITS_10=0.529+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.93+-4.39	 HITS_10=0.529+-0.386
# ====== Com       	 (662     events): 	MAR=8.93+-4.39	 HITS_10=0.529+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0, Test Loss: 364.9010353088379
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=335.546, psi=[0.5025591850280762, 0.5053969621658325], loss1 min/max=0.2618/0.2655, loss2 min/max=0.0165/0.0532, integral time stamps=5000, sec/iter=0.2928
# Slot 0: 0 (no events), 1 (662 events): MAR=8.93+-4.35, HITS_10=0.531+-0.389, Com (662 events): MAR=8.93+-4.35, HITS_10=0.531+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (662     events): 	MAR=8.93+-4.35	 HITS_10=0.531+-0.389
# ====== Com       	 (662     events): 	MAR=8.93+-4.35	 HITS_10=0.531+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0, Test Loss: 359.0300296783447
#
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=605.656, psi=[0.500432550907135, 0.5005562901496887], loss1 min/max=0.3971/0.4079, loss2 min/max=0.0793/0.1847, integral time stamps=5000, sec/iter=0.3910
# Slot 0: 0 (no events), 1 (681 events): MAR=9.00+-4.16, HITS_10=0.529+-0.373, Com (681 events): MAR=9.00+-4.16, HITS_10=0.529+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.529+-0.373
# ====== Com       	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.529+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0, Test Loss: 605.6564865112305
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=616.058, psi=[0.5009079575538635, 0.5009859800338745], loss1 min/max=0.4175/0.4276, loss2 min/max=0.0834/0.1918, integral time stamps=5000, sec/iter=0.3907
# Slot 0: 0 (no events), 1 (681 events): MAR=9.03+-4.16, HITS_10=0.523+-0.374, Com (681 events): MAR=9.03+-4.16, HITS_10=0.523+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.03+-4.16	 HITS_10=0.523+-0.374
# ====== Com       	 (681     events): 	MAR=9.03+-4.16	 HITS_10=0.523+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0, Test Loss: 610.8572845458984
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=627.685, psi=[0.5014107823371887, 0.5012391805648804], loss1 min/max=0.4307/0.4407, loss2 min/max=0.0860/0.1990, integral time stamps=5000, sec/iter=0.3245
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-4.17, HITS_10=0.521+-0.375, Com (681 events): MAR=9.04+-4.17, HITS_10=0.521+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-4.17	 HITS_10=0.521+-0.375
# ====== Com       	 (681     events): 	MAR=9.04+-4.17	 HITS_10=0.521+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0, Test Loss: 616.466682434082
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=639.897, psi=[0.5019166469573975, 0.5013763904571533], loss1 min/max=0.4394/0.4495, loss2 min/max=0.0878/0.2066, integral time stamps=5000, sec/iter=0.3049
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-4.16, HITS_10=0.521+-0.374, Com (681 events): MAR=9.04+-4.16, HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-4.16	 HITS_10=0.521+-0.374
# ====== Com       	 (681     events): 	MAR=9.04+-4.16	 HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0, Test Loss: 622.3241386413574
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=652.418, psi=[0.5024168491363525, 0.5014379620552063], loss1 min/max=0.4449/0.4550, loss2 min/max=0.0889/0.2141, integral time stamps=5000, sec/iter=0.3164
# Slot 0: 0 (no events), 1 (681 events): MAR=9.05+-4.17, HITS_10=0.521+-0.374, Com (681 events): MAR=9.05+-4.17, HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.05+-4.17	 HITS_10=0.521+-0.374
# ====== Com       	 (681     events): 	MAR=9.05+-4.17	 HITS_10=0.521+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0, Test Loss: 628.3429000854492
#
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=502.106, psi=[0.5004363059997559, 0.4986416697502136], loss1 min/max=1.3993/1.4159, loss2 min/max=0.0692/0.2838, integral time stamps=5000, sec/iter=0.3674
# Slot 0: 0 (no events), 1 (633 events): MAR=9.10+-4.11, HITS_10=0.509+-0.366, Com (633 events): MAR=9.10+-4.11, HITS_10=0.509+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.10+-4.11	 HITS_10=0.509+-0.366
# ====== Com       	 (633     events): 	MAR=9.10+-4.11	 HITS_10=0.509+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0, Test Loss: 502.10619163513184
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=478.031, psi=[0.5008919835090637, 0.49709609150886536], loss1 min/max=1.2618/1.2783, loss2 min/max=0.0709/0.2563, integral time stamps=5000, sec/iter=0.2990
# Slot 0: 0 (no events), 1 (633 events): MAR=9.06+-4.15, HITS_10=0.514+-0.367, Com (633 events): MAR=9.06+-4.15, HITS_10=0.514+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.06+-4.15	 HITS_10=0.514+-0.367
# ====== Com       	 (633     events): 	MAR=9.06+-4.15	 HITS_10=0.514+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0, Test Loss: 490.06880378723145
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=457.899, psi=[0.5013942718505859, 0.49541589617729187], loss1 min/max=1.1356/1.1514, loss2 min/max=0.0729/0.2309, integral time stamps=5000, sec/iter=0.2984
# Slot 0: 0 (no events), 1 (633 events): MAR=9.01+-4.13, HITS_10=0.521+-0.367, Com (633 events): MAR=9.01+-4.13, HITS_10=0.521+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.01+-4.13	 HITS_10=0.521+-0.367
# ====== Com       	 (633     events): 	MAR=9.01+-4.13	 HITS_10=0.521+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0, Test Loss: 479.34542147318524
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=441.696, psi=[0.5019150972366333, 0.4936666190624237], loss1 min/max=1.0203/1.0352, loss2 min/max=0.0751/0.2076, integral time stamps=5000, sec/iter=0.2829
# Slot 0: 0 (no events), 1 (633 events): MAR=8.99+-4.18, HITS_10=0.524+-0.369, Com (633 events): MAR=8.99+-4.18, HITS_10=0.524+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.99+-4.18	 HITS_10=0.524+-0.369
# ====== Com       	 (633     events): 	MAR=8.99+-4.18	 HITS_10=0.524+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0, Test Loss: 469.93308448791504
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=429.394, psi=[0.5024428963661194, 0.4918982684612274], loss1 min/max=0.9167/0.9309, loss2 min/max=0.0774/0.1866, integral time stamps=5000, sec/iter=0.3105
# Slot 0: 0 (no events), 1 (633 events): MAR=8.97+-4.18, HITS_10=0.536+-0.373, Com (633 events): MAR=8.97+-4.18, HITS_10=0.536+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.97+-4.18	 HITS_10=0.536+-0.373
# ====== Com       	 (633     events): 	MAR=8.97+-4.18	 HITS_10=0.536+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0, Test Loss: 461.82520484924316
#
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=540.558, psi=[0.500432014465332, 0.5009716749191284], loss1 min/max=0.2664/0.2771, loss2 min/max=0.0531/0.1709, integral time stamps=5000, sec/iter=0.3774
# Slot 0: 0 (no events), 1 (613 events): MAR=9.08+-4.11, HITS_10=0.527+-0.372, Com (613 events): MAR=9.08+-4.11, HITS_10=0.527+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.08+-4.11	 HITS_10=0.527+-0.372
# ====== Com       	 (613     events): 	MAR=9.08+-4.11	 HITS_10=0.527+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0, Test Loss: 540.5579414367676
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=542.469, psi=[0.5008978843688965, 0.5018969774246216], loss1 min/max=0.3088/0.3202, loss2 min/max=0.0616/0.1782, integral time stamps=5000, sec/iter=0.2751
# Slot 0: 0 (no events), 1 (613 events): MAR=9.08+-4.08, HITS_10=0.525+-0.369, Com (613 events): MAR=9.08+-4.08, HITS_10=0.525+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.08+-4.08	 HITS_10=0.525+-0.369
# ====== Com       	 (613     events): 	MAR=9.08+-4.08	 HITS_10=0.525+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0, Test Loss: 541.5135307312012
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=548.196, psi=[0.5013893842697144, 0.5025846362113953], loss1 min/max=0.3455/0.3574, loss2 min/max=0.0689/0.1857, integral time stamps=5000, sec/iter=0.2722
# Slot 0: 0 (no events), 1 (613 events): MAR=9.08+-4.06, HITS_10=0.523+-0.366, Com (613 events): MAR=9.08+-4.06, HITS_10=0.523+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.08+-4.06	 HITS_10=0.523+-0.366
# ====== Com       	 (613     events): 	MAR=9.08+-4.06	 HITS_10=0.523+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0, Test Loss: 543.7411123911539
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=556.268, psi=[0.501882016658783, 0.5030738115310669], loss1 min/max=0.3754/0.3877, loss2 min/max=0.0748/0.1932, integral time stamps=5000, sec/iter=0.2738
# Slot 0: 0 (no events), 1 (613 events): MAR=9.08+-4.08, HITS_10=0.524+-0.368, Com (613 events): MAR=9.08+-4.08, HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.08+-4.08	 HITS_10=0.524+-0.368
# ====== Com       	 (613     events): 	MAR=9.08+-4.08	 HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0, Test Loss: 546.8729157447815
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=565.691, psi=[0.5023671984672546, 0.5034071207046509], loss1 min/max=0.3981/0.4107, loss2 min/max=0.0795/0.2003, integral time stamps=5000, sec/iter=0.2739
# Slot 0: 0 (no events), 1 (613 events): MAR=9.07+-4.08, HITS_10=0.523+-0.367, Com (613 events): MAR=9.07+-4.08, HITS_10=0.523+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.07+-4.08	 HITS_10=0.523+-0.367
# ====== Com       	 (613     events): 	MAR=9.07+-4.08	 HITS_10=0.523+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0, Test Loss: 550.6365358352662
#
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=447.953, psi=[0.5004450082778931, 0.5008823871612549], loss1 min/max=0.3191/0.3245, loss2 min/max=0.0638/0.0992, integral time stamps=5000, sec/iter=0.2921
# Slot 0: 0 (no events), 1 (648 events): MAR=9.01+-3.96, HITS_10=0.514+-0.369, Com (648 events): MAR=9.01+-3.96, HITS_10=0.514+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.01+-3.96	 HITS_10=0.514+-0.369
# ====== Com       	 (648     events): 	MAR=9.01+-3.96	 HITS_10=0.514+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0, Test Loss: 447.9525909423828
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=449.979, psi=[0.5009657144546509, 0.501699686050415], loss1 min/max=0.3554/0.3604, loss2 min/max=0.0711/0.1038, integral time stamps=5000, sec/iter=0.3011
# Slot 0: 0 (no events), 1 (648 events): MAR=9.01+-3.99, HITS_10=0.518+-0.373, Com (648 events): MAR=9.01+-3.99, HITS_10=0.518+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.01+-3.99	 HITS_10=0.518+-0.373
# ====== Com       	 (648     events): 	MAR=9.01+-3.99	 HITS_10=0.518+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0, Test Loss: 448.96575927734375
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=455.077, psi=[0.5015056729316711, 0.5022786855697632], loss1 min/max=0.3838/0.3887, loss2 min/max=0.0768/0.1088, integral time stamps=5000, sec/iter=0.2969
# Slot 0: 0 (no events), 1 (648 events): MAR=8.99+-4.00, HITS_10=0.525+-0.365, Com (648 events): MAR=8.99+-4.00, HITS_10=0.525+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.99+-4.00	 HITS_10=0.525+-0.365
# ====== Com       	 (648     events): 	MAR=8.99+-4.00	 HITS_10=0.525+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0, Test Loss: 451.0028127034505
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=462.022, psi=[0.5020429491996765, 0.5026723742485046], loss1 min/max=0.4051/0.4097, loss2 min/max=0.0810/0.1142, integral time stamps=5000, sec/iter=0.3491
# Slot 0: 0 (no events), 1 (648 events): MAR=8.96+-4.01, HITS_10=0.526+-0.364, Com (648 events): MAR=8.96+-4.01, HITS_10=0.526+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.96+-4.01	 HITS_10=0.526+-0.364
# ====== Com       	 (648     events): 	MAR=8.96+-4.01	 HITS_10=0.526+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0, Test Loss: 453.7577314376831
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=470.083, psi=[0.5025700330734253, 0.5029298663139343], loss1 min/max=0.4202/0.4248, loss2 min/max=0.0840/0.1198, integral time stamps=5000, sec/iter=0.4061
# Slot 0: 0 (no events), 1 (648 events): MAR=8.95+-4.01, HITS_10=0.528+-0.365, Com (648 events): MAR=8.95+-4.01, HITS_10=0.528+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.95+-4.01	 HITS_10=0.528+-0.365
# ====== Com       	 (648     events): 	MAR=8.95+-4.01	 HITS_10=0.528+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0, Test Loss: 457.0227340698242
# Best loss for decay rate 0 with data 0.1: (0, 359.0300296783447)
# Best loss for decay rate 0 with data 0.2: (0, 628.3429000854492)
# Best loss for decay rate 0 with data 0.3: (0, 461.82520484924316)
# Best loss for decay rate 0 with data 0.4: (0, 550.6365358352662)
# Best loss for decay rate 0 with data 0.5: (0, 457.0227340698242)

# %%
decay_rates = np.linspace(0.01, 1.0, 20)  # Example range of decay rates
best_decay_rate, best_loss = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.2.csv', decay_rates=decay_rates, epochs=5)
print(f"Best decay_rate: {best_decay_rate} with loss: {best_loss}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0.01
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=631.796, psi=[0.5004444122314453, 0.501681387424469], loss1 min/max=0.0474/0.0500, loss2 min/max=0.0095/0.0604, integral time stamps=5000, sec/iter=0.3165
# Slot 0: 0 (no events), 1 (681 events): MAR=8.92+-4.15, HITS_10=0.527+-0.370, Com (681 events): MAR=8.92+-4.15, HITS_10=0.527+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.92+-4.15	 HITS_10=0.527+-0.370
# ====== Com       	 (681     events): 	MAR=8.92+-4.15	 HITS_10=0.527+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.01, Test Loss: 631.7961044311523
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=604.091, psi=[0.5009457468986511, 0.5031250715255737], loss1 min/max=0.0597/0.0630, loss2 min/max=0.0119/0.0646, integral time stamps=5000, sec/iter=0.3142
# Slot 0: 0 (no events), 1 (681 events): MAR=8.95+-4.16, HITS_10=0.525+-0.371, Com (681 events): MAR=8.95+-4.16, HITS_10=0.525+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.95+-4.16	 HITS_10=0.525+-0.371
# ====== Com       	 (681     events): 	MAR=8.95+-4.16	 HITS_10=0.525+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.01, Test Loss: 617.9433059692383
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=579.980, psi=[0.501470685005188, 0.5044596791267395], loss1 min/max=0.0744/0.0784, loss2 min/max=0.0149/0.0694, integral time stamps=5000, sec/iter=0.3109
# Slot 0: 0 (no events), 1 (681 events): MAR=8.95+-4.16, HITS_10=0.525+-0.368, Com (681 events): MAR=8.95+-4.16, HITS_10=0.525+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.95+-4.16	 HITS_10=0.525+-0.368
# ====== Com       	 (681     events): 	MAR=8.95+-4.16	 HITS_10=0.525+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.01, Test Loss: 605.2887268066406
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=559.355, psi=[0.5019955635070801, 0.5056882500648499], loss1 min/max=0.0914/0.0964, loss2 min/max=0.0183/0.0747, integral time stamps=5000, sec/iter=0.3272
# Slot 0: 0 (no events), 1 (681 events): MAR=8.94+-4.13, HITS_10=0.524+-0.368, Com (681 events): MAR=8.94+-4.13, HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.94+-4.13	 HITS_10=0.524+-0.368
# ====== Com       	 (681     events): 	MAR=8.94+-4.13	 HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.01, Test Loss: 593.8052387237549
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=542.223, psi=[0.5025116205215454, 0.5068086385726929], loss1 min/max=0.1108/0.1168, loss2 min/max=0.0221/0.0797, integral time stamps=5000, sec/iter=0.3142
# Slot 0: 0 (no events), 1 (681 events): MAR=8.96+-4.13, HITS_10=0.520+-0.367, Com (681 events): MAR=8.96+-4.13, HITS_10=0.520+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.96+-4.13	 HITS_10=0.520+-0.367
# ====== Com       	 (681     events): 	MAR=8.96+-4.13	 HITS_10=0.520+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.01, Test Loss: 583.4888229370117
# Testing decay_rate: 0.06210526315789474
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=369.121, psi=[0.5004348754882812, 0.500705361366272], loss1 min/max=0.4047/0.4162, loss2 min/max=0.0444/0.0832, integral time stamps=5000, sec/iter=0.3131
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-4.10, HITS_10=0.518+-0.375, Com (681 events): MAR=9.04+-4.10, HITS_10=0.518+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-4.10	 HITS_10=0.518+-0.375
# ====== Com       	 (681     events): 	MAR=9.04+-4.10	 HITS_10=0.518+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.06210526315789474, Test Loss: 369.12075424194336
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=373.542, psi=[0.5008281469345093, 0.5010474324226379], loss1 min/max=0.4338/0.4438, loss2 min/max=0.0478/0.0892, integral time stamps=5000, sec/iter=0.3136
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-4.11, HITS_10=0.519+-0.377, Com (681 events): MAR=9.07+-4.11, HITS_10=0.519+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-4.11	 HITS_10=0.519+-0.377
# ====== Com       	 (681     events): 	MAR=9.07+-4.11	 HITS_10=0.519+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.06210526315789474, Test Loss: 371.3315181732178
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=379.120, psi=[0.5012686848640442, 0.5011487603187561], loss1 min/max=0.4494/0.4590, loss2 min/max=0.0514/0.0923, integral time stamps=5000, sec/iter=0.3114
# Slot 0: 0 (no events), 1 (681 events): MAR=9.08+-4.11, HITS_10=0.518+-0.376, Com (681 events): MAR=9.08+-4.11, HITS_10=0.518+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.08+-4.11	 HITS_10=0.518+-0.376
# ====== Com       	 (681     events): 	MAR=9.08+-4.11	 HITS_10=0.518+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.06210526315789474, Test Loss: 373.92761484781903
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=385.197, psi=[0.5017273426055908, 0.5011214017868042], loss1 min/max=0.4574/0.4668, loss2 min/max=0.0551/0.0938, integral time stamps=5000, sec/iter=0.3129
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-4.12, HITS_10=0.519+-0.377, Com (681 events): MAR=9.07+-4.12, HITS_10=0.519+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-4.12	 HITS_10=0.519+-0.377
# ====== Com       	 (681     events): 	MAR=9.07+-4.12	 HITS_10=0.519+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.06210526315789474, Test Loss: 376.7450180053711
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=391.583, psi=[0.5021915435791016, 0.5010262131690979], loss1 min/max=0.4614/0.4709, loss2 min/max=0.0589/0.0947, integral time stamps=5000, sec/iter=0.3119
# Slot 0: 0 (no events), 1 (681 events): MAR=9.06+-4.12, HITS_10=0.520+-0.377, Com (681 events): MAR=9.06+-4.12, HITS_10=0.520+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.06+-4.12	 HITS_10=0.520+-0.377
# ====== Com       	 (681     events): 	MAR=9.06+-4.12	 HITS_10=0.520+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.06210526315789474, Test Loss: 379.71260299682615
# Testing decay_rate: 0.11421052631578947
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=610.676, psi=[0.5004448294639587, 0.5016757249832153], loss1 min/max=0.0774/0.0808, loss2 min/max=0.0154/0.0901, integral time stamps=5000, sec/iter=0.3123
# Slot 0: 0 (no events), 1 (681 events): MAR=9.13+-4.34, HITS_10=0.515+-0.387, Com (681 events): MAR=9.13+-4.34, HITS_10=0.515+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.13+-4.34	 HITS_10=0.515+-0.387
# ====== Com       	 (681     events): 	MAR=9.13+-4.34	 HITS_10=0.515+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.11421052631578947, Test Loss: 610.6757888793945
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=582.269, psi=[0.5009471774101257, 0.5030532479286194], loss1 min/max=0.1004/0.1045, loss2 min/max=0.0200/0.0945, integral time stamps=5000, sec/iter=0.3124
# Slot 0: 0 (no events), 1 (681 events): MAR=9.09+-4.37, HITS_10=0.526+-0.389, Com (681 events): MAR=9.09+-4.37, HITS_10=0.526+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.09+-4.37	 HITS_10=0.526+-0.389
# ====== Com       	 (681     events): 	MAR=9.09+-4.37	 HITS_10=0.526+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.11421052631578947, Test Loss: 596.4722900390625
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=559.953, psi=[0.5014742016792297, 0.5042721033096313], loss1 min/max=0.1269/0.1316, loss2 min/max=0.0252/0.0993, integral time stamps=5000, sec/iter=0.3205
# Slot 0: 0 (no events), 1 (681 events): MAR=9.10+-4.39, HITS_10=0.522+-0.387, Com (681 events): MAR=9.10+-4.39, HITS_10=0.522+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.10+-4.39	 HITS_10=0.522+-0.387
# ====== Com       	 (681     events): 	MAR=9.10+-4.39	 HITS_10=0.522+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.11421052631578947, Test Loss: 584.299196879069
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=543.242, psi=[0.5020024180412292, 0.5053368210792542], loss1 min/max=0.1562/0.1616, loss2 min/max=0.0311/0.1041, integral time stamps=5000, sec/iter=0.3109
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.39, HITS_10=0.518+-0.388, Com (681 events): MAR=9.11+-4.39, HITS_10=0.518+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.39	 HITS_10=0.518+-0.388
# ====== Com       	 (681     events): 	MAR=9.11+-4.39	 HITS_10=0.518+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.11421052631578947, Test Loss: 574.0348949432373
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=531.703, psi=[0.50252366065979, 0.5062514543533325], loss1 min/max=0.1875/0.1934, loss2 min/max=0.0373/0.1091, integral time stamps=5000, sec/iter=0.3119
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.39, HITS_10=0.518+-0.389, Com (681 events): MAR=9.11+-4.39, HITS_10=0.518+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.39	 HITS_10=0.518+-0.389
# ====== Com       	 (681     events): 	MAR=9.11+-4.39	 HITS_10=0.518+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.11421052631578947, Test Loss: 565.5685470581054
# Testing decay_rate: 0.16631578947368422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=498.879, psi=[0.5004526972770691, 0.501168429851532], loss1 min/max=0.1869/0.1909, loss2 min/max=0.0373/0.0944, integral time stamps=5000, sec/iter=0.3119
# Slot 0: 0 (no events), 1 (681 events): MAR=9.13+-4.43, HITS_10=0.520+-0.388, Com (681 events): MAR=9.13+-4.43, HITS_10=0.520+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.13+-4.43	 HITS_10=0.520+-0.388
# ====== Com       	 (681     events): 	MAR=9.13+-4.43	 HITS_10=0.520+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.16631578947368422, Test Loss: 498.87864685058594
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=489.588, psi=[0.5010195970535278, 0.5023887753486633], loss1 min/max=0.2243/0.2283, loss2 min/max=0.0448/0.0987, integral time stamps=5000, sec/iter=0.3113
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.42, HITS_10=0.522+-0.385, Com (681 events): MAR=9.11+-4.42, HITS_10=0.522+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.42	 HITS_10=0.522+-0.385
# ====== Com       	 (681     events): 	MAR=9.11+-4.42	 HITS_10=0.522+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.16631578947368422, Test Loss: 494.23321533203125
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=485.613, psi=[0.5015875101089478, 0.5033924579620361], loss1 min/max=0.2610/0.2650, loss2 min/max=0.0521/0.1041, integral time stamps=5000, sec/iter=0.3176
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-4.42, HITS_10=0.521+-0.385, Com (681 events): MAR=9.12+-4.42, HITS_10=0.521+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-4.42	 HITS_10=0.521+-0.385
# ====== Com       	 (681     events): 	MAR=9.12+-4.42	 HITS_10=0.521+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.16631578947368422, Test Loss: 491.35985056559247
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=485.834, psi=[0.502143919467926, 0.504202663898468], loss1 min/max=0.2956/0.2996, loss2 min/max=0.0590/0.1106, integral time stamps=5000, sec/iter=0.3122
# Slot 0: 0 (no events), 1 (681 events): MAR=9.13+-4.43, HITS_10=0.516+-0.383, Com (681 events): MAR=9.13+-4.43, HITS_10=0.516+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.13+-4.43	 HITS_10=0.516+-0.383
# ====== Com       	 (681     events): 	MAR=9.13+-4.43	 HITS_10=0.516+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.16631578947368422, Test Loss: 489.9784336090088
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=489.270, psi=[0.5026851892471313, 0.5048426985740662], loss1 min/max=0.3269/0.3306, loss2 min/max=0.0653/0.1155, integral time stamps=5000, sec/iter=0.3210
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-4.44, HITS_10=0.518+-0.382, Com (681 events): MAR=9.12+-4.44, HITS_10=0.518+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-4.44	 HITS_10=0.518+-0.382
# ====== Com       	 (681     events): 	MAR=9.12+-4.44	 HITS_10=0.518+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.16631578947368422, Test Loss: 489.8367034912109
# Testing decay_rate: 0.21842105263157896
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=613.805, psi=[0.5004315972328186, 0.5011326670646667], loss1 min/max=0.2604/0.2711, loss2 min/max=0.0520/0.1761, integral time stamps=5000, sec/iter=0.3136
# Slot 0: 0 (no events), 1 (681 events): MAR=8.98+-4.02, HITS_10=0.521+-0.369, Com (681 events): MAR=8.98+-4.02, HITS_10=0.521+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.98+-4.02	 HITS_10=0.521+-0.369
# ====== Com       	 (681     events): 	MAR=8.98+-4.02	 HITS_10=0.521+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.21842105263157896, Test Loss: 613.8047332763672
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=611.125, psi=[0.5008793473243713, 0.5021907091140747], loss1 min/max=0.3015/0.3128, loss2 min/max=0.0602/0.1806, integral time stamps=5000, sec/iter=0.3149
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-4.01, HITS_10=0.518+-0.368, Com (681 events): MAR=9.04+-4.01, HITS_10=0.518+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-4.01	 HITS_10=0.518+-0.368
# ====== Com       	 (681     events): 	MAR=9.04+-4.01	 HITS_10=0.518+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.21842105263157896, Test Loss: 612.4650115966797
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=614.046, psi=[0.5013678073883057, 0.5029951333999634], loss1 min/max=0.3371/0.3488, loss2 min/max=0.0673/0.1860, integral time stamps=5000, sec/iter=0.3121
# Slot 0: 0 (no events), 1 (681 events): MAR=9.05+-4.02, HITS_10=0.515+-0.368, Com (681 events): MAR=9.05+-4.02, HITS_10=0.515+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.05+-4.02	 HITS_10=0.515+-0.368
# ====== Com       	 (681     events): 	MAR=9.05+-4.02	 HITS_10=0.515+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.21842105263157896, Test Loss: 612.9921010335287
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=620.733, psi=[0.5018665194511414, 0.5035927891731262], loss1 min/max=0.3664/0.3782, loss2 min/max=0.0731/0.1922, integral time stamps=5000, sec/iter=0.3140
# Slot 0: 0 (no events), 1 (681 events): MAR=9.06+-4.02, HITS_10=0.511+-0.370, Com (681 events): MAR=9.06+-4.02, HITS_10=0.511+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.06+-4.02	 HITS_10=0.511+-0.370
# ====== Com       	 (681     events): 	MAR=9.06+-4.02	 HITS_10=0.511+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.21842105263157896, Test Loss: 614.9273166656494
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=629.895, psi=[0.5023629069328308, 0.5040280222892761], loss1 min/max=0.3892/0.4012, loss2 min/max=0.0777/0.1990, integral time stamps=5000, sec/iter=0.3139
# Slot 0: 0 (no events), 1 (681 events): MAR=9.06+-4.03, HITS_10=0.512+-0.371, Com (681 events): MAR=9.06+-4.03, HITS_10=0.512+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.06+-4.03	 HITS_10=0.512+-0.371
# ====== Com       	 (681     events): 	MAR=9.06+-4.03	 HITS_10=0.512+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.21842105263157896, Test Loss: 617.9207626342774
# Testing decay_rate: 0.2705263157894737
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=713.204, psi=[0.5004435777664185, 0.5016761422157288], loss1 min/max=0.0719/0.0741, loss2 min/max=0.0144/0.1437, integral time stamps=5000, sec/iter=0.3161
# Slot 0: 0 (no events), 1 (681 events): MAR=9.00+-4.16, HITS_10=0.514+-0.368, Com (681 events): MAR=9.00+-4.16, HITS_10=0.514+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.514+-0.368
# ====== Com       	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.514+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.2705263157894737, Test Loss: 713.2041091918945
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=686.787, psi=[0.5009836554527283, 0.5030772686004639], loss1 min/max=0.0912/0.0940, loss2 min/max=0.0182/0.1480, integral time stamps=5000, sec/iter=0.3289
# Slot 0: 0 (no events), 1 (681 events): MAR=8.98+-4.14, HITS_10=0.514+-0.372, Com (681 events): MAR=8.98+-4.14, HITS_10=0.514+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.98+-4.14	 HITS_10=0.514+-0.372
# ====== Com       	 (681     events): 	MAR=8.98+-4.14	 HITS_10=0.514+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.2705263157894737, Test Loss: 699.995662689209
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=665.367, psi=[0.5015391111373901, 0.5043387413024902], loss1 min/max=0.1134/0.1168, loss2 min/max=0.0227/0.1525, integral time stamps=5000, sec/iter=0.3421
# Slot 0: 0 (no events), 1 (681 events): MAR=9.00+-4.15, HITS_10=0.512+-0.370, Com (681 events): MAR=9.00+-4.15, HITS_10=0.512+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.00+-4.15	 HITS_10=0.512+-0.370
# ====== Com       	 (681     events): 	MAR=9.00+-4.15	 HITS_10=0.512+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.2705263157894737, Test Loss: 688.4528249104818
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=648.593, psi=[0.5020926594734192, 0.505464494228363], loss1 min/max=0.1382/0.1423, loss2 min/max=0.0276/0.1574, integral time stamps=5000, sec/iter=0.3159
# Slot 0: 0 (no events), 1 (681 events): MAR=8.99+-4.13, HITS_10=0.518+-0.367, Com (681 events): MAR=8.99+-4.13, HITS_10=0.518+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.99+-4.13	 HITS_10=0.518+-0.367
# ====== Com       	 (681     events): 	MAR=8.99+-4.13	 HITS_10=0.518+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.2705263157894737, Test Loss: 678.4878978729248
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=636.306, psi=[0.5026386380195618, 0.5064553618431091], loss1 min/max=0.1652/0.1699, loss2 min/max=0.0330/0.1624, integral time stamps=5000, sec/iter=0.3156
# Slot 0: 0 (no events), 1 (681 events): MAR=9.00+-4.16, HITS_10=0.518+-0.375, Com (681 events): MAR=9.00+-4.16, HITS_10=0.518+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.518+-0.375
# ====== Com       	 (681     events): 	MAR=9.00+-4.16	 HITS_10=0.518+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.2705263157894737, Test Loss: 670.0514312744141
# Testing decay_rate: 0.32263157894736844
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=361.537, psi=[0.5004451274871826, 0.5009114742279053], loss1 min/max=0.3140/0.3183, loss2 min/max=0.0330/0.0637, integral time stamps=5000, sec/iter=0.3212
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-4.13, HITS_10=0.523+-0.379, Com (681 events): MAR=9.07+-4.13, HITS_10=0.523+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-4.13	 HITS_10=0.523+-0.379
# ====== Com       	 (681     events): 	MAR=9.07+-4.13	 HITS_10=0.523+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.32263157894736844, Test Loss: 361.53669357299805
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=359.798, psi=[0.500935971736908, 0.501800000667572], loss1 min/max=0.3495/0.3533, loss2 min/max=0.0353/0.0707, integral time stamps=5000, sec/iter=0.3122
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-4.05, HITS_10=0.530+-0.368, Com (681 events): MAR=9.07+-4.05, HITS_10=0.530+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-4.05	 HITS_10=0.530+-0.368
# ====== Com       	 (681     events): 	MAR=9.07+-4.05	 HITS_10=0.530+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.32263157894736844, Test Loss: 360.6675109863281
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=361.046, psi=[0.5014600157737732, 0.5024504065513611], loss1 min/max=0.3779/0.3813, loss2 min/max=0.0380/0.0763, integral time stamps=5000, sec/iter=0.3234
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-3.98, HITS_10=0.532+-0.368, Com (681 events): MAR=9.04+-3.98, HITS_10=0.532+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-3.98	 HITS_10=0.532+-0.368
# ====== Com       	 (681     events): 	MAR=9.04+-3.98	 HITS_10=0.532+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.32263157894736844, Test Loss: 360.7937609354655
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=364.240, psi=[0.501990556716919, 0.5029131770133972], loss1 min/max=0.3996/0.4028, loss2 min/max=0.0410/0.0806, integral time stamps=5000, sec/iter=0.3038
# Slot 0: 0 (no events), 1 (681 events): MAR=8.99+-3.98, HITS_10=0.532+-0.369, Com (681 events): MAR=8.99+-3.98, HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.99+-3.98	 HITS_10=0.532+-0.369
# ====== Com       	 (681     events): 	MAR=8.99+-3.98	 HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.32263157894736844, Test Loss: 361.6553249359131
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=368.731, psi=[0.5025173425674438, 0.5032340884208679], loss1 min/max=0.4156/0.4186, loss2 min/max=0.0442/0.0838, integral time stamps=5000, sec/iter=0.3195
# Slot 0: 0 (no events), 1 (681 events): MAR=8.98+-3.99, HITS_10=0.528+-0.366, Com (681 events): MAR=8.98+-3.99, HITS_10=0.528+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.98+-3.99	 HITS_10=0.528+-0.366
# ====== Com       	 (681     events): 	MAR=8.98+-3.99	 HITS_10=0.528+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.32263157894736844, Test Loss: 363.07044525146483
# Testing decay_rate: 0.37473684210526315
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=560.535, psi=[0.5004482269287109, 0.501684308052063], loss1 min/max=0.0464/0.0483, loss2 min/max=0.0092/0.0158, integral time stamps=5000, sec/iter=0.3099
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.48, HITS_10=0.517+-0.393, Com (681 events): MAR=9.11+-4.48, HITS_10=0.517+-0.393
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.48	 HITS_10=0.517+-0.393
# ====== Com       	 (681     events): 	MAR=9.11+-4.48	 HITS_10=0.517+-0.393
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.37473684210526315, Test Loss: 560.5353240966797
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=523.972, psi=[0.5009592771530151, 0.5031153559684753], loss1 min/max=0.0603/0.0626, loss2 min/max=0.0120/0.0174, integral time stamps=5000, sec/iter=0.3123
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.55, HITS_10=0.516+-0.393, Com (681 events): MAR=9.11+-4.55, HITS_10=0.516+-0.393
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.55	 HITS_10=0.516+-0.393
# ====== Com       	 (681     events): 	MAR=9.11+-4.55	 HITS_10=0.516+-0.393
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.37473684210526315, Test Loss: 542.2537384033203
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=491.968, psi=[0.5014980435371399, 0.5044270753860474], loss1 min/max=0.0767/0.0796, loss2 min/max=0.0153/0.0193, integral time stamps=5000, sec/iter=0.3091
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-4.59, HITS_10=0.518+-0.391, Com (681 events): MAR=9.07+-4.59, HITS_10=0.518+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-4.59	 HITS_10=0.518+-0.391
# ====== Com       	 (681     events): 	MAR=9.07+-4.59	 HITS_10=0.518+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.37473684210526315, Test Loss: 525.4917246500651
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=464.319, psi=[0.5020418763160706, 0.5056231021881104], loss1 min/max=0.0957/0.0992, loss2 min/max=0.0191/0.0212, integral time stamps=5000, sec/iter=0.3102
# Slot 0: 0 (no events), 1 (681 events): MAR=9.10+-4.60, HITS_10=0.515+-0.394, Com (681 events): MAR=9.10+-4.60, HITS_10=0.515+-0.394
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.10+-4.60	 HITS_10=0.515+-0.394
# ====== Com       	 (681     events): 	MAR=9.10+-4.60	 HITS_10=0.515+-0.394
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.37473684210526315, Test Loss: 510.198543548584
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=440.962, psi=[0.5025825500488281, 0.5067024230957031], loss1 min/max=0.1172/0.1213, loss2 min/max=0.0230/0.0243, integral time stamps=5000, sec/iter=0.3103
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.62, HITS_10=0.513+-0.395, Com (681 events): MAR=9.11+-4.62, HITS_10=0.513+-0.395
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.62	 HITS_10=0.513+-0.395
# ====== Com       	 (681     events): 	MAR=9.11+-4.62	 HITS_10=0.513+-0.395
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.37473684210526315, Test Loss: 496.35116348266604
# Testing decay_rate: 0.4268421052631579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=435.485, psi=[0.500441312789917, 0.4997108280658722], loss1 min/max=0.4891/0.4958, loss2 min/max=0.0840/0.0992, integral time stamps=5000, sec/iter=0.3082
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-4.00, HITS_10=0.526+-0.366, Com (681 events): MAR=9.12+-4.00, HITS_10=0.526+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-4.00	 HITS_10=0.526+-0.366
# ====== Com       	 (681     events): 	MAR=9.12+-4.00	 HITS_10=0.526+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4268421052631579, Test Loss: 435.48499298095703
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=444.515, psi=[0.5009112358093262, 0.4994179606437683], loss1 min/max=0.4773/0.4830, loss2 min/max=0.0891/0.0967, integral time stamps=5000, sec/iter=0.3111
# Slot 0: 0 (no events), 1 (681 events): MAR=9.13+-3.98, HITS_10=0.526+-0.367, Com (681 events): MAR=9.13+-3.98, HITS_10=0.526+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.13+-3.98	 HITS_10=0.526+-0.367
# ====== Com       	 (681     events): 	MAR=9.13+-3.98	 HITS_10=0.526+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4268421052631579, Test Loss: 440.0000247955322
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=454.582, psi=[0.501410961151123, 0.49918466806411743], loss1 min/max=0.4706/0.4765, loss2 min/max=0.0941/0.0983, integral time stamps=5000, sec/iter=0.3113
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-3.98, HITS_10=0.526+-0.367, Com (681 events): MAR=9.12+-3.98, HITS_10=0.526+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-3.98	 HITS_10=0.526+-0.367
# ====== Com       	 (681     events): 	MAR=9.12+-3.98	 HITS_10=0.526+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4268421052631579, Test Loss: 444.86064529418945
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=465.173, psi=[0.501912534236908, 0.4989931881427765], loss1 min/max=0.4670/0.4729, loss2 min/max=0.0934/0.1046, integral time stamps=5000, sec/iter=0.3331
# Slot 0: 0 (no events), 1 (681 events): MAR=9.10+-3.96, HITS_10=0.527+-0.367, Com (681 events): MAR=9.10+-3.96, HITS_10=0.527+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.10+-3.96	 HITS_10=0.527+-0.367
# ====== Com       	 (681     events): 	MAR=9.10+-3.96	 HITS_10=0.527+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.4268421052631579, Test Loss: 449.938796043396
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=476.117, psi=[0.5024057030677795, 0.49882522225379944], loss1 min/max=0.4649/0.4709, loss2 min/max=0.0929/0.1110, integral time stamps=5000, sec/iter=0.3108
# Slot 0: 0 (no events), 1 (681 events): MAR=9.07+-3.98, HITS_10=0.532+-0.369, Com (681 events): MAR=9.07+-3.98, HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.07+-3.98	 HITS_10=0.532+-0.369
# ====== Com       	 (681     events): 	MAR=9.07+-3.98	 HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.4268421052631579, Test Loss: 455.1743766784668
# Testing decay_rate: 0.4789473684210527
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=359.346, psi=[0.5004427433013916, 0.49878832697868347], loss1 min/max=0.7995/0.8122, loss2 min/max=0.0286/0.1626, integral time stamps=5000, sec/iter=0.3131
# Slot 0: 0 (no events), 1 (681 events): MAR=9.02+-4.01, HITS_10=0.526+-0.368, Com (681 events): MAR=9.02+-4.01, HITS_10=0.526+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.02+-4.01	 HITS_10=0.526+-0.368
# ====== Com       	 (681     events): 	MAR=9.02+-4.01	 HITS_10=0.526+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4789473684210527, Test Loss: 359.345947265625
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=350.772, psi=[0.5009251832962036, 0.4975103735923767], loss1 min/max=0.7087/0.7179, loss2 min/max=0.0297/0.1437, integral time stamps=5000, sec/iter=0.3099
# Slot 0: 0 (no events), 1 (681 events): MAR=9.03+-3.99, HITS_10=0.533+-0.369, Com (681 events): MAR=9.03+-3.99, HITS_10=0.533+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.03+-3.99	 HITS_10=0.533+-0.369
# ====== Com       	 (681     events): 	MAR=9.03+-3.99	 HITS_10=0.533+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4789473684210527, Test Loss: 355.0589370727539
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=346.832, psi=[0.5014504194259644, 0.4962921440601349], loss1 min/max=0.6372/0.6441, loss2 min/max=0.0310/0.1290, integral time stamps=5000, sec/iter=0.3108
# Slot 0: 0 (no events), 1 (681 events): MAR=9.04+-3.99, HITS_10=0.527+-0.366, Com (681 events): MAR=9.04+-3.99, HITS_10=0.527+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.04+-3.99	 HITS_10=0.527+-0.366
# ====== Com       	 (681     events): 	MAR=9.04+-3.99	 HITS_10=0.527+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4789473684210527, Test Loss: 352.3167419433594
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# ...
# ====== 1         	 (681     events): 	MAR=9.12+-4.59	 HITS_10=0.521+-0.398
# ====== Com       	 (681     events): 	MAR=9.12+-4.59	 HITS_10=0.521+-0.398
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8436842105263158, Test Loss: 377.86912631988525
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=379.862, psi=[0.5027413964271545, 0.5041086077690125], loss1 min/max=0.3799/0.3921, loss2 min/max=0.0500/0.0785, integral time stamps=5000, sec/iter=0.3117
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-4.60, HITS_10=0.521+-0.398, Com (681 events): MAR=9.12+-4.60, HITS_10=0.521+-0.398
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-4.60	 HITS_10=0.521+-0.398
# ====== Com       	 (681     events): 	MAR=9.12+-4.60	 HITS_10=0.521+-0.398
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8436842105263158, Test Loss: 378.26763076782225
# Testing decay_rate: 0.8957894736842106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=517.152, psi=[0.5004367828369141, 0.5016771554946899], loss1 min/max=0.0731/0.0758, loss2 min/max=0.0145/0.0302, integral time stamps=5000, sec/iter=0.3110
# Slot 0: 0 (no events), 1 (681 events): MAR=9.18+-4.24, HITS_10=0.512+-0.376, Com (681 events): MAR=9.18+-4.24, HITS_10=0.512+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.18+-4.24	 HITS_10=0.512+-0.376
# ====== Com       	 (681     events): 	MAR=9.18+-4.24	 HITS_10=0.512+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.8957894736842106, Test Loss: 517.1518325805664
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=488.436, psi=[0.5008718371391296, 0.5030816197395325], loss1 min/max=0.0915/0.0949, loss2 min/max=0.0183/0.0320, integral time stamps=5000, sec/iter=0.3126
# Slot 0: 0 (no events), 1 (681 events): MAR=9.18+-4.31, HITS_10=0.519+-0.379, Com (681 events): MAR=9.18+-4.31, HITS_10=0.519+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.18+-4.31	 HITS_10=0.519+-0.379
# ====== Com       	 (681     events): 	MAR=9.18+-4.31	 HITS_10=0.519+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.8957894736842106, Test Loss: 502.79398345947266
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=463.945, psi=[0.5013551115989685, 0.5043513178825378], loss1 min/max=0.1127/0.1167, loss2 min/max=0.0225/0.0340, integral time stamps=5000, sec/iter=0.3098
# Slot 0: 0 (no events), 1 (681 events): MAR=9.15+-4.33, HITS_10=0.516+-0.379, Com (681 events): MAR=9.15+-4.33, HITS_10=0.516+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.15+-4.33	 HITS_10=0.516+-0.379
# ====== Com       	 (681     events): 	MAR=9.15+-4.33	 HITS_10=0.516+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.8957894736842106, Test Loss: 489.84448496500653
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=443.557, psi=[0.5018572807312012, 0.5054900646209717], loss1 min/max=0.1364/0.1411, loss2 min/max=0.0271/0.0362, integral time stamps=5000, sec/iter=0.3093
# Slot 0: 0 (no events), 1 (681 events): MAR=9.18+-4.37, HITS_10=0.514+-0.382, Com (681 events): MAR=9.18+-4.37, HITS_10=0.514+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.18+-4.37	 HITS_10=0.514+-0.382
# ====== Com       	 (681     events): 	MAR=9.18+-4.37	 HITS_10=0.514+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8957894736842106, Test Loss: 478.27259731292725
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=427.171, psi=[0.5023660659790039, 0.5064982175827026], loss1 min/max=0.1621/0.1675, loss2 min/max=0.0322/0.0386, integral time stamps=5000, sec/iter=0.3135
# Slot 0: 0 (no events), 1 (681 events): MAR=9.18+-4.41, HITS_10=0.513+-0.383, Com (681 events): MAR=9.18+-4.41, HITS_10=0.513+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.18+-4.41	 HITS_10=0.513+-0.383
# ====== Com       	 (681     events): 	MAR=9.18+-4.41	 HITS_10=0.513+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8957894736842106, Test Loss: 468.05223846435547
# Testing decay_rate: 0.9478947368421053
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=363.783, psi=[0.5004439353942871, 0.49868983030319214], loss1 min/max=0.7525/0.7690, loss2 min/max=0.0340/0.1538, integral time stamps=5000, sec/iter=0.3192
# Slot 0: 0 (no events), 1 (681 events): MAR=9.17+-4.55, HITS_10=0.515+-0.396, Com (681 events): MAR=9.17+-4.55, HITS_10=0.515+-0.396
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.17+-4.55	 HITS_10=0.515+-0.396
# ====== Com       	 (681     events): 	MAR=9.17+-4.55	 HITS_10=0.515+-0.396
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.9478947368421053, Test Loss: 363.78278732299805
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=360.180, psi=[0.5009220242500305, 0.4973532259464264], loss1 min/max=0.6767/0.6908, loss2 min/max=0.0366/0.1383, integral time stamps=5000, sec/iter=0.3143
# Slot 0: 0 (no events), 1 (681 events): MAR=9.15+-4.51, HITS_10=0.520+-0.391, Com (681 events): MAR=9.15+-4.51, HITS_10=0.520+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.15+-4.51	 HITS_10=0.520+-0.391
# ====== Com       	 (681     events): 	MAR=9.15+-4.51	 HITS_10=0.520+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.9478947368421053, Test Loss: 361.98151206970215
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=360.024, psi=[0.5014355778694153, 0.4961215853691101], loss1 min/max=0.6154/0.6279, loss2 min/max=0.0394/0.1257, integral time stamps=5000, sec/iter=0.3090
# Slot 0: 0 (no events), 1 (681 events): MAR=9.12+-4.52, HITS_10=0.523+-0.392, Com (681 events): MAR=9.12+-4.52, HITS_10=0.523+-0.392
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.12+-4.52	 HITS_10=0.523+-0.392
# ====== Com       	 (681     events): 	MAR=9.12+-4.52	 HITS_10=0.523+-0.392
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.9478947368421053, Test Loss: 361.32888158162433
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=362.489, psi=[0.5019579529762268, 0.4950511157512665], loss1 min/max=0.5673/0.5786, loss2 min/max=0.0424/0.1158, integral time stamps=5000, sec/iter=0.3118
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.53, HITS_10=0.520+-0.389, Com (681 events): MAR=9.11+-4.53, HITS_10=0.520+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.53	 HITS_10=0.520+-0.389
# ====== Com       	 (681     events): 	MAR=9.11+-4.53	 HITS_10=0.520+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.9478947368421053, Test Loss: 361.6189937591553
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=366.835, psi=[0.5024783611297607, 0.4941692054271698], loss1 min/max=0.5309/0.5411, loss2 min/max=0.0457/0.1083, integral time stamps=5000, sec/iter=0.3833
# Slot 0: 0 (no events), 1 (681 events): MAR=9.11+-4.52, HITS_10=0.519+-0.390, Com (681 events): MAR=9.11+-4.52, HITS_10=0.519+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=9.11+-4.52	 HITS_10=0.519+-0.390
# ====== Com       	 (681     events): 	MAR=9.11+-4.52	 HITS_10=0.519+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.9478947368421053, Test Loss: 362.66211700439453
# Testing decay_rate: 1.0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=577.442, psi=[0.5004389882087708, 0.4996033012866974], loss1 min/max=0.4932/0.5064, loss2 min/max=0.0985/0.1711, integral time stamps=5000, sec/iter=0.3065
# Slot 0: 0 (no events), 1 (681 events): MAR=8.97+-4.09, HITS_10=0.529+-0.363, Com (681 events): MAR=8.97+-4.09, HITS_10=0.529+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.97+-4.09	 HITS_10=0.529+-0.363
# ====== Com       	 (681     events): 	MAR=8.97+-4.09	 HITS_10=0.529+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 1.0, Test Loss: 577.4419555664062
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=594.152, psi=[0.5009385943412781, 0.49923062324523926], loss1 min/max=0.4841/0.4974, loss2 min/max=0.0966/0.1809, integral time stamps=5000, sec/iter=0.3113
# Slot 0: 0 (no events), 1 (681 events): MAR=8.97+-4.08, HITS_10=0.531+-0.363, Com (681 events): MAR=8.97+-4.08, HITS_10=0.531+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.97+-4.08	 HITS_10=0.531+-0.363
# ====== Com       	 (681     events): 	MAR=8.97+-4.08	 HITS_10=0.531+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 1.0, Test Loss: 585.7970237731934
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=612.711, psi=[0.5014501214027405, 0.4988974630832672], loss1 min/max=0.4794/0.4929, loss2 min/max=0.0958/0.1920, integral time stamps=5000, sec/iter=0.3133
# Slot 0: 0 (no events), 1 (681 events): MAR=8.96+-4.09, HITS_10=0.529+-0.363, Com (681 events): MAR=8.96+-4.09, HITS_10=0.529+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.96+-4.09	 HITS_10=0.529+-0.363
# ====== Com       	 (681     events): 	MAR=8.96+-4.09	 HITS_10=0.529+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 1.0, Test Loss: 594.7683436075846
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=632.017, psi=[0.5019503235816956, 0.49859145283699036], loss1 min/max=0.4767/0.4906, loss2 min/max=0.0952/0.2032, integral time stamps=5000, sec/iter=0.3114
# Slot 0: 0 (no events), 1 (681 events): MAR=8.97+-4.08, HITS_10=0.530+-0.363, Com (681 events): MAR=8.97+-4.08, HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.97+-4.08	 HITS_10=0.530+-0.363
# ====== Com       	 (681     events): 	MAR=8.97+-4.08	 HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 1.0, Test Loss: 604.0805034637451
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=651.540, psi=[0.5024324059486389, 0.4983054995536804], loss1 min/max=0.4750/0.4890, loss2 min/max=0.0949/0.2147, integral time stamps=5000, sec/iter=0.3107
# Slot 0: 0 (no events), 1 (681 events): MAR=8.96+-4.09, HITS_10=0.532+-0.364, Com (681 events): MAR=8.96+-4.09, HITS_10=0.532+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (681     events): 	MAR=8.96+-4.09	 HITS_10=0.532+-0.364
# ====== Com       	 (681     events): 	MAR=8.96+-4.09	 HITS_10=0.532+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 1.0, Test Loss: 613.5724227905273
# Best decay_rate: 0.6873684210526316 with loss: 337.2467094421387

# %%
decay_rates = np.linspace(0.01, 1.0, 20)  # Example range of decay rates
best_decay_rate, best_loss = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.3.csv', decay_rates=decay_rates, epochs=5)
print(f"Best decay_rate: {best_decay_rate} with loss: {best_loss}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0.01
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=856.982, psi=[0.5004178881645203, 0.5016216039657593], loss1 min/max=0.0626/0.0645, loss2 min/max=0.0125/0.2552, integral time stamps=5000, sec/iter=0.3777
# Slot 0: 0 (no events), 1 (633 events): MAR=9.03+-3.96, HITS_10=0.524+-0.370, Com (633 events): MAR=9.03+-3.96, HITS_10=0.524+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.03+-3.96	 HITS_10=0.524+-0.370
# ====== Com       	 (633     events): 	MAR=9.03+-3.96	 HITS_10=0.524+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.01, Test Loss: 856.9822807312012
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=825.156, psi=[0.500855028629303, 0.5029734969139099], loss1 min/max=0.0798/0.0820, loss2 min/max=0.0159/0.2557, integral time stamps=5000, sec/iter=0.3748
# Slot 0: 0 (no events), 1 (633 events): MAR=9.04+-3.96, HITS_10=0.523+-0.372, Com (633 events): MAR=9.04+-3.96, HITS_10=0.523+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.04+-3.96	 HITS_10=0.523+-0.372
# ====== Com       	 (633     events): 	MAR=9.04+-3.96	 HITS_10=0.523+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.01, Test Loss: 841.0692901611328
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=797.870, psi=[0.5013434290885925, 0.5042070150375366], loss1 min/max=0.0999/0.1027, loss2 min/max=0.0199/0.2568, integral time stamps=5000, sec/iter=0.2961
# Slot 0: 0 (no events), 1 (633 events): MAR=9.02+-3.94, HITS_10=0.521+-0.368, Com (633 events): MAR=9.02+-3.94, HITS_10=0.521+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.02+-3.94	 HITS_10=0.521+-0.368
# ====== Com       	 (633     events): 	MAR=9.02+-3.94	 HITS_10=0.521+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.01, Test Loss: 826.6694145202637
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=775.056, psi=[0.5018554329872131, 0.5053189992904663], loss1 min/max=0.1229/0.1263, loss2 min/max=0.0245/0.2582, integral time stamps=5000, sec/iter=0.3078
# Slot 0: 0 (no events), 1 (633 events): MAR=9.02+-3.90, HITS_10=0.519+-0.365, Com (633 events): MAR=9.02+-3.90, HITS_10=0.519+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.02+-3.90	 HITS_10=0.519+-0.365
# ====== Com       	 (633     events): 	MAR=9.02+-3.90	 HITS_10=0.519+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.01, Test Loss: 813.7660932540894
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=756.733, psi=[0.5023795366287231, 0.5063064098358154], loss1 min/max=0.1485/0.1524, loss2 min/max=0.0295/0.2602, integral time stamps=5000, sec/iter=0.2962
# Slot 0: 0 (no events), 1 (633 events): MAR=9.04+-3.90, HITS_10=0.517+-0.361, Com (633 events): MAR=9.04+-3.90, HITS_10=0.517+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.04+-3.90	 HITS_10=0.517+-0.361
# ====== Com       	 (633     events): 	MAR=9.04+-3.90	 HITS_10=0.517+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.01, Test Loss: 802.359521484375
# Testing decay_rate: 0.06210526315789474
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=367.214, psi=[0.5004540085792542, 0.5011759996414185], loss1 min/max=0.1491/0.1520, loss2 min/max=0.0128/0.0304, integral time stamps=5000, sec/iter=0.2970
# Slot 0: 0 (no events), 1 (633 events): MAR=8.84+-4.30, HITS_10=0.532+-0.392, Com (633 events): MAR=8.84+-4.30, HITS_10=0.532+-0.392
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.84+-4.30	 HITS_10=0.532+-0.392
# ====== Com       	 (633     events): 	MAR=8.84+-4.30	 HITS_10=0.532+-0.392
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.06210526315789474, Test Loss: 367.21428298950195
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=350.988, psi=[0.50101238489151, 0.5024253726005554], loss1 min/max=0.1769/0.1799, loss2 min/max=0.0138/0.0360, integral time stamps=5000, sec/iter=0.2969
# Slot 0: 0 (no events), 1 (633 events): MAR=8.85+-4.30, HITS_10=0.534+-0.389, Com (633 events): MAR=8.85+-4.30, HITS_10=0.534+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.85+-4.30	 HITS_10=0.534+-0.389
# ====== Com       	 (633     events): 	MAR=8.85+-4.30	 HITS_10=0.534+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.06210526315789474, Test Loss: 359.101037979126
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=338.322, psi=[0.5015861988067627, 0.5035195350646973], loss1 min/max=0.2058/0.2090, loss2 min/max=0.0150/0.0418, integral time stamps=5000, sec/iter=0.2954
# Slot 0: 0 (no events), 1 (633 events): MAR=8.87+-4.32, HITS_10=0.535+-0.386, Com (633 events): MAR=8.87+-4.32, HITS_10=0.535+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.87+-4.32	 HITS_10=0.535+-0.386
# ====== Com       	 (633     events): 	MAR=8.87+-4.32	 HITS_10=0.535+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.06210526315789474, Test Loss: 352.1748269399007
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=328.844, psi=[0.5021598935127258, 0.5044633150100708], loss1 min/max=0.2351/0.2385, loss2 min/max=0.0164/0.0477, integral time stamps=5000, sec/iter=0.3642
# Slot 0: 0 (no events), 1 (633 events): MAR=8.86+-4.32, HITS_10=0.538+-0.386, Com (633 events): MAR=8.86+-4.32, HITS_10=0.538+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.86+-4.32	 HITS_10=0.538+-0.386
# ====== Com       	 (633     events): 	MAR=8.86+-4.32	 HITS_10=0.538+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.06210526315789474, Test Loss: 346.34208631515503
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=322.195, psi=[0.5027281641960144, 0.505264401435852], loss1 min/max=0.2639/0.2674, loss2 min/max=0.0178/0.0535, integral time stamps=5000, sec/iter=0.2954
# Slot 0: 0 (no events), 1 (633 events): MAR=8.85+-4.32, HITS_10=0.534+-0.384, Com (633 events): MAR=8.85+-4.32, HITS_10=0.534+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.85+-4.32	 HITS_10=0.534+-0.384
# ====== Com       	 (633     events): 	MAR=8.85+-4.32	 HITS_10=0.534+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.06210526315789474, Test Loss: 341.5126838684082
# Testing decay_rate: 0.11421052631578947
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=584.917, psi=[0.5004463195800781, 0.5016301870346069], loss1 min/max=0.0363/0.0380, loss2 min/max=0.0072/0.0338, integral time stamps=5000, sec/iter=0.2949
# Slot 0: 0 (no events), 1 (633 events): MAR=8.91+-4.09, HITS_10=0.539+-0.370, Com (633 events): MAR=8.91+-4.09, HITS_10=0.539+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.91+-4.09	 HITS_10=0.539+-0.370
# ====== Com       	 (633     events): 	MAR=8.91+-4.09	 HITS_10=0.539+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.11421052631578947, Test Loss: 584.9166450500488
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=547.375, psi=[0.5009662508964539, 0.5030113458633423], loss1 min/max=0.0480/0.0502, loss2 min/max=0.0095/0.0356, integral time stamps=5000, sec/iter=0.3048
# Slot 0: 0 (no events), 1 (633 events): MAR=8.90+-4.20, HITS_10=0.524+-0.379, Com (633 events): MAR=8.90+-4.20, HITS_10=0.524+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.90+-4.20	 HITS_10=0.524+-0.379
# ====== Com       	 (633     events): 	MAR=8.90+-4.20	 HITS_10=0.524+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.11421052631578947, Test Loss: 566.1456985473633
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=513.437, psi=[0.5015138983726501, 0.5042901635169983], loss1 min/max=0.0626/0.0654, loss2 min/max=0.0125/0.0376, integral time stamps=5000, sec/iter=0.3042
# Slot 0: 0 (no events), 1 (633 events): MAR=8.91+-4.24, HITS_10=0.528+-0.388, Com (633 events): MAR=8.91+-4.24, HITS_10=0.528+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.91+-4.24	 HITS_10=0.528+-0.388
# ====== Com       	 (633     events): 	MAR=8.91+-4.24	 HITS_10=0.528+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.11421052631578947, Test Loss: 548.5760561625162
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=483.328, psi=[0.5020674467086792, 0.5054619312286377], loss1 min/max=0.0803/0.0838, loss2 min/max=0.0159/0.0397, integral time stamps=5000, sec/iter=0.2959
# Slot 0: 0 (no events), 1 (633 events): MAR=8.92+-4.29, HITS_10=0.529+-0.386, Com (633 events): MAR=8.92+-4.29, HITS_10=0.529+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.92+-4.29	 HITS_10=0.529+-0.386
# ====== Com       	 (633     events): 	MAR=8.92+-4.29	 HITS_10=0.529+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.11421052631578947, Test Loss: 532.2639617919922
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=457.345, psi=[0.5026190876960754, 0.5065213441848755], loss1 min/max=0.1012/0.1053, loss2 min/max=0.0200/0.0419, integral time stamps=5000, sec/iter=0.2958
# Slot 0: 0 (no events), 1 (633 events): MAR=8.90+-4.29, HITS_10=0.531+-0.385, Com (633 events): MAR=8.90+-4.29, HITS_10=0.531+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.90+-4.29	 HITS_10=0.531+-0.385
# ====== Com       	 (633     events): 	MAR=8.90+-4.29	 HITS_10=0.531+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.11421052631578947, Test Loss: 517.2802673339844
# Testing decay_rate: 0.16631578947368422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=317.696, psi=[0.5004419088363647, 0.49897944927215576], loss1 min/max=0.6292/0.6367, loss2 min/max=0.0281/0.1277, integral time stamps=5000, sec/iter=0.2957
# Slot 0: 0 (no events), 1 (633 events): MAR=9.05+-4.00, HITS_10=0.521+-0.368, Com (633 events): MAR=9.05+-4.00, HITS_10=0.521+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.05+-4.00	 HITS_10=0.521+-0.368
# ====== Com       	 (633     events): 	MAR=9.05+-4.00	 HITS_10=0.521+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.16631578947368422, Test Loss: 317.69604301452637
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=318.045, psi=[0.5009307265281677, 0.49800679087638855], loss1 min/max=0.5767/0.5818, loss2 min/max=0.0301/0.1167, integral time stamps=5000, sec/iter=0.2960
# Slot 0: 0 (no events), 1 (633 events): MAR=9.06+-4.01, HITS_10=0.520+-0.364, Com (633 events): MAR=9.06+-4.01, HITS_10=0.520+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.06+-4.01	 HITS_10=0.520+-0.364
# ====== Com       	 (633     events): 	MAR=9.06+-4.01	 HITS_10=0.520+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.16631578947368422, Test Loss: 317.8704023361206
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=320.717, psi=[0.5014537572860718, 0.49716201424598694], loss1 min/max=0.5388/0.5434, loss2 min/max=0.0326/0.1089, integral time stamps=5000, sec/iter=0.2967
# Slot 0: 0 (no events), 1 (633 events): MAR=9.07+-4.02, HITS_10=0.516+-0.370, Com (633 events): MAR=9.07+-4.02, HITS_10=0.516+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.07+-4.02	 HITS_10=0.516+-0.370
# ====== Com       	 (633     events): 	MAR=9.07+-4.02	 HITS_10=0.516+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.16631578947368422, Test Loss: 318.8192647298177
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=324.944, psi=[0.5019837021827698, 0.4964723587036133], loss1 min/max=0.5123/0.5168, loss2 min/max=0.0356/0.1035, integral time stamps=5000, sec/iter=0.2964
# Slot 0: 0 (no events), 1 (633 events): MAR=9.08+-4.03, HITS_10=0.517+-0.370, Com (633 events): MAR=9.08+-4.03, HITS_10=0.517+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.08+-4.03	 HITS_10=0.517+-0.370
# ====== Com       	 (633     events): 	MAR=9.08+-4.03	 HITS_10=0.517+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.16631578947368422, Test Loss: 320.3503484725952
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=330.237, psi=[0.5025088787078857, 0.4959239661693573], loss1 min/max=0.4945/0.4989, loss2 min/max=0.0389/0.0999, integral time stamps=5000, sec/iter=0.2960
# Slot 0: 0 (no events), 1 (633 events): MAR=9.06+-4.03, HITS_10=0.517+-0.370, Com (633 events): MAR=9.06+-4.03, HITS_10=0.517+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.06+-4.03	 HITS_10=0.517+-0.370
# ====== Com       	 (633     events): 	MAR=9.06+-4.03	 HITS_10=0.517+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.16631578947368422, Test Loss: 322.32772903442384
# Testing decay_rate: 0.21842105263157896
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=401.563, psi=[0.50043785572052, 0.4988465905189514], loss1 min/max=0.6333/0.6419, loss2 min/max=0.0807/0.1286, integral time stamps=5000, sec/iter=0.2963
# Slot 0: 0 (no events), 1 (633 events): MAR=9.05+-4.17, HITS_10=0.521+-0.382, Com (633 events): MAR=9.05+-4.17, HITS_10=0.521+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.05+-4.17	 HITS_10=0.521+-0.382
# ====== Com       	 (633     events): 	MAR=9.05+-4.17	 HITS_10=0.521+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.21842105263157896, Test Loss: 401.5627956390381
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=404.365, psi=[0.5009114146232605, 0.49775004386901855], loss1 min/max=0.5837/0.5916, loss2 min/max=0.0842/0.1184, integral time stamps=5000, sec/iter=0.2958
# Slot 0: 0 (no events), 1 (633 events): MAR=9.03+-4.16, HITS_10=0.524+-0.378, Com (633 events): MAR=9.03+-4.16, HITS_10=0.524+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.03+-4.16	 HITS_10=0.524+-0.378
# ====== Com       	 (633     events): 	MAR=9.03+-4.16	 HITS_10=0.524+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.21842105263157896, Test Loss: 402.9640636444092
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=409.377, psi=[0.501420259475708, 0.49680718779563904], loss1 min/max=0.5449/0.5527, loss2 min/max=0.0884/0.1105, integral time stamps=5000, sec/iter=0.3165
# Slot 0: 0 (no events), 1 (633 events): MAR=9.01+-4.17, HITS_10=0.522+-0.381, Com (633 events): MAR=9.01+-4.17, HITS_10=0.522+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.01+-4.17	 HITS_10=0.522+-0.381
# ====== Com       	 (633     events): 	MAR=9.01+-4.17	 HITS_10=0.522+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.21842105263157896, Test Loss: 405.1017093658447
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=415.979, psi=[0.5019367337226868, 0.49603861570358276], loss1 min/max=0.5158/0.5236, loss2 min/max=0.0929/0.1047, integral time stamps=5000, sec/iter=0.2965
# Slot 0: 0 (no events), 1 (633 events): MAR=9.01+-4.17, HITS_10=0.520+-0.383, Com (633 events): MAR=9.01+-4.17, HITS_10=0.520+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.01+-4.17	 HITS_10=0.520+-0.383
# ====== Com       	 (633     events): 	MAR=9.01+-4.17	 HITS_10=0.520+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.21842105263157896, Test Loss: 407.8211569786072
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=423.677, psi=[0.5024497509002686, 0.4954327344894409], loss1 min/max=0.4949/0.5025, loss2 min/max=0.0978/0.1005, integral time stamps=5000, sec/iter=0.2977
# Slot 0: 0 (no events), 1 (633 events): MAR=9.00+-4.16, HITS_10=0.521+-0.384, Com (633 events): MAR=9.00+-4.16, HITS_10=0.521+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.00+-4.16	 HITS_10=0.521+-0.384
# ====== Com       	 (633     events): 	MAR=9.00+-4.16	 HITS_10=0.521+-0.384
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.21842105263157896, Test Loss: 410.9922443389893
# Testing decay_rate: 0.2705263157894737
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=533.724, psi=[0.5004335641860962, 0.5010489225387573], loss1 min/max=0.2431/0.2486, loss2 min/max=0.0484/0.1498, integral time stamps=5000, sec/iter=0.2959
# Slot 0: 0 (no events), 1 (633 events): MAR=8.90+-4.26, HITS_10=0.535+-0.383, Com (633 events): MAR=8.90+-4.26, HITS_10=0.535+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.90+-4.26	 HITS_10=0.535+-0.383
# ====== Com       	 (633     events): 	MAR=8.90+-4.26	 HITS_10=0.535+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.2705263157894737, Test Loss: 533.723611831665
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=533.482, psi=[0.500880241394043, 0.5020701885223389], loss1 min/max=0.2869/0.2926, loss2 min/max=0.0571/0.1577, integral time stamps=5000, sec/iter=0.2962
# Slot 0: 0 (no events), 1 (633 events): MAR=8.91+-4.23, HITS_10=0.532+-0.381, Com (633 events): MAR=8.91+-4.23, HITS_10=0.532+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.91+-4.23	 HITS_10=0.532+-0.381
# ====== Com       	 (633     events): 	MAR=8.91+-4.23	 HITS_10=0.532+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.2705263157894737, Test Loss: 533.6026048660278
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=537.811, psi=[0.5013567805290222, 0.5028446316719055], loss1 min/max=0.3268/0.3325, loss2 min/max=0.0651/0.1654, integral time stamps=5000, sec/iter=0.3007
# Slot 0: 0 (no events), 1 (633 events): MAR=8.96+-4.21, HITS_10=0.528+-0.376, Com (633 events): MAR=8.96+-4.21, HITS_10=0.528+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.96+-4.21	 HITS_10=0.528+-0.376
# ====== Com       	 (633     events): 	MAR=8.96+-4.21	 HITS_10=0.528+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.2705263157894737, Test Loss: 535.0053806304932
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=545.127, psi=[0.5018361806869507, 0.5034061074256897], loss1 min/max=0.3606/0.3664, loss2 min/max=0.0719/0.1726, integral time stamps=5000, sec/iter=0.2899
# Slot 0: 0 (no events), 1 (633 events): MAR=8.98+-4.20, HITS_10=0.522+-0.374, Com (633 events): MAR=8.98+-4.20, HITS_10=0.522+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.98+-4.20	 HITS_10=0.522+-0.374
# ====== Com       	 (633     events): 	MAR=8.98+-4.20	 HITS_10=0.522+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.2705263157894737, Test Loss: 537.5357851982117
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=554.203, psi=[0.5023091435432434, 0.503795325756073], loss1 min/max=0.3876/0.3935, loss2 min/max=0.0773/0.1807, integral time stamps=5000, sec/iter=0.2909
# Slot 0: 0 (no events), 1 (633 events): MAR=9.00+-4.19, HITS_10=0.517+-0.378, Com (633 events): MAR=9.00+-4.19, HITS_10=0.517+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.00+-4.19	 HITS_10=0.517+-0.378
# ====== Com       	 (633     events): 	MAR=9.00+-4.19	 HITS_10=0.517+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.2705263157894737, Test Loss: 540.869324874878
# Testing decay_rate: 0.32263157894736844
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=298.498, psi=[0.5004447102546692, 0.5001852512359619], loss1 min/max=0.4394/0.4525, loss2 min/max=0.0185/0.0911, integral time stamps=5000, sec/iter=0.2903
# Slot 0: 0 (no events), 1 (633 events): MAR=9.02+-4.07, HITS_10=0.513+-0.364, Com (633 events): MAR=9.02+-4.07, HITS_10=0.513+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.02+-4.07	 HITS_10=0.513+-0.364
# ====== Com       	 (633     events): 	MAR=9.02+-4.07	 HITS_10=0.513+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.32263157894736844, Test Loss: 298.4978885650635
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=300.302, psi=[0.5009447336196899, 0.5002418756484985], loss1 min/max=0.4496/0.4630, loss2 min/max=0.0198/0.0933, integral time stamps=5000, sec/iter=0.2956
# Slot 0: 0 (no events), 1 (633 events): MAR=9.02+-4.07, HITS_10=0.513+-0.363, Com (633 events): MAR=9.02+-4.07, HITS_10=0.513+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.02+-4.07	 HITS_10=0.513+-0.363
# ====== Com       	 (633     events): 	MAR=9.02+-4.07	 HITS_10=0.513+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.32263157894736844, Test Loss: 299.3998589515686
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=302.546, psi=[0.5014787316322327, 0.5002025961875916], loss1 min/max=0.4545/0.4681, loss2 min/max=0.0214/0.0942, integral time stamps=5000, sec/iter=0.2928
# Slot 0: 0 (no events), 1 (633 events): MAR=9.01+-4.07, HITS_10=0.514+-0.364, Com (633 events): MAR=9.01+-4.07, HITS_10=0.514+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.01+-4.07	 HITS_10=0.514+-0.364
# ====== Com       	 (633     events): 	MAR=9.01+-4.07	 HITS_10=0.514+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.32263157894736844, Test Loss: 300.448592821757
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=305.068, psi=[0.5020221471786499, 0.5001187324523926], loss1 min/max=0.4569/0.4707, loss2 min/max=0.0230/0.0947, integral time stamps=5000, sec/iter=0.2924
# Slot 0: 0 (no events), 1 (633 events): MAR=9.00+-4.07, HITS_10=0.513+-0.362, Com (633 events): MAR=9.00+-4.07, HITS_10=0.513+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.00+-4.07	 HITS_10=0.513+-0.362
# ====== Com       	 (633     events): 	MAR=9.00+-4.07	 HITS_10=0.513+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.32263157894736844, Test Loss: 301.6035544872284
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=307.819, psi=[0.5025658011436462, 0.5000095963478088], loss1 min/max=0.4581/0.4719, loss2 min/max=0.0247/0.0949, integral time stamps=5000, sec/iter=0.2915
# Slot 0: 0 (no events), 1 (633 events): MAR=9.00+-4.08, HITS_10=0.513+-0.362, Com (633 events): MAR=9.00+-4.08, HITS_10=0.513+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.00+-4.08	 HITS_10=0.513+-0.362
# ====== Com       	 (633     events): 	MAR=9.00+-4.08	 HITS_10=0.513+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.32263157894736844, Test Loss: 302.8466047286987
# Testing decay_rate: 0.37473684210526315
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=409.357, psi=[0.5004547834396362, 0.5016027092933655], loss1 min/max=0.1509/0.1544, loss2 min/max=0.0301/0.0410, integral time stamps=5000, sec/iter=0.2925
# Slot 0: 0 (no events), 1 (633 events): MAR=8.89+-3.96, HITS_10=0.532+-0.369, Com (633 events): MAR=8.89+-3.96, HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.89+-3.96	 HITS_10=0.532+-0.369
# ====== Com       	 (633     events): 	MAR=8.89+-3.96	 HITS_10=0.532+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.37473684210526315, Test Loss: 409.3573455810547
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=389.425, psi=[0.5010303854942322, 0.5028073191642761], loss1 min/max=0.1869/0.1907, loss2 min/max=0.0373/0.0423, integral time stamps=5000, sec/iter=0.2893
# Slot 0: 0 (no events), 1 (633 events): MAR=8.98+-3.95, HITS_10=0.525+-0.370, Com (633 events): MAR=8.98+-3.95, HITS_10=0.525+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.98+-3.95	 HITS_10=0.525+-0.370
# ====== Com       	 (633     events): 	MAR=8.98+-3.95	 HITS_10=0.525+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.37473684210526315, Test Loss: 399.3911008834839
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=375.492, psi=[0.501617431640625, 0.5038177967071533], loss1 min/max=0.2242/0.2282, loss2 min/max=0.0430/0.0457, integral time stamps=5000, sec/iter=0.2905
# Slot 0: 0 (no events), 1 (633 events): MAR=8.95+-3.92, HITS_10=0.535+-0.373, Com (633 events): MAR=8.95+-3.92, HITS_10=0.535+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.95+-3.92	 HITS_10=0.535+-0.373
# ====== Com       	 (633     events): 	MAR=8.95+-3.92	 HITS_10=0.535+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.37473684210526315, Test Loss: 391.4248689015706
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=366.666, psi=[0.502202570438385, 0.5046464204788208], loss1 min/max=0.2608/0.2649, loss2 min/max=0.0450/0.0530, integral time stamps=5000, sec/iter=0.2896
# Slot 0: 0 (no events), 1 (633 events): MAR=8.94+-3.93, HITS_10=0.531+-0.368, Com (633 events): MAR=8.94+-3.93, HITS_10=0.531+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.94+-3.93	 HITS_10=0.531+-0.368
# ====== Com       	 (633     events): 	MAR=8.94+-3.93	 HITS_10=0.531+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.37473684210526315, Test Loss: 385.235134601593
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=361.967, psi=[0.5027806758880615, 0.5053122043609619], loss1 min/max=0.2948/0.2990, loss2 min/max=0.0473/0.0599, integral time stamps=5000, sec/iter=0.2906
# Slot 0: 0 (no events), 1 (633 events): MAR=8.96+-3.89, HITS_10=0.524+-0.369, Com (633 events): MAR=8.96+-3.89, HITS_10=0.524+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.96+-3.89	 HITS_10=0.524+-0.369
# ====== Com       	 (633     events): 	MAR=8.96+-3.89	 HITS_10=0.524+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.37473684210526315, Test Loss: 380.5815425872803
# Testing decay_rate: 0.4268421052631579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=568.084, psi=[0.5004521608352661, 0.5016151070594788], loss1 min/max=0.0961/0.1001, loss2 min/max=0.0191/0.1076, integral time stamps=5000, sec/iter=0.3113
# Slot 0: 0 (no events), 1 (633 events): MAR=8.97+-3.93, HITS_10=0.526+-0.365, Com (633 events): MAR=8.97+-3.93, HITS_10=0.526+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.97+-3.93	 HITS_10=0.526+-0.365
# ====== Com       	 (633     events): 	MAR=8.97+-3.93	 HITS_10=0.526+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4268421052631579, Test Loss: 568.0837268829346
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=544.415, psi=[0.5010140538215637, 0.5029066205024719], loss1 min/max=0.1224/0.1272, loss2 min/max=0.0243/0.1113, integral time stamps=5000, sec/iter=0.2899
# Slot 0: 0 (no events), 1 (633 events): MAR=8.99+-3.96, HITS_10=0.521+-0.367, Com (633 events): MAR=8.99+-3.96, HITS_10=0.521+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.99+-3.96	 HITS_10=0.521+-0.367
# ====== Com       	 (633     events): 	MAR=8.99+-3.96	 HITS_10=0.521+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4268421052631579, Test Loss: 556.2494258880615
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=526.299, psi=[0.5015849471092224, 0.5040420889854431], loss1 min/max=0.1518/0.1576, loss2 min/max=0.0302/0.1154, integral time stamps=5000, sec/iter=0.2920
# Slot 0: 0 (no events), 1 (633 events): MAR=8.96+-3.92, HITS_10=0.525+-0.368, Com (633 events): MAR=8.96+-3.92, HITS_10=0.525+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.96+-3.92	 HITS_10=0.525+-0.368
# ====== Com       	 (633     events): 	MAR=8.96+-3.92	 HITS_10=0.525+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4268421052631579, Test Loss: 546.2659422556559
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=513.395, psi=[0.5021504163742065, 0.5050219893455505], loss1 min/max=0.1836/0.1903, loss2 min/max=0.0365/0.1198, integral time stamps=5000, sec/iter=0.2897
# Slot 0: 0 (no events), 1 (633 events): MAR=9.02+-3.90, HITS_10=0.524+-0.368, Com (633 events): MAR=9.02+-3.90, HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.02+-3.90	 HITS_10=0.524+-0.368
# ====== Com       	 (633     events): 	MAR=9.02+-3.90	 HITS_10=0.524+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.4268421052631579, Test Loss: 538.0482993125916
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=505.205, psi=[0.5027056336402893, 0.5058516263961792], loss1 min/max=0.2164/0.2239, loss2 min/max=0.0430/0.1243, integral time stamps=5000, sec/iter=0.2902
# Slot 0: 0 (no events), 1 (633 events): MAR=9.03+-3.89, HITS_10=0.523+-0.367, Com (633 events): MAR=9.03+-3.89, HITS_10=0.523+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.03+-3.89	 HITS_10=0.523+-0.367
# ====== Com       	 (633     events): 	MAR=9.03+-3.89	 HITS_10=0.523+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.4268421052631579, Test Loss: 531.4797084808349
# Testing decay_rate: 0.4789473684210527
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=332.836, psi=[0.5004401803016663, 0.5007707476615906], loss1 min/max=0.3516/0.3586, loss2 min/max=0.0358/0.0718, integral time stamps=5000, sec/iter=0.2956
# Slot 0: 0 (no events), 1 (633 events): MAR=8.87+-4.30, HITS_10=0.531+-0.377, Com (633 events): MAR=8.87+-4.30, HITS_10=0.531+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.87+-4.30	 HITS_10=0.531+-0.377
# ====== Com       	 (633     events): 	MAR=8.87+-4.30	 HITS_10=0.531+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4789473684210527, Test Loss: 332.835729598999
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=333.781, psi=[0.5009226202964783, 0.5013997554779053], loss1 min/max=0.3855/0.3919, loss2 min/max=0.0386/0.0784, integral time stamps=5000, sec/iter=0.2990
# Slot 0: 0 (no events), 1 (633 events): MAR=8.92+-4.27, HITS_10=0.522+-0.382, Com (633 events): MAR=8.92+-4.27, HITS_10=0.522+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.92+-4.27	 HITS_10=0.522+-0.382
# ====== Com       	 (633     events): 	MAR=8.92+-4.27	 HITS_10=0.522+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4789473684210527, Test Loss: 333.3081455230713
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=336.960, psi=[0.501437246799469, 0.5017955899238586], loss1 min/max=0.4096/0.4157, loss2 min/max=0.0417/0.0832, integral time stamps=5000, sec/iter=0.2970
# Slot 0: 0 (no events), 1 (633 events): MAR=8.95+-4.22, HITS_10=0.514+-0.382, Com (633 events): MAR=8.95+-4.22, HITS_10=0.514+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.95+-4.22	 HITS_10=0.514+-0.382
# ====== Com       	 (633     events): 	MAR=8.95+-4.22	 HITS_10=0.514+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4789473684210527, Test Loss: 334.52551523844403
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# ...
# ====== 1         	 (633     events): 	MAR=9.05+-4.16	 HITS_10=0.523+-0.375
# ====== Com       	 (633     events): 	MAR=9.05+-4.16	 HITS_10=0.523+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8436842105263158, Test Loss: 313.7748818397522
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=314.547, psi=[0.5025563836097717, 0.5033460855484009], loss1 min/max=0.4052/0.4081, loss2 min/max=0.0272/0.0816, integral time stamps=5000, sec/iter=0.2866
# Slot 0: 0 (no events), 1 (633 events): MAR=9.07+-4.13, HITS_10=0.521+-0.373, Com (633 events): MAR=9.07+-4.13, HITS_10=0.521+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.07+-4.13	 HITS_10=0.521+-0.373
# ====== Com       	 (633     events): 	MAR=9.07+-4.13	 HITS_10=0.521+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8436842105263158, Test Loss: 313.9293632507324
# Testing decay_rate: 0.8957894736842106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=607.214, psi=[0.5004212856292725, 0.4992762506008148], loss1 min/max=0.5300/0.5360, loss2 min/max=0.1060/0.2166, integral time stamps=5000, sec/iter=0.2859
# Slot 0: 0 (no events), 1 (633 events): MAR=9.10+-3.90, HITS_10=0.524+-0.360, Com (633 events): MAR=9.10+-3.90, HITS_10=0.524+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.10+-3.90	 HITS_10=0.524+-0.360
# ====== Com       	 (633     events): 	MAR=9.10+-3.90	 HITS_10=0.524+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.8957894736842106, Test Loss: 607.2138080596924
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=617.514, psi=[0.5007392168045044, 0.49874114990234375], loss1 min/max=0.4965/0.5006, loss2 min/max=0.0993/0.2233, integral time stamps=5000, sec/iter=0.2861
# Slot 0: 0 (no events), 1 (633 events): MAR=9.12+-3.88, HITS_10=0.522+-0.359, Com (633 events): MAR=9.12+-3.88, HITS_10=0.522+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.12+-3.88	 HITS_10=0.522+-0.359
# ====== Com       	 (633     events): 	MAR=9.12+-3.88	 HITS_10=0.522+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.8957894736842106, Test Loss: 612.3637704849243
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=629.960, psi=[0.5011075139045715, 0.4983786344528198], loss1 min/max=0.4772/0.4815, loss2 min/max=0.0954/0.2311, integral time stamps=5000, sec/iter=0.2852
# Slot 0: 0 (no events), 1 (633 events): MAR=9.06+-3.88, HITS_10=0.528+-0.358, Com (633 events): MAR=9.06+-3.88, HITS_10=0.528+-0.358
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.06+-3.88	 HITS_10=0.528+-0.358
# ====== Com       	 (633     events): 	MAR=9.06+-3.88	 HITS_10=0.528+-0.358
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.8957894736842106, Test Loss: 618.2291774749756
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=643.500, psi=[0.5014964938163757, 0.49814099073410034], loss1 min/max=0.4666/0.4712, loss2 min/max=0.0932/0.2395, integral time stamps=5000, sec/iter=0.2863
# Slot 0: 0 (no events), 1 (633 events): MAR=9.09+-3.88, HITS_10=0.520+-0.359, Com (633 events): MAR=9.09+-3.88, HITS_10=0.520+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.09+-3.88	 HITS_10=0.520+-0.359
# ====== Com       	 (633     events): 	MAR=9.09+-3.88	 HITS_10=0.520+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8957894736842106, Test Loss: 624.5468754768372
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=657.409, psi=[0.5018916726112366, 0.4979800581932068], loss1 min/max=0.4607/0.4654, loss2 min/max=0.0920/0.2482, integral time stamps=5000, sec/iter=0.2932
# Slot 0: 0 (no events), 1 (633 events): MAR=9.10+-3.89, HITS_10=0.518+-0.361, Com (633 events): MAR=9.10+-3.89, HITS_10=0.518+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=9.10+-3.89	 HITS_10=0.518+-0.361
# ====== Com       	 (633     events): 	MAR=9.10+-3.89	 HITS_10=0.518+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8957894736842106, Test Loss: 631.1192592620849
# Testing decay_rate: 0.9478947368421053
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=351.001, psi=[0.5004413723945618, 0.5002057552337646], loss1 min/max=0.4282/0.4325, loss2 min/max=0.0513/0.0865, integral time stamps=5000, sec/iter=0.2915
# Slot 0: 0 (no events), 1 (633 events): MAR=8.94+-4.24, HITS_10=0.535+-0.385, Com (633 events): MAR=8.94+-4.24, HITS_10=0.535+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.94+-4.24	 HITS_10=0.535+-0.385
# ====== Com       	 (633     events): 	MAR=8.94+-4.24	 HITS_10=0.535+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.9478947368421053, Test Loss: 351.001070022583
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=356.701, psi=[0.5009305477142334, 0.5003328323364258], loss1 min/max=0.4412/0.4444, loss2 min/max=0.0552/0.0889, integral time stamps=5000, sec/iter=0.2868
# Slot 0: 0 (no events), 1 (633 events): MAR=8.97+-4.23, HITS_10=0.533+-0.386, Com (633 events): MAR=8.97+-4.23, HITS_10=0.533+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.97+-4.23	 HITS_10=0.533+-0.386
# ====== Com       	 (633     events): 	MAR=8.97+-4.23	 HITS_10=0.533+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.9478947368421053, Test Loss: 353.85094928741455
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=363.071, psi=[0.5014468431472778, 0.5003498196601868], loss1 min/max=0.4487/0.4517, loss2 min/max=0.0594/0.0903, integral time stamps=5000, sec/iter=0.2905
# Slot 0: 0 (no events), 1 (633 events): MAR=8.98+-4.24, HITS_10=0.521+-0.390, Com (633 events): MAR=8.98+-4.24, HITS_10=0.521+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.98+-4.24	 HITS_10=0.521+-0.390
# ====== Com       	 (633     events): 	MAR=8.98+-4.24	 HITS_10=0.521+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.9478947368421053, Test Loss: 356.92430051167804
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=369.897, psi=[0.5019657611846924, 0.5003001093864441], loss1 min/max=0.4532/0.4561, loss2 min/max=0.0638/0.0912, integral time stamps=5000, sec/iter=0.2889
# Slot 0: 0 (no events), 1 (633 events): MAR=8.96+-4.26, HITS_10=0.524+-0.385, Com (633 events): MAR=8.96+-4.26, HITS_10=0.524+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.96+-4.26	 HITS_10=0.524+-0.385
# ====== Com       	 (633     events): 	MAR=8.96+-4.26	 HITS_10=0.524+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.9478947368421053, Test Loss: 360.1675853729248
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=377.085, psi=[0.5024781227111816, 0.5002089738845825], loss1 min/max=0.4560/0.4588, loss2 min/max=0.0684/0.0918, integral time stamps=5000, sec/iter=0.2913
# Slot 0: 0 (no events), 1 (633 events): MAR=8.98+-4.30, HITS_10=0.521+-0.387, Com (633 events): MAR=8.98+-4.30, HITS_10=0.521+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.98+-4.30	 HITS_10=0.521+-0.387
# ====== Com       	 (633     events): 	MAR=8.98+-4.30	 HITS_10=0.521+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.9478947368421053, Test Loss: 363.5510452270508
# Testing decay_rate: 1.0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=623.109, psi=[0.5004224181175232, 0.5011935234069824], loss1 min/max=0.1120/0.1168, loss2 min/max=0.0223/0.1551, integral time stamps=5000, sec/iter=0.2875
# Slot 0: 0 (no events), 1 (633 events): MAR=8.86+-4.17, HITS_10=0.537+-0.382, Com (633 events): MAR=8.86+-4.17, HITS_10=0.537+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.86+-4.17	 HITS_10=0.537+-0.382
# ====== Com       	 (633     events): 	MAR=8.86+-4.17	 HITS_10=0.537+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 1.0, Test Loss: 623.1089706420898
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=597.807, psi=[0.5007184743881226, 0.5024336576461792], loss1 min/max=0.1472/0.1531, loss2 min/max=0.0294/0.1590, integral time stamps=5000, sec/iter=0.2865
# Slot 0: 0 (no events), 1 (633 events): MAR=8.86+-4.18, HITS_10=0.543+-0.383, Com (633 events): MAR=8.86+-4.18, HITS_10=0.543+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.86+-4.18	 HITS_10=0.543+-0.383
# ====== Com       	 (633     events): 	MAR=8.86+-4.18	 HITS_10=0.543+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 1.0, Test Loss: 610.4578971862793
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=580.207, psi=[0.5010700821876526, 0.5034735202789307], loss1 min/max=0.1864/0.1933, loss2 min/max=0.0371/0.1633, integral time stamps=5000, sec/iter=0.2868
# Slot 0: 0 (no events), 1 (633 events): MAR=8.89+-4.22, HITS_10=0.540+-0.382, Com (633 events): MAR=8.89+-4.22, HITS_10=0.540+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.89+-4.22	 HITS_10=0.540+-0.382
# ====== Com       	 (633     events): 	MAR=8.89+-4.22	 HITS_10=0.540+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 1.0, Test Loss: 600.3744004567465
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=569.438, psi=[0.5014506578445435, 0.5043193101882935], loss1 min/max=0.2275/0.2351, loss2 min/max=0.0453/0.1680, integral time stamps=5000, sec/iter=0.3065
# Slot 0: 0 (no events), 1 (633 events): MAR=8.88+-4.21, HITS_10=0.536+-0.375, Com (633 events): MAR=8.88+-4.21, HITS_10=0.536+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.88+-4.21	 HITS_10=0.536+-0.375
# ====== Com       	 (633     events): 	MAR=8.88+-4.21	 HITS_10=0.536+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 1.0, Test Loss: 592.6403679847717
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=564.338, psi=[0.5018463134765625, 0.5049867630004883], loss1 min/max=0.2676/0.2758, loss2 min/max=0.0534/0.1728, integral time stamps=5000, sec/iter=0.2851
# Slot 0: 0 (no events), 1 (633 events): MAR=8.89+-4.24, HITS_10=0.543+-0.377, Com (633 events): MAR=8.89+-4.24, HITS_10=0.543+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (633     events): 	MAR=8.89+-4.24	 HITS_10=0.543+-0.377
# ====== Com       	 (633     events): 	MAR=8.89+-4.24	 HITS_10=0.543+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 1.0, Test Loss: 586.979919052124
# Best decay_rate: 0.5831578947368421 with loss: 279.2585115432739

# %%
decay_rates = np.linspace(0.01, 1.0, 20)  # Example range of decay rates
best_decay_rate, best_loss = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.4.csv', decay_rates=decay_rates, epochs=5)
print(f"Best decay_rate: {best_decay_rate} with loss: {best_loss}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0.01
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=461.837, psi=[0.5004369020462036, 0.5011734962463379], loss1 min/max=0.0933/0.0957, loss2 min/max=0.0186/0.0471, integral time stamps=5000, sec/iter=0.2828
# Slot 0: 0 (no events), 1 (613 events): MAR=9.00+-4.21, HITS_10=0.529+-0.378, Com (613 events): MAR=9.00+-4.21, HITS_10=0.529+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.00+-4.21	 HITS_10=0.529+-0.378
# ====== Com       	 (613     events): 	MAR=9.00+-4.21	 HITS_10=0.529+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.01, Test Loss: 461.8371868133545
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=439.670, psi=[0.5009022951126099, 0.5024467706680298], loss1 min/max=0.1162/0.1191, loss2 min/max=0.0232/0.0498, integral time stamps=5000, sec/iter=0.2796
# Slot 0: 0 (no events), 1 (613 events): MAR=8.99+-4.22, HITS_10=0.531+-0.380, Com (613 events): MAR=8.99+-4.22, HITS_10=0.531+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=8.99+-4.22	 HITS_10=0.531+-0.380
# ====== Com       	 (613     events): 	MAR=8.99+-4.22	 HITS_10=0.531+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.01, Test Loss: 450.753502368927
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=421.727, psi=[0.5014055371284485, 0.5035856366157532], loss1 min/max=0.1420/0.1454, loss2 min/max=0.0284/0.0528, integral time stamps=5000, sec/iter=0.3004
# Slot 0: 0 (no events), 1 (613 events): MAR=9.00+-4.21, HITS_10=0.527+-0.380, Com (613 events): MAR=9.00+-4.21, HITS_10=0.527+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.00+-4.21	 HITS_10=0.527+-0.380
# ====== Com       	 (613     events): 	MAR=9.00+-4.21	 HITS_10=0.527+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.01, Test Loss: 441.0781297683716
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=407.867, psi=[0.5019192099571228, 0.5045886039733887], loss1 min/max=0.1700/0.1740, loss2 min/max=0.0340/0.0561, integral time stamps=5000, sec/iter=0.2760
# Slot 0: 0 (no events), 1 (613 events): MAR=9.02+-4.22, HITS_10=0.533+-0.379, Com (613 events): MAR=9.02+-4.22, HITS_10=0.533+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.02+-4.22	 HITS_10=0.533+-0.379
# ====== Com       	 (613     events): 	MAR=9.02+-4.22	 HITS_10=0.533+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.01, Test Loss: 432.775354385376
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=397.869, psi=[0.5024324059486389, 0.5054567456245422], loss1 min/max=0.1995/0.2039, loss2 min/max=0.0399/0.0595, integral time stamps=5000, sec/iter=0.2783
# Slot 0: 0 (no events), 1 (613 events): MAR=9.02+-4.22, HITS_10=0.533+-0.377, Com (613 events): MAR=9.02+-4.22, HITS_10=0.533+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.02+-4.22	 HITS_10=0.533+-0.377
# ====== Com       	 (613     events): 	MAR=9.02+-4.22	 HITS_10=0.533+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.01, Test Loss: 425.793985748291
# Testing decay_rate: 0.06210526315789474
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=476.305, psi=[0.5004295706748962, 0.4987258315086365], loss1 min/max=0.7514/0.7634, loss2 min/max=0.1300/0.1528, integral time stamps=5000, sec/iter=0.2773
# Slot 0: 0 (no events), 1 (613 events): MAR=9.34+-4.24, HITS_10=0.501+-0.388, Com (613 events): MAR=9.34+-4.24, HITS_10=0.501+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.34+-4.24	 HITS_10=0.501+-0.388
# ====== Com       	 (613     events): 	MAR=9.34+-4.24	 HITS_10=0.501+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.06210526315789474, Test Loss: 476.3050193786621
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=474.668, psi=[0.5008436441421509, 0.49747151136398315], loss1 min/max=0.6659/0.6762, loss2 min/max=0.1328/0.1362, integral time stamps=5000, sec/iter=0.2757
# Slot 0: 0 (no events), 1 (613 events): MAR=9.34+-4.23, HITS_10=0.498+-0.387, Com (613 events): MAR=9.34+-4.23, HITS_10=0.498+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.34+-4.23	 HITS_10=0.498+-0.387
# ====== Com       	 (613     events): 	MAR=9.34+-4.23	 HITS_10=0.498+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.06210526315789474, Test Loss: 475.48675632476807
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=477.165, psi=[0.5013048052787781, 0.49634212255477905], loss1 min/max=0.5996/0.6087, loss2 min/max=0.1196/0.1406, integral time stamps=5000, sec/iter=0.2757
# Slot 0: 0 (no events), 1 (613 events): MAR=9.33+-4.23, HITS_10=0.502+-0.387, Com (613 events): MAR=9.33+-4.23, HITS_10=0.502+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.33+-4.23	 HITS_10=0.502+-0.387
# ====== Com       	 (613     events): 	MAR=9.33+-4.23	 HITS_10=0.502+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.06210526315789474, Test Loss: 476.04603544871014
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=482.633, psi=[0.5017827153205872, 0.49539655447006226], loss1 min/max=0.5505/0.5584, loss2 min/max=0.1098/0.1456, integral time stamps=5000, sec/iter=0.2769
# Slot 0: 0 (no events), 1 (613 events): MAR=9.34+-4.22, HITS_10=0.499+-0.387, Com (613 events): MAR=9.34+-4.22, HITS_10=0.499+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.34+-4.22	 HITS_10=0.499+-0.387
# ====== Com       	 (613     events): 	MAR=9.34+-4.22	 HITS_10=0.499+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.06210526315789474, Test Loss: 477.69276213645935
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=490.087, psi=[0.5022639632225037, 0.494650274515152], loss1 min/max=0.5152/0.5225, loss2 min/max=0.1026/0.1509, integral time stamps=5000, sec/iter=0.2873
# Slot 0: 0 (no events), 1 (613 events): MAR=9.34+-4.22, HITS_10=0.495+-0.386, Com (613 events): MAR=9.34+-4.22, HITS_10=0.495+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.34+-4.22	 HITS_10=0.495+-0.386
# ====== Com       	 (613     events): 	MAR=9.34+-4.22	 HITS_10=0.495+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.06210526315789474, Test Loss: 480.1716440200806
# Testing decay_rate: 0.11421052631578947
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=354.478, psi=[0.5004366040229797, 0.5008389353752136], loss1 min/max=0.3111/0.3202, loss2 min/max=0.0530/0.0640, integral time stamps=5000, sec/iter=0.2761
# Slot 0: 0 (no events), 1 (613 events): MAR=9.30+-4.23, HITS_10=0.505+-0.379, Com (613 events): MAR=9.30+-4.23, HITS_10=0.505+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.30+-4.23	 HITS_10=0.505+-0.379
# ====== Com       	 (613     events): 	MAR=9.30+-4.23	 HITS_10=0.505+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.11421052631578947, Test Loss: 354.47767972946167
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=353.869, psi=[0.5009009838104248, 0.5016031265258789], loss1 min/max=0.3516/0.3614, loss2 min/max=0.0565/0.0723, integral time stamps=5000, sec/iter=0.2766
# Slot 0: 0 (no events), 1 (613 events): MAR=9.31+-4.22, HITS_10=0.502+-0.379, Com (613 events): MAR=9.31+-4.22, HITS_10=0.502+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.31+-4.22	 HITS_10=0.502+-0.379
# ====== Com       	 (613     events): 	MAR=9.31+-4.22	 HITS_10=0.502+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.11421052631578947, Test Loss: 354.17333221435547
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=356.492, psi=[0.5013999342918396, 0.5021191239356995], loss1 min/max=0.3830/0.3933, loss2 min/max=0.0603/0.0787, integral time stamps=5000, sec/iter=0.2764
# Slot 0: 0 (no events), 1 (613 events): MAR=9.32+-4.22, HITS_10=0.500+-0.379, Com (613 events): MAR=9.32+-4.22, HITS_10=0.500+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.32+-4.22	 HITS_10=0.500+-0.379
# ====== Com       	 (613     events): 	MAR=9.32+-4.22	 HITS_10=0.500+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.11421052631578947, Test Loss: 354.94627809524536
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=361.021, psi=[0.5019060969352722, 0.5024487376213074], loss1 min/max=0.4052/0.4158, loss2 min/max=0.0643/0.0832, integral time stamps=5000, sec/iter=0.2756
# Slot 0: 0 (no events), 1 (613 events): MAR=9.33+-4.22, HITS_10=0.501+-0.379, Com (613 events): MAR=9.33+-4.22, HITS_10=0.501+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.33+-4.22	 HITS_10=0.501+-0.379
# ====== Com       	 (613     events): 	MAR=9.33+-4.22	 HITS_10=0.501+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.11421052631578947, Test Loss: 356.46493315696716
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=366.622, psi=[0.5024089813232422, 0.5026504397392273], loss1 min/max=0.4200/0.4307, loss2 min/max=0.0686/0.0862, integral time stamps=5000, sec/iter=0.2755
# Slot 0: 0 (no events), 1 (613 events): MAR=9.32+-4.22, HITS_10=0.501+-0.379, Com (613 events): MAR=9.32+-4.22, HITS_10=0.501+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.32+-4.22	 HITS_10=0.501+-0.379
# ====== Com       	 (613     events): 	MAR=9.32+-4.22	 HITS_10=0.501+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.11421052631578947, Test Loss: 358.496272277832
# Testing decay_rate: 0.16631578947368422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=412.115, psi=[0.5004351139068604, 0.5011848211288452], loss1 min/max=0.0933/0.0962, loss2 min/max=0.0148/0.0193, integral time stamps=5000, sec/iter=0.2750
# Slot 0: 0 (no events), 1 (613 events): MAR=9.23+-4.16, HITS_10=0.507+-0.386, Com (613 events): MAR=9.23+-4.16, HITS_10=0.507+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.23+-4.16	 HITS_10=0.507+-0.386
# ====== Com       	 (613     events): 	MAR=9.23+-4.16	 HITS_10=0.507+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.16631578947368422, Test Loss: 412.11495780944824
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=389.957, psi=[0.5008805394172668, 0.5024686455726624], loss1 min/max=0.1135/0.1169, loss2 min/max=0.0157/0.0234, integral time stamps=5000, sec/iter=0.2762
# Slot 0: 0 (no events), 1 (613 events): MAR=9.25+-4.15, HITS_10=0.506+-0.383, Com (613 events): MAR=9.25+-4.15, HITS_10=0.506+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.25+-4.15	 HITS_10=0.506+-0.383
# ====== Com       	 (613     events): 	MAR=9.25+-4.15	 HITS_10=0.506+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.16631578947368422, Test Loss: 401.0361137390137
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=371.170, psi=[0.5013743042945862, 0.5036333203315735], loss1 min/max=0.1358/0.1398, loss2 min/max=0.0168/0.0280, integral time stamps=5000, sec/iter=0.2763
# Slot 0: 0 (no events), 1 (613 events): MAR=9.29+-4.16, HITS_10=0.501+-0.390, Com (613 events): MAR=9.29+-4.16, HITS_10=0.501+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.29+-4.16	 HITS_10=0.501+-0.390
# ====== Com       	 (613     events): 	MAR=9.29+-4.16	 HITS_10=0.501+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.16631578947368422, Test Loss: 391.0808038711548
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=355.618, psi=[0.5018877983093262, 0.5046785473823547], loss1 min/max=0.1597/0.1642, loss2 min/max=0.0179/0.0329, integral time stamps=5000, sec/iter=0.2757
# Slot 0: 0 (no events), 1 (613 events): MAR=9.30+-4.16, HITS_10=0.496+-0.389, Com (613 events): MAR=9.30+-4.16, HITS_10=0.496+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.30+-4.16	 HITS_10=0.496+-0.389
# ====== Com       	 (613     events): 	MAR=9.30+-4.16	 HITS_10=0.496+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.16631578947368422, Test Loss: 382.21521985530853
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=343.107, psi=[0.5024093389511108, 0.5056053996086121], loss1 min/max=0.1846/0.1897, loss2 min/max=0.0191/0.0380, integral time stamps=5000, sec/iter=0.2776
# Slot 0: 0 (no events), 1 (613 events): MAR=9.30+-4.18, HITS_10=0.488+-0.388, Com (613 events): MAR=9.30+-4.18, HITS_10=0.488+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.30+-4.18	 HITS_10=0.488+-0.388
# ====== Com       	 (613     events): 	MAR=9.30+-4.18	 HITS_10=0.488+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.16631578947368422, Test Loss: 374.39353704452515
# Testing decay_rate: 0.21842105263157896
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=526.871, psi=[0.5004259347915649, 0.4988560080528259], loss1 min/max=0.6415/0.6536, loss2 min/max=0.1281/0.1718, integral time stamps=5000, sec/iter=0.2755
# Slot 0: 0 (no events), 1 (613 events): MAR=9.21+-4.15, HITS_10=0.512+-0.378, Com (613 events): MAR=9.21+-4.15, HITS_10=0.512+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.21+-4.15	 HITS_10=0.512+-0.378
# ====== Com       	 (613     events): 	MAR=9.21+-4.15	 HITS_10=0.512+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.21842105263157896, Test Loss: 526.8708181381226
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=530.279, psi=[0.5008549690246582, 0.4978317618370056], loss1 min/max=0.5702/0.5808, loss2 min/max=0.1138/0.1766, integral time stamps=5000, sec/iter=0.2756
# Slot 0: 0 (no events), 1 (613 events): MAR=9.19+-4.14, HITS_10=0.517+-0.375, Com (613 events): MAR=9.19+-4.14, HITS_10=0.517+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.19+-4.14	 HITS_10=0.517+-0.375
# ====== Com       	 (613     events): 	MAR=9.19+-4.14	 HITS_10=0.517+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.21842105263157896, Test Loss: 528.5748991966248
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=536.799, psi=[0.5013269186019897, 0.49703454971313477], loss1 min/max=0.5219/0.5317, loss2 min/max=0.1041/0.1818, integral time stamps=5000, sec/iter=0.2763
# Slot 0: 0 (no events), 1 (613 events): MAR=9.18+-4.13, HITS_10=0.512+-0.373, Com (613 events): MAR=9.18+-4.13, HITS_10=0.512+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.18+-4.13	 HITS_10=0.512+-0.373
# ====== Com       	 (613     events): 	MAR=9.18+-4.13	 HITS_10=0.512+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.21842105263157896, Test Loss: 531.316304842631
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=545.041, psi=[0.5018135905265808, 0.49647486209869385], loss1 min/max=0.4912/0.5007, loss2 min/max=0.0981/0.1873, integral time stamps=5000, sec/iter=0.3227
# Slot 0: 0 (no events), 1 (613 events): MAR=9.17+-4.14, HITS_10=0.511+-0.373, Com (613 events): MAR=9.17+-4.14, HITS_10=0.511+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.17+-4.14	 HITS_10=0.511+-0.373
# ====== Com       	 (613     events): 	MAR=9.17+-4.14	 HITS_10=0.511+-0.373
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.21842105263157896, Test Loss: 534.7473545074463
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=554.218, psi=[0.5023030042648315, 0.4961091876029968], loss1 min/max=0.4727/0.4820, loss2 min/max=0.0943/0.1932, integral time stamps=5000, sec/iter=0.2783
# Slot 0: 0 (no events), 1 (613 events): MAR=9.16+-4.13, HITS_10=0.512+-0.374, Com (613 events): MAR=9.16+-4.13, HITS_10=0.512+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.16+-4.13	 HITS_10=0.512+-0.374
# ====== Com       	 (613     events): 	MAR=9.16+-4.13	 HITS_10=0.512+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.21842105263157896, Test Loss: 538.6415588378907
# Testing decay_rate: 0.2705263157894737
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=570.277, psi=[0.5004235506057739, 0.4996214807033539], loss1 min/max=0.4958/0.5015, loss2 min/max=0.0991/0.2038, integral time stamps=5000, sec/iter=0.2758
# Slot 0: 0 (no events), 1 (613 events): MAR=9.02+-4.04, HITS_10=0.528+-0.366, Com (613 events): MAR=9.02+-4.04, HITS_10=0.528+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.02+-4.04	 HITS_10=0.528+-0.366
# ====== Com       	 (613     events): 	MAR=9.02+-4.04	 HITS_10=0.528+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.2705263157894737, Test Loss: 570.2772769927979
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=581.949, psi=[0.5008400678634644, 0.49926576018333435], loss1 min/max=0.4828/0.4886, loss2 min/max=0.0965/0.2113, integral time stamps=5000, sec/iter=0.2755
# Slot 0: 0 (no events), 1 (613 events): MAR=9.01+-4.05, HITS_10=0.529+-0.365, Com (613 events): MAR=9.01+-4.05, HITS_10=0.529+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.529+-0.365
# ====== Com       	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.529+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.2705263157894737, Test Loss: 576.1131176948547
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=595.902, psi=[0.5012949109077454, 0.4989570379257202], loss1 min/max=0.4761/0.4822, loss2 min/max=0.0951/0.2205, integral time stamps=5000, sec/iter=0.2963
# Slot 0: 0 (no events), 1 (613 events): MAR=9.01+-4.05, HITS_10=0.525+-0.364, Com (613 events): MAR=9.01+-4.05, HITS_10=0.525+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.525+-0.364
# ====== Com       	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.525+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.2705263157894737, Test Loss: 582.7092987696329
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=610.782, psi=[0.5017572045326233, 0.49868205189704895], loss1 min/max=0.4724/0.4789, loss2 min/max=0.0944/0.2302, integral time stamps=5000, sec/iter=0.2756
# Slot 0: 0 (no events), 1 (613 events): MAR=9.00+-4.05, HITS_10=0.526+-0.365, Com (613 events): MAR=9.00+-4.05, HITS_10=0.526+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.00+-4.05	 HITS_10=0.526+-0.365
# ====== Com       	 (613     events): 	MAR=9.00+-4.05	 HITS_10=0.526+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.2705263157894737, Test Loss: 589.7274079322815
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=625.984, psi=[0.5022153258323669, 0.4984268248081207], loss1 min/max=0.4702/0.4768, loss2 min/max=0.0939/0.2400, integral time stamps=5000, sec/iter=0.2772
# Slot 0: 0 (no events), 1 (613 events): MAR=9.01+-4.05, HITS_10=0.526+-0.363, Com (613 events): MAR=9.01+-4.05, HITS_10=0.526+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.526+-0.363
# ====== Com       	 (613     events): 	MAR=9.01+-4.05	 HITS_10=0.526+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.2705263157894737, Test Loss: 596.9787197113037
# Testing decay_rate: 0.32263157894736844
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=533.690, psi=[0.5004250407218933, 0.5011612772941589], loss1 min/max=0.1387/0.1437, loss2 min/max=0.0277/0.1257, integral time stamps=5000, sec/iter=0.2776
# Slot 0: 0 (no events), 1 (613 events): MAR=9.40+-4.27, HITS_10=0.496+-0.389, Com (613 events): MAR=9.40+-4.27, HITS_10=0.496+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.40+-4.27	 HITS_10=0.496+-0.389
# ====== Com       	 (613     events): 	MAR=9.40+-4.27	 HITS_10=0.496+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.32263157894736844, Test Loss: 533.689528465271
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=523.661, psi=[0.5007960796356201, 0.5023642182350159], loss1 min/max=0.1688/0.1746, loss2 min/max=0.0335/0.1325, integral time stamps=5000, sec/iter=0.2750
# Slot 0: 0 (no events), 1 (613 events): MAR=9.39+-4.28, HITS_10=0.500+-0.391, Com (613 events): MAR=9.39+-4.28, HITS_10=0.500+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.39+-4.28	 HITS_10=0.500+-0.391
# ====== Com       	 (613     events): 	MAR=9.39+-4.28	 HITS_10=0.500+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.32263157894736844, Test Loss: 528.6755018234253
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=518.406, psi=[0.5012094974517822, 0.5034016966819763], loss1 min/max=0.2010/0.2075, loss2 min/max=0.0402/0.1398, integral time stamps=5000, sec/iter=0.2763
# Slot 0: 0 (no events), 1 (613 events): MAR=9.35+-4.28, HITS_10=0.496+-0.394, Com (613 events): MAR=9.35+-4.28, HITS_10=0.496+-0.394
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.35+-4.28	 HITS_10=0.496+-0.394
# ====== Com       	 (613     events): 	MAR=9.35+-4.28	 HITS_10=0.496+-0.394
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.32263157894736844, Test Loss: 525.2522859573364
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=517.298, psi=[0.5016354322433472, 0.5042774081230164], loss1 min/max=0.2338/0.2411, loss2 min/max=0.0465/0.1475, integral time stamps=5000, sec/iter=0.2751
# Slot 0: 0 (no events), 1 (613 events): MAR=9.33+-4.27, HITS_10=0.498+-0.391, Com (613 events): MAR=9.33+-4.27, HITS_10=0.498+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.33+-4.27	 HITS_10=0.498+-0.391
# ====== Com       	 (613     events): 	MAR=9.33+-4.27	 HITS_10=0.498+-0.391
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.32263157894736844, Test Loss: 523.2636952400208
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=519.654, psi=[0.5020610690116882, 0.505000114440918], loss1 min/max=0.2660/0.2739, loss2 min/max=0.0529/0.1554, integral time stamps=5000, sec/iter=0.2750
# Slot 0: 0 (no events), 1 (613 events): MAR=9.32+-4.25, HITS_10=0.500+-0.390, Com (613 events): MAR=9.32+-4.25, HITS_10=0.500+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.32+-4.25	 HITS_10=0.500+-0.390
# ====== Com       	 (613     events): 	MAR=9.32+-4.25	 HITS_10=0.500+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.32263157894736844, Test Loss: 522.5418296813965
# Testing decay_rate: 0.37473684210526315
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=1057.875, psi=[0.5004110932350159, 0.5016037821769714], loss1 min/max=0.0476/0.0491, loss2 min/max=0.0095/0.3795, integral time stamps=5000, sec/iter=0.2751
# Slot 0: 0 (no events), 1 (613 events): MAR=8.99+-4.11, HITS_10=0.530+-0.369, Com (613 events): MAR=8.99+-4.11, HITS_10=0.530+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=8.99+-4.11	 HITS_10=0.530+-0.369
# ====== Com       	 (613     events): 	MAR=8.99+-4.11	 HITS_10=0.530+-0.369
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.37473684210526315, Test Loss: 1057.8754329681396
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=1025.416, psi=[0.5008588433265686, 0.5029342174530029], loss1 min/max=0.0611/0.0631, loss2 min/max=0.0122/0.3805, integral time stamps=5000, sec/iter=0.2754
# Slot 0: 0 (no events), 1 (613 events): MAR=9.06+-4.12, HITS_10=0.527+-0.374, Com (613 events): MAR=9.06+-4.12, HITS_10=0.527+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.06+-4.12	 HITS_10=0.527+-0.374
# ====== Com       	 (613     events): 	MAR=9.06+-4.12	 HITS_10=0.527+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.37473684210526315, Test Loss: 1041.64582157135
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=997.488, psi=[0.5013522505760193, 0.5041640400886536], loss1 min/max=0.0775/0.0801, loss2 min/max=0.0155/0.3825, integral time stamps=5000, sec/iter=0.2751
# Slot 0: 0 (no events), 1 (613 events): MAR=9.07+-4.13, HITS_10=0.530+-0.378, Com (613 events): MAR=9.07+-4.13, HITS_10=0.530+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.07+-4.13	 HITS_10=0.530+-0.378
# ====== Com       	 (613     events): 	MAR=9.07+-4.13	 HITS_10=0.530+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.37473684210526315, Test Loss: 1026.9264227549236
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=974.013, psi=[0.5018652081489563, 0.5052873492240906], loss1 min/max=0.0968/0.1001, loss2 min/max=0.0194/0.3855, integral time stamps=5000, sec/iter=0.2768
# Slot 0: 0 (no events), 1 (613 events): MAR=9.10+-4.12, HITS_10=0.531+-0.374, Com (613 events): MAR=9.10+-4.12, HITS_10=0.531+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.10+-4.12	 HITS_10=0.531+-0.374
# ====== Com       	 (613     events): 	MAR=9.10+-4.12	 HITS_10=0.531+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.37473684210526315, Test Loss: 1013.6980233192444
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=954.986, psi=[0.5023869872093201, 0.5062982439994812], loss1 min/max=0.1192/0.1232, loss2 min/max=0.0238/0.3892, integral time stamps=5000, sec/iter=0.2768
# Slot 0: 0 (no events), 1 (613 events): MAR=9.11+-4.12, HITS_10=0.526+-0.374, Com (613 events): MAR=9.11+-4.12, HITS_10=0.526+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.11+-4.12	 HITS_10=0.526+-0.374
# ====== Com       	 (613     events): 	MAR=9.11+-4.12	 HITS_10=0.526+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.37473684210526315, Test Loss: 1001.9555660247803
# Testing decay_rate: 0.4268421052631579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=607.832, psi=[0.5004375576972961, 0.5005168914794922], loss1 min/max=0.4064/0.4116, loss2 min/max=0.0811/0.2263, integral time stamps=5000, sec/iter=0.2756
# Slot 0: 0 (no events), 1 (613 events): MAR=9.19+-4.12, HITS_10=0.512+-0.372, Com (613 events): MAR=9.19+-4.12, HITS_10=0.512+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.19+-4.12	 HITS_10=0.512+-0.372
# ====== Com       	 (613     events): 	MAR=9.19+-4.12	 HITS_10=0.512+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4268421052631579, Test Loss: 607.8316783905029
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=617.970, psi=[0.500956118106842, 0.5008112788200378], loss1 min/max=0.4289/0.4333, loss2 min/max=0.0856/0.2339, integral time stamps=5000, sec/iter=0.2763
# Slot 0: 0 (no events), 1 (613 events): MAR=9.17+-4.10, HITS_10=0.508+-0.370, Com (613 events): MAR=9.17+-4.10, HITS_10=0.508+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.508+-0.370
# ====== Com       	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.508+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4268421052631579, Test Loss: 612.9010057449341
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=628.752, psi=[0.5014876127243042, 0.5009361505508423], loss1 min/max=0.4411/0.4455, loss2 min/max=0.0881/0.2413, integral time stamps=5000, sec/iter=0.2751
# Slot 0: 0 (no events), 1 (613 events): MAR=9.17+-4.10, HITS_10=0.504+-0.370, Com (613 events): MAR=9.17+-4.10, HITS_10=0.504+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.504+-0.370
# ====== Com       	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.504+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4268421052631579, Test Loss: 618.184827486674
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=639.689, psi=[0.502014696598053, 0.500969648361206], loss1 min/max=0.4476/0.4519, loss2 min/max=0.0894/0.2485, integral time stamps=5000, sec/iter=0.2750
# Slot 0: 0 (no events), 1 (613 events): MAR=9.16+-4.11, HITS_10=0.509+-0.372, Com (613 events): MAR=9.16+-4.11, HITS_10=0.509+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.16+-4.11	 HITS_10=0.509+-0.372
# ====== Com       	 (613     events): 	MAR=9.16+-4.11	 HITS_10=0.509+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.4268421052631579, Test Loss: 623.5609447956085
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=650.687, psi=[0.5025321245193481, 0.5009528398513794], loss1 min/max=0.4511/0.4553, loss2 min/max=0.0901/0.2555, integral time stamps=5000, sec/iter=0.2810
# Slot 0: 0 (no events), 1 (613 events): MAR=9.17+-4.10, HITS_10=0.509+-0.371, Com (613 events): MAR=9.17+-4.10, HITS_10=0.509+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.509+-0.371
# ====== Com       	 (613     events): 	MAR=9.17+-4.10	 HITS_10=0.509+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.4268421052631579, Test Loss: 628.9861661911011
# Testing decay_rate: 0.4789473684210527
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=479.302, psi=[0.500436544418335, 0.5002214908599854], loss1 min/max=0.4315/0.4390, loss2 min/max=0.0862/0.1430, integral time stamps=5000, sec/iter=0.2764
# Slot 0: 0 (no events), 1 (613 events): MAR=8.99+-4.12, HITS_10=0.529+-0.370, Com (613 events): MAR=8.99+-4.12, HITS_10=0.529+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=8.99+-4.12	 HITS_10=0.529+-0.370
# ====== Com       	 (613     events): 	MAR=8.99+-4.12	 HITS_10=0.529+-0.370
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4789473684210527, Test Loss: 479.30207347869873
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=490.896, psi=[0.5009291768074036, 0.5002981424331665], loss1 min/max=0.4495/0.4561, loss2 min/max=0.0899/0.1510, integral time stamps=5000, sec/iter=0.2859
# Slot 0: 0 (no events), 1 (613 events): MAR=8.99+-4.12, HITS_10=0.524+-0.372, Com (613 events): MAR=8.99+-4.12, HITS_10=0.524+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=8.99+-4.12	 HITS_10=0.524+-0.372
# ====== Com       	 (613     events): 	MAR=8.99+-4.12	 HITS_10=0.524+-0.372
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4789473684210527, Test Loss: 485.0989260673523
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=502.559, psi=[0.501438319683075, 0.5002405047416687], loss1 min/max=0.4581/0.4645, loss2 min/max=0.0916/0.1588, integral time stamps=5000, sec/iter=0.2777
# Slot 0: 0 (no events), 1 (613 events): MAR=8.98+-4.11, HITS_10=0.525+-0.371, Com (613 events): MAR=8.98+-4.11, HITS_10=0.525+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=8.98+-4.11	 HITS_10=0.525+-0.371
# ====== Com       	 (613     events): 	MAR=8.98+-4.11	 HITS_10=0.525+-0.371
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4789473684210527, Test Loss: 490.918984413147
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# ...
# ====== 1         	 (613     events): 	MAR=9.31+-4.19	 HITS_10=0.493+-0.390
# ====== Com       	 (613     events): 	MAR=9.31+-4.19	 HITS_10=0.493+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8436842105263158, Test Loss: 317.2480607032776
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=329.655, psi=[0.5024226903915405, 0.4978608787059784], loss1 min/max=0.4606/0.4671, loss2 min/max=0.0454/0.0935, integral time stamps=5000, sec/iter=0.2823
# Slot 0: 0 (no events), 1 (613 events): MAR=9.31+-4.19, HITS_10=0.492+-0.389, Com (613 events): MAR=9.31+-4.19, HITS_10=0.492+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.31+-4.19	 HITS_10=0.492+-0.389
# ====== Com       	 (613     events): 	MAR=9.31+-4.19	 HITS_10=0.492+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8436842105263158, Test Loss: 319.72935581207275
# Testing decay_rate: 0.8957894736842106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=498.855, psi=[0.500433087348938, 0.498494416475296], loss1 min/max=1.2868/1.2984, loss2 min/max=0.0906/0.2598, integral time stamps=5000, sec/iter=0.2821
# Slot 0: 0 (no events), 1 (613 events): MAR=9.24+-4.28, HITS_10=0.483+-0.386, Com (613 events): MAR=9.24+-4.28, HITS_10=0.483+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.24+-4.28	 HITS_10=0.483+-0.386
# ====== Com       	 (613     events): 	MAR=9.24+-4.28	 HITS_10=0.483+-0.386
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.8957894736842106, Test Loss: 498.8550224304199
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=485.293, psi=[0.5008992552757263, 0.49690982699394226], loss1 min/max=1.1758/1.1873, loss2 min/max=0.0954/0.2376, integral time stamps=5000, sec/iter=0.2910
# Slot 0: 0 (no events), 1 (613 events): MAR=9.24+-4.29, HITS_10=0.486+-0.381, Com (613 events): MAR=9.24+-4.29, HITS_10=0.486+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.24+-4.29	 HITS_10=0.486+-0.381
# ====== Com       	 (613     events): 	MAR=9.24+-4.29	 HITS_10=0.486+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.8957894736842106, Test Loss: 492.0739736557007
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=474.846, psi=[0.5013998746871948, 0.495272159576416], loss1 min/max=1.0727/1.0844, loss2 min/max=0.0995/0.2170, integral time stamps=5000, sec/iter=0.2813
# Slot 0: 0 (no events), 1 (613 events): MAR=9.22+-4.24, HITS_10=0.491+-0.378, Com (613 events): MAR=9.22+-4.24, HITS_10=0.491+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.22+-4.24	 HITS_10=0.491+-0.378
# ====== Com       	 (613     events): 	MAR=9.22+-4.24	 HITS_10=0.491+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.8957894736842106, Test Loss: 486.33145173390704
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=467.430, psi=[0.5019086003303528, 0.49360886216163635], loss1 min/max=0.9782/0.9897, loss2 min/max=0.1046/0.1980, integral time stamps=5000, sec/iter=0.2788
# Slot 0: 0 (no events), 1 (613 events): MAR=9.22+-4.26, HITS_10=0.498+-0.378, Com (613 events): MAR=9.22+-4.26, HITS_10=0.498+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.22+-4.26	 HITS_10=0.498+-0.378
# ====== Com       	 (613     events): 	MAR=9.22+-4.26	 HITS_10=0.498+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8957894736842106, Test Loss: 481.6061022281647
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=462.920, psi=[0.5024151802062988, 0.49194902181625366], loss1 min/max=0.8928/0.9041, loss2 min/max=0.1093/0.1809, integral time stamps=5000, sec/iter=0.2764
# Slot 0: 0 (no events), 1 (613 events): MAR=9.20+-4.27, HITS_10=0.505+-0.380, Com (613 events): MAR=9.20+-4.27, HITS_10=0.505+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.20+-4.27	 HITS_10=0.505+-0.380
# ====== Com       	 (613     events): 	MAR=9.20+-4.27	 HITS_10=0.505+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8957894736842106, Test Loss: 477.8688180923462
# Testing decay_rate: 0.9478947368421053
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=326.805, psi=[0.5004406571388245, 0.4998253881931305], loss1 min/max=0.4760/0.4789, loss2 min/max=0.0431/0.0958, integral time stamps=5000, sec/iter=0.2762
# Slot 0: 0 (no events), 1 (613 events): MAR=9.23+-4.28, HITS_10=0.502+-0.387, Com (613 events): MAR=9.23+-4.28, HITS_10=0.502+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.23+-4.28	 HITS_10=0.502+-0.387
# ====== Com       	 (613     events): 	MAR=9.23+-4.28	 HITS_10=0.502+-0.387
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.9478947368421053, Test Loss: 326.80452251434326
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=332.716, psi=[0.5009260773658752, 0.4995834231376648], loss1 min/max=0.4715/0.4744, loss2 min/max=0.0469/0.0949, integral time stamps=5000, sec/iter=0.2764
# Slot 0: 0 (no events), 1 (613 events): MAR=9.22+-4.30, HITS_10=0.506+-0.388, Com (613 events): MAR=9.22+-4.30, HITS_10=0.506+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.22+-4.30	 HITS_10=0.506+-0.388
# ====== Com       	 (613     events): 	MAR=9.22+-4.30	 HITS_10=0.506+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.9478947368421053, Test Loss: 329.76030111312866
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=339.295, psi=[0.501438319683075, 0.49934834241867065], loss1 min/max=0.4684/0.4712, loss2 min/max=0.0513/0.0943, integral time stamps=5000, sec/iter=0.2832
# Slot 0: 0 (no events), 1 (613 events): MAR=9.21+-4.28, HITS_10=0.499+-0.383, Com (613 events): MAR=9.21+-4.28, HITS_10=0.499+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.21+-4.28	 HITS_10=0.499+-0.383
# ====== Com       	 (613     events): 	MAR=9.21+-4.28	 HITS_10=0.499+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.9478947368421053, Test Loss: 332.93848784764606
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=346.447, psi=[0.5019515156745911, 0.49912789463996887], loss1 min/max=0.4665/0.4692, loss2 min/max=0.0557/0.0938, integral time stamps=5000, sec/iter=0.2771
# Slot 0: 0 (no events), 1 (613 events): MAR=9.17+-4.29, HITS_10=0.504+-0.378, Com (613 events): MAR=9.17+-4.29, HITS_10=0.504+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.17+-4.29	 HITS_10=0.504+-0.378
# ====== Com       	 (613     events): 	MAR=9.17+-4.29	 HITS_10=0.504+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.9478947368421053, Test Loss: 336.31558787822723
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=354.104, psi=[0.5024557113647461, 0.4989205598831177], loss1 min/max=0.4653/0.4679, loss2 min/max=0.0607/0.0936, integral time stamps=5000, sec/iter=0.2772
# Slot 0: 0 (no events), 1 (613 events): MAR=9.14+-4.31, HITS_10=0.508+-0.383, Com (613 events): MAR=9.14+-4.31, HITS_10=0.508+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.14+-4.31	 HITS_10=0.508+-0.383
# ====== Com       	 (613     events): 	MAR=9.14+-4.31	 HITS_10=0.508+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.9478947368421053, Test Loss: 339.87333555221556
# Testing decay_rate: 1.0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=370.154, psi=[0.5004351139068604, 0.5010868310928345], loss1 min/max=0.1899/0.1973, loss2 min/max=0.0380/0.0395, integral time stamps=5000, sec/iter=0.2763
# Slot 0: 0 (no events), 1 (613 events): MAR=9.01+-4.18, HITS_10=0.532+-0.375, Com (613 events): MAR=9.01+-4.18, HITS_10=0.532+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.01+-4.18	 HITS_10=0.532+-0.375
# ====== Com       	 (613     events): 	MAR=9.01+-4.18	 HITS_10=0.532+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 1.0, Test Loss: 370.15357780456543
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=358.435, psi=[0.5008886456489563, 0.5021946430206299], loss1 min/max=0.2280/0.2364, loss2 min/max=0.0409/0.0473, integral time stamps=5000, sec/iter=0.2821
# Slot 0: 0 (no events), 1 (613 events): MAR=9.02+-4.18, HITS_10=0.527+-0.376, Com (613 events): MAR=9.02+-4.18, HITS_10=0.527+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.02+-4.18	 HITS_10=0.527+-0.376
# ====== Com       	 (613     events): 	MAR=9.02+-4.18	 HITS_10=0.527+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 1.0, Test Loss: 364.29421305656433
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=351.396, psi=[0.5013811588287354, 0.5031011700630188], loss1 min/max=0.2657/0.2750, loss2 min/max=0.0439/0.0555, integral time stamps=5000, sec/iter=0.2769
# Slot 0: 0 (no events), 1 (613 events): MAR=9.02+-4.20, HITS_10=0.529+-0.380, Com (613 events): MAR=9.02+-4.20, HITS_10=0.529+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.02+-4.20	 HITS_10=0.529+-0.380
# ====== Com       	 (613     events): 	MAR=9.02+-4.20	 HITS_10=0.529+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 1.0, Test Loss: 359.9947603543599
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=348.157, psi=[0.5018852353096008, 0.5038214325904846], loss1 min/max=0.3010/0.3112, loss2 min/max=0.0471/0.0627, integral time stamps=5000, sec/iter=0.2820
# Slot 0: 0 (no events), 1 (613 events): MAR=9.00+-4.19, HITS_10=0.535+-0.377, Com (613 events): MAR=9.00+-4.19, HITS_10=0.535+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.00+-4.19	 HITS_10=0.535+-0.377
# ====== Com       	 (613     events): 	MAR=9.00+-4.19	 HITS_10=0.535+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 1.0, Test Loss: 357.0353037118912
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=347.822, psi=[0.5023898482322693, 0.5043788552284241], loss1 min/max=0.3325/0.3433, loss2 min/max=0.0504/0.0687, integral time stamps=5000, sec/iter=0.2769
# Slot 0: 0 (no events), 1 (613 events): MAR=9.01+-4.16, HITS_10=0.529+-0.376, Com (613 events): MAR=9.01+-4.16, HITS_10=0.529+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (613     events): 	MAR=9.01+-4.16	 HITS_10=0.529+-0.376
# ====== Com       	 (613     events): 	MAR=9.01+-4.16	 HITS_10=0.529+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 1.0, Test Loss: 355.19260625839235
# Best decay_rate: 0.7394736842105263 with loss: 312.4558792114258

# %%
decay_rates = np.linspace(0.01, 1.0, 20)  # Example range of decay rates
best_decay_rate, best_loss = grid_search_decay_rate(data_dir='/Users/amberrrrrr/Desktop/huozhe/simulated_data/final_hawkes_process_events_0.5.csv', decay_rates=decay_rates, epochs=5)
print(f"Best decay_rate: {best_decay_rate} with loss: {best_loss}")
# Out:
# A_initial 0.0
#
# A_initial 0.0
# Testing decay_rate: 0.01
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/1088651520.py:26: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   hits_10.append(np.mean([float(rank1[0] <= 9), float(rank2[0] <= 9)]))
# test 0
#
# TEST batch=4/4, loss=479.185, psi=[0.5004487037658691, 0.49868544936180115], loss1 min/max=1.6969/1.7112, loss2 min/max=0.0086/0.3431, integral time stamps=5000, sec/iter=0.3734
# Slot 0: 0 (no events), 1 (648 events): MAR=9.05+-3.96, HITS_10=0.530+-0.363, Com (648 events): MAR=9.05+-3.96, HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.05+-3.96	 HITS_10=0.530+-0.363
# ====== Com       	 (648     events): 	MAR=9.05+-3.96	 HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.01, Test Loss: 479.185359954834
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# /var/folders/1t/0v2zn4w16nbbv578tpkxbmhr0000gn/T/ipykernel_11799/71941381.py:248: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   b_prime = 1. / (float(self.node_degree_global[rel][j]) + 1e-7)
# test 0
#
# TEST batch=4/4, loss=446.566, psi=[0.5009679794311523, 0.4971216022968292], loss1 min/max=1.5450/1.5576, loss2 min/max=0.0096/0.3121, integral time stamps=5000, sec/iter=0.3840
# Slot 0: 0 (no events), 1 (648 events): MAR=9.06+-3.98, HITS_10=0.532+-0.363, Com (648 events): MAR=9.06+-3.98, HITS_10=0.532+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.06+-3.98	 HITS_10=0.532+-0.363
# ====== Com       	 (648     events): 	MAR=9.06+-3.98	 HITS_10=0.532+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.01, Test Loss: 462.8755588531494
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=417.352, psi=[0.5015159845352173, 0.4953615963459015], loss1 min/max=1.4012/1.4125, loss2 min/max=0.0106/0.2831, integral time stamps=5000, sec/iter=0.2908
# Slot 0: 0 (no events), 1 (648 events): MAR=9.04+-4.02, HITS_10=0.534+-0.365, Com (648 events): MAR=9.04+-4.02, HITS_10=0.534+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.04+-4.02	 HITS_10=0.534+-0.365
# ====== Com       	 (648     events): 	MAR=9.04+-4.02	 HITS_10=0.534+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.01, Test Loss: 447.70118459065753
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=391.450, psi=[0.5020707845687866, 0.49346923828125], loss1 min/max=1.2647/1.2750, loss2 min/max=0.0117/0.2554, integral time stamps=5000, sec/iter=0.2858
# Slot 0: 0 (no events), 1 (648 events): MAR=9.07+-4.04, HITS_10=0.530+-0.364, Com (648 events): MAR=9.07+-4.04, HITS_10=0.530+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.07+-4.04	 HITS_10=0.530+-0.364
# ====== Com       	 (648     events): 	MAR=9.07+-4.04	 HITS_10=0.530+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.01, Test Loss: 433.6382808685303
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=369.512, psi=[0.5026243925094604, 0.49149081110954285], loss1 min/max=1.1389/1.1481, loss2 min/max=0.0129/0.2299, integral time stamps=5000, sec/iter=0.2936
# Slot 0: 0 (no events), 1 (648 events): MAR=9.06+-4.09, HITS_10=0.530+-0.363, Com (648 events): MAR=9.06+-4.09, HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.06+-4.09	 HITS_10=0.530+-0.363
# ====== Com       	 (648     events): 	MAR=9.06+-4.09	 HITS_10=0.530+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.01, Test Loss: 420.81302337646486
# Testing decay_rate: 0.06210526315789474
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=342.353, psi=[0.5004538297653198, 0.4987804889678955], loss1 min/max=0.6934/0.7049, loss2 min/max=0.0357/0.1419, integral time stamps=5000, sec/iter=0.3136
# Slot 0: 0 (no events), 1 (648 events): MAR=9.02+-4.16, HITS_10=0.521+-0.364, Com (648 events): MAR=9.02+-4.16, HITS_10=0.521+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.02+-4.16	 HITS_10=0.521+-0.364
# ====== Com       	 (648     events): 	MAR=9.02+-4.16	 HITS_10=0.521+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.06210526315789474, Test Loss: 342.3533821105957
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=340.260, psi=[0.5010033249855042, 0.4975861608982086], loss1 min/max=0.6234/0.6342, loss2 min/max=0.0379/0.1278, integral time stamps=5000, sec/iter=0.2899
# Slot 0: 0 (no events), 1 (648 events): MAR=9.01+-4.18, HITS_10=0.522+-0.360, Com (648 events): MAR=9.01+-4.18, HITS_10=0.522+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.01+-4.18	 HITS_10=0.522+-0.360
# ====== Com       	 (648     events): 	MAR=9.01+-4.18	 HITS_10=0.522+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.06210526315789474, Test Loss: 341.3066644668579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=341.267, psi=[0.5015705227851868, 0.4965397119522095], loss1 min/max=0.5701/0.5804, loss2 min/max=0.0402/0.1169, integral time stamps=5000, sec/iter=0.2910
# Slot 0: 0 (no events), 1 (648 events): MAR=8.99+-4.19, HITS_10=0.529+-0.360, Com (648 events): MAR=8.99+-4.19, HITS_10=0.529+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.99+-4.19	 HITS_10=0.529+-0.360
# ====== Com       	 (648     events): 	MAR=8.99+-4.19	 HITS_10=0.529+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.06210526315789474, Test Loss: 341.2935988108317
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=344.402, psi=[0.502137303352356, 0.4956847131252289], loss1 min/max=0.5315/0.5413, loss2 min/max=0.0429/0.1096, integral time stamps=5000, sec/iter=0.2919
# Slot 0: 0 (no events), 1 (648 events): MAR=8.98+-4.22, HITS_10=0.528+-0.361, Com (648 events): MAR=8.98+-4.22, HITS_10=0.528+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.98+-4.22	 HITS_10=0.528+-0.361
# ====== Com       	 (648     events): 	MAR=8.98+-4.22	 HITS_10=0.528+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.06210526315789474, Test Loss: 342.0707297325134
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=348.915, psi=[0.5026968717575073, 0.49501773715019226], loss1 min/max=0.5049/0.5144, loss2 min/max=0.0459/0.1041, integral time stamps=5000, sec/iter=0.2928
# Slot 0: 0 (no events), 1 (648 events): MAR=9.00+-4.23, HITS_10=0.526+-0.364, Com (648 events): MAR=9.00+-4.23, HITS_10=0.526+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.00+-4.23	 HITS_10=0.526+-0.364
# ====== Com       	 (648     events): 	MAR=9.00+-4.23	 HITS_10=0.526+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.06210526315789474, Test Loss: 343.43949165344236
# Testing decay_rate: 0.11421052631578947
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=323.512, psi=[0.5004592537879944, 0.49877387285232544], loss1 min/max=0.7444/0.7555, loss2 min/max=0.0201/0.1511, integral time stamps=5000, sec/iter=0.2953
# Slot 0: 0 (no events), 1 (648 events): MAR=9.32+-4.30, HITS_10=0.498+-0.379, Com (648 events): MAR=9.32+-4.30, HITS_10=0.498+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.32+-4.30	 HITS_10=0.498+-0.379
# ====== Com       	 (648     events): 	MAR=9.32+-4.30	 HITS_10=0.498+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.11421052631578947, Test Loss: 323.5124168395996
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=318.653, psi=[0.5010339617729187, 0.49752455949783325], loss1 min/max=0.6694/0.6784, loss2 min/max=0.0214/0.1357, integral time stamps=5000, sec/iter=0.3065
# Slot 0: 0 (no events), 1 (648 events): MAR=9.31+-4.29, HITS_10=0.496+-0.378, Com (648 events): MAR=9.31+-4.29, HITS_10=0.496+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.31+-4.29	 HITS_10=0.496+-0.378
# ====== Com       	 (648     events): 	MAR=9.31+-4.29	 HITS_10=0.496+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.11421052631578947, Test Loss: 321.0827751159668
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=317.018, psi=[0.5016191601753235, 0.49636703729629517], loss1 min/max=0.6099/0.6176, loss2 min/max=0.0230/0.1236, integral time stamps=5000, sec/iter=0.3487
# Slot 0: 0 (no events), 1 (648 events): MAR=9.32+-4.30, HITS_10=0.491+-0.380, Com (648 events): MAR=9.32+-4.30, HITS_10=0.491+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.32+-4.30	 HITS_10=0.491+-0.380
# ====== Com       	 (648     events): 	MAR=9.32+-4.30	 HITS_10=0.491+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.11421052631578947, Test Loss: 319.7277495066325
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=317.815, psi=[0.5022013783454895, 0.49536067247390747], loss1 min/max=0.5645/0.5712, loss2 min/max=0.0248/0.1143, integral time stamps=5000, sec/iter=0.3083
# Slot 0: 0 (no events), 1 (648 events): MAR=9.30+-4.24, HITS_10=0.496+-0.378, Com (648 events): MAR=9.30+-4.24, HITS_10=0.496+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.30+-4.24	 HITS_10=0.496+-0.378
# ====== Com       	 (648     events): 	MAR=9.30+-4.24	 HITS_10=0.496+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.11421052631578947, Test Loss: 319.2496666908264
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=320.294, psi=[0.5027753710746765, 0.4945232570171356], loss1 min/max=0.5310/0.5369, loss2 min/max=0.0270/0.1074, integral time stamps=5000, sec/iter=0.2967
# Slot 0: 0 (no events), 1 (648 events): MAR=9.30+-4.23, HITS_10=0.497+-0.381, Com (648 events): MAR=9.30+-4.23, HITS_10=0.497+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.30+-4.23	 HITS_10=0.497+-0.381
# ====== Com       	 (648     events): 	MAR=9.30+-4.23	 HITS_10=0.497+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.11421052631578947, Test Loss: 319.45858573913574
# Testing decay_rate: 0.16631578947368422
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=341.784, psi=[0.5004387497901917, 0.498695433139801], loss1 min/max=0.7365/0.7477, loss2 min/max=0.0326/0.1496, integral time stamps=5000, sec/iter=0.4443
# Slot 0: 0 (no events), 1 (648 events): MAR=9.36+-4.20, HITS_10=0.492+-0.378, Com (648 events): MAR=9.36+-4.20, HITS_10=0.492+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.36+-4.20	 HITS_10=0.492+-0.378
# ====== Com       	 (648     events): 	MAR=9.36+-4.20	 HITS_10=0.492+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.16631578947368422, Test Loss: 341.78405952453613
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=338.032, psi=[0.5008817911148071, 0.4973776340484619], loss1 min/max=0.6746/0.6842, loss2 min/max=0.0339/0.1369, integral time stamps=5000, sec/iter=0.3037
# Slot 0: 0 (no events), 1 (648 events): MAR=9.36+-4.19, HITS_10=0.491+-0.376, Com (648 events): MAR=9.36+-4.19, HITS_10=0.491+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.36+-4.19	 HITS_10=0.491+-0.376
# ====== Com       	 (648     events): 	MAR=9.36+-4.19	 HITS_10=0.491+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.16631578947368422, Test Loss: 339.9077854156494
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=336.832, psi=[0.5013750791549683, 0.4961507320404053], loss1 min/max=0.6233/0.6319, loss2 min/max=0.0355/0.1264, integral time stamps=5000, sec/iter=0.2946
# Slot 0: 0 (no events), 1 (648 events): MAR=9.36+-4.19, HITS_10=0.491+-0.376, Com (648 events): MAR=9.36+-4.19, HITS_10=0.491+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.36+-4.19	 HITS_10=0.491+-0.376
# ====== Com       	 (648     events): 	MAR=9.36+-4.19	 HITS_10=0.491+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.16631578947368422, Test Loss: 338.88257280985516
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=337.654, psi=[0.5018881559371948, 0.4950503408908844], loss1 min/max=0.5821/0.5898, loss2 min/max=0.0375/0.1180, integral time stamps=5000, sec/iter=0.3277
# Slot 0: 0 (no events), 1 (648 events): MAR=9.37+-4.20, HITS_10=0.488+-0.375, Com (648 events): MAR=9.37+-4.20, HITS_10=0.488+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.37+-4.20	 HITS_10=0.488+-0.375
# ====== Com       	 (648     events): 	MAR=9.37+-4.20	 HITS_10=0.488+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.16631578947368422, Test Loss: 338.57548236846924
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=340.050, psi=[0.5024075508117676, 0.49409398436546326], loss1 min/max=0.5499/0.5568, loss2 min/max=0.0398/0.1114, integral time stamps=5000, sec/iter=0.3022
# Slot 0: 0 (no events), 1 (648 events): MAR=9.35+-4.21, HITS_10=0.491+-0.377, Com (648 events): MAR=9.35+-4.21, HITS_10=0.491+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.35+-4.21	 HITS_10=0.491+-0.377
# ====== Com       	 (648     events): 	MAR=9.35+-4.21	 HITS_10=0.491+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.16631578947368422, Test Loss: 338.8704063415527
# Testing decay_rate: 0.21842105263157896
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=433.718, psi=[0.5004504323005676, 0.5003248453140259], loss1 min/max=0.4135/0.4192, loss2 min/max=0.0820/0.0975, integral time stamps=5000, sec/iter=0.2946
# Slot 0: 0 (no events), 1 (648 events): MAR=9.08+-4.46, HITS_10=0.509+-0.388, Com (648 events): MAR=9.08+-4.46, HITS_10=0.509+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.08+-4.46	 HITS_10=0.509+-0.388
# ====== Com       	 (648     events): 	MAR=9.08+-4.46	 HITS_10=0.509+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.21842105263157896, Test Loss: 433.71773529052734
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=443.562, psi=[0.5010020136833191, 0.5005871653556824], loss1 min/max=0.4279/0.4339, loss2 min/max=0.0853/0.1041, integral time stamps=5000, sec/iter=0.4164
# Slot 0: 0 (no events), 1 (648 events): MAR=9.11+-4.46, HITS_10=0.512+-0.388, Com (648 events): MAR=9.11+-4.46, HITS_10=0.512+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.11+-4.46	 HITS_10=0.512+-0.388
# ====== Com       	 (648     events): 	MAR=9.11+-4.46	 HITS_10=0.512+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.21842105263157896, Test Loss: 438.63966941833496
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=454.289, psi=[0.5015547871589661, 0.500720739364624], loss1 min/max=0.4372/0.4433, loss2 min/max=0.0872/0.1110, integral time stamps=5000, sec/iter=0.3156
# Slot 0: 0 (no events), 1 (648 events): MAR=9.13+-4.45, HITS_10=0.510+-0.389, Com (648 events): MAR=9.13+-4.45, HITS_10=0.510+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.13+-4.45	 HITS_10=0.510+-0.389
# ====== Com       	 (648     events): 	MAR=9.13+-4.45	 HITS_10=0.510+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.21842105263157896, Test Loss: 443.8561096191406
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=465.544, psi=[0.5020941495895386, 0.5007705092430115], loss1 min/max=0.4432/0.4494, loss2 min/max=0.0885/0.1181, integral time stamps=5000, sec/iter=0.2926
# Slot 0: 0 (no events), 1 (648 events): MAR=9.14+-4.44, HITS_10=0.508+-0.390, Com (648 events): MAR=9.14+-4.44, HITS_10=0.508+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.14+-4.44	 HITS_10=0.508+-0.390
# ====== Com       	 (648     events): 	MAR=9.14+-4.44	 HITS_10=0.508+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.21842105263157896, Test Loss: 449.27812576293945
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=477.152, psi=[0.5026158690452576, 0.5007664561271667], loss1 min/max=0.4469/0.4532, loss2 min/max=0.0892/0.1254, integral time stamps=5000, sec/iter=0.3519
# Slot 0: 0 (no events), 1 (648 events): MAR=9.15+-4.43, HITS_10=0.510+-0.390, Com (648 events): MAR=9.15+-4.43, HITS_10=0.510+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.15+-4.43	 HITS_10=0.510+-0.390
# ====== Com       	 (648     events): 	MAR=9.15+-4.43	 HITS_10=0.510+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.21842105263157896, Test Loss: 454.8529739379883
# Testing decay_rate: 0.2705263157894737
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=373.871, psi=[0.5004501938819885, 0.4987209439277649], loss1 min/max=1.0237/1.0380, loss2 min/max=0.0263/0.2085, integral time stamps=5000, sec/iter=0.2916
# Slot 0: 0 (no events), 1 (648 events): MAR=8.95+-3.98, HITS_10=0.541+-0.363, Com (648 events): MAR=8.95+-3.98, HITS_10=0.541+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.95+-3.98	 HITS_10=0.541+-0.363
# ====== Com       	 (648     events): 	MAR=8.95+-3.98	 HITS_10=0.541+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.2705263157894737, Test Loss: 373.8711624145508
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=361.905, psi=[0.5009729862213135, 0.4973081052303314], loss1 min/max=0.9252/0.9384, loss2 min/max=0.0285/0.1884, integral time stamps=5000, sec/iter=0.2990
# Slot 0: 0 (no events), 1 (648 events): MAR=8.96+-3.99, HITS_10=0.540+-0.361, Com (648 events): MAR=8.96+-3.99, HITS_10=0.540+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.96+-3.99	 HITS_10=0.540+-0.361
# ====== Com       	 (648     events): 	MAR=8.96+-3.99	 HITS_10=0.540+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.2705263157894737, Test Loss: 367.88816833496094
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=353.538, psi=[0.5015199184417725, 0.49583858251571655], loss1 min/max=0.8376/0.8497, loss2 min/max=0.0308/0.1707, integral time stamps=5000, sec/iter=0.2912
# Slot 0: 0 (no events), 1 (648 events): MAR=8.95+-4.01, HITS_10=0.542+-0.361, Com (648 events): MAR=8.95+-4.01, HITS_10=0.542+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.95+-4.01	 HITS_10=0.542+-0.361
# ====== Com       	 (648     events): 	MAR=8.95+-4.01	 HITS_10=0.542+-0.361
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.2705263157894737, Test Loss: 363.1047166188558
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=348.488, psi=[0.5020691752433777, 0.4943859279155731], loss1 min/max=0.7612/0.7723, loss2 min/max=0.0330/0.1555, integral time stamps=5000, sec/iter=0.2915
# Slot 0: 0 (no events), 1 (648 events): MAR=8.93+-4.03, HITS_10=0.540+-0.357, Com (648 events): MAR=8.93+-4.03, HITS_10=0.540+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.93+-4.03	 HITS_10=0.540+-0.357
# ====== Com       	 (648     events): 	MAR=8.93+-4.03	 HITS_10=0.540+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.2705263157894737, Test Loss: 359.45051860809326
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=346.389, psi=[0.5026128888130188, 0.4929999113082886], loss1 min/max=0.6959/0.7062, loss2 min/max=0.0357/0.1424, integral time stamps=5000, sec/iter=0.2913
# Slot 0: 0 (no events), 1 (648 events): MAR=8.94+-4.06, HITS_10=0.541+-0.355, Com (648 events): MAR=8.94+-4.06, HITS_10=0.541+-0.355
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.94+-4.06	 HITS_10=0.541+-0.355
# ====== Com       	 (648     events): 	MAR=8.94+-4.06	 HITS_10=0.541+-0.355
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.2705263157894737, Test Loss: 356.8381916046143
# Testing decay_rate: 0.32263157894736844
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=302.472, psi=[0.5004392266273499, 0.500616192817688], loss1 min/max=0.3765/0.3829, loss2 min/max=0.0138/0.0766, integral time stamps=5000, sec/iter=0.2907
# Slot 0: 0 (no events), 1 (648 events): MAR=9.11+-4.27, HITS_10=0.512+-0.380, Com (648 events): MAR=9.11+-4.27, HITS_10=0.512+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.11+-4.27	 HITS_10=0.512+-0.380
# ====== Com       	 (648     events): 	MAR=9.11+-4.27	 HITS_10=0.512+-0.380
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.32263157894736844, Test Loss: 302.47175216674805
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=302.408, psi=[0.5008850693702698, 0.5010932683944702], loss1 min/max=0.4120/0.4172, loss2 min/max=0.0155/0.0835, integral time stamps=5000, sec/iter=0.2909
# Slot 0: 0 (no events), 1 (648 events): MAR=9.12+-4.28, HITS_10=0.512+-0.385, Com (648 events): MAR=9.12+-4.28, HITS_10=0.512+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.12+-4.28	 HITS_10=0.512+-0.385
# ====== Com       	 (648     events): 	MAR=9.12+-4.28	 HITS_10=0.512+-0.385
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.32263157894736844, Test Loss: 302.4400930404663
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=304.167, psi=[0.5013731718063354, 0.5013099312782288], loss1 min/max=0.4346/0.4399, loss2 min/max=0.0174/0.0880, integral time stamps=5000, sec/iter=0.2913
# Slot 0: 0 (no events), 1 (648 events): MAR=9.12+-4.30, HITS_10=0.521+-0.388, Com (648 events): MAR=9.12+-4.30, HITS_10=0.521+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.12+-4.30	 HITS_10=0.521+-0.388
# ====== Com       	 (648     events): 	MAR=9.12+-4.30	 HITS_10=0.521+-0.388
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.32263157894736844, Test Loss: 303.0157292683919
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=306.849, psi=[0.5018752217292786, 0.5013570785522461], loss1 min/max=0.4486/0.4540, loss2 min/max=0.0194/0.0909, integral time stamps=5000, sec/iter=0.2919
# Slot 0: 0 (no events), 1 (648 events): MAR=9.16+-4.31, HITS_10=0.523+-0.390, Com (648 events): MAR=9.16+-4.31, HITS_10=0.523+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.16+-4.31	 HITS_10=0.523+-0.390
# ====== Com       	 (648     events): 	MAR=9.16+-4.31	 HITS_10=0.523+-0.390
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.32263157894736844, Test Loss: 303.97415018081665
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=310.094, psi=[0.5023797154426575, 0.5012977719306946], loss1 min/max=0.4567/0.4621, loss2 min/max=0.0214/0.0925, integral time stamps=5000, sec/iter=0.3175
# Slot 0: 0 (no events), 1 (648 events): MAR=9.15+-4.32, HITS_10=0.522+-0.389, Com (648 events): MAR=9.15+-4.32, HITS_10=0.522+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.15+-4.32	 HITS_10=0.522+-0.389
# ====== Com       	 (648     events): 	MAR=9.15+-4.32	 HITS_10=0.522+-0.389
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.32263157894736844, Test Loss: 305.1981288909912
# Testing decay_rate: 0.37473684210526315
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=364.167, psi=[0.5004427433013916, 0.500071108341217], loss1 min/max=0.4505/0.4608, loss2 min/max=0.0549/0.0925, integral time stamps=5000, sec/iter=0.2884
# Slot 0: 0 (no events), 1 (648 events): MAR=8.82+-4.13, HITS_10=0.548+-0.359, Com (648 events): MAR=8.82+-4.13, HITS_10=0.548+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.82+-4.13	 HITS_10=0.548+-0.359
# ====== Com       	 (648     events): 	MAR=8.82+-4.13	 HITS_10=0.548+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.37473684210526315, Test Loss: 364.16693115234375
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=370.685, psi=[0.500921905040741, 0.5000145435333252], loss1 min/max=0.4587/0.4678, loss2 min/max=0.0590/0.0946, integral time stamps=5000, sec/iter=0.2889
# Slot 0: 0 (no events), 1 (648 events): MAR=8.83+-4.14, HITS_10=0.549+-0.359, Com (648 events): MAR=8.83+-4.14, HITS_10=0.549+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.83+-4.14	 HITS_10=0.549+-0.359
# ====== Com       	 (648     events): 	MAR=8.83+-4.14	 HITS_10=0.549+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.37473684210526315, Test Loss: 367.4258785247803
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=377.792, psi=[0.5014307498931885, 0.49987468123435974], loss1 min/max=0.4624/0.4714, loss2 min/max=0.0635/0.0950, integral time stamps=5000, sec/iter=0.3160
# Slot 0: 0 (no events), 1 (648 events): MAR=8.82+-4.15, HITS_10=0.547+-0.359, Com (648 events): MAR=8.82+-4.15, HITS_10=0.547+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.82+-4.15	 HITS_10=0.547+-0.359
# ====== Com       	 (648     events): 	MAR=8.82+-4.15	 HITS_10=0.547+-0.359
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.37473684210526315, Test Loss: 370.8812777201335
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=385.352, psi=[0.5019433498382568, 0.49969395995140076], loss1 min/max=0.4643/0.4733, loss2 min/max=0.0681/0.0957, integral time stamps=5000, sec/iter=0.2887
# Slot 0: 0 (no events), 1 (648 events): MAR=8.82+-4.15, HITS_10=0.549+-0.357, Com (648 events): MAR=8.82+-4.15, HITS_10=0.549+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.82+-4.15	 HITS_10=0.549+-0.357
# ====== Com       	 (648     events): 	MAR=8.82+-4.15	 HITS_10=0.549+-0.357
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.37473684210526315, Test Loss: 374.4989285469055
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=393.284, psi=[0.5024497509002686, 0.4994909465312958], loss1 min/max=0.4653/0.4743, loss2 min/max=0.0730/0.0956, integral time stamps=5000, sec/iter=0.2889
# Slot 0: 0 (no events), 1 (648 events): MAR=8.81+-4.15, HITS_10=0.547+-0.356, Com (648 events): MAR=8.81+-4.15, HITS_10=0.547+-0.356
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.81+-4.15	 HITS_10=0.547+-0.356
# ====== Com       	 (648     events): 	MAR=8.81+-4.15	 HITS_10=0.547+-0.356
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.37473684210526315, Test Loss: 378.25586967468263
# Testing decay_rate: 0.4268421052631579
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=296.791, psi=[0.5004494190216064, 0.49874240159988403], loss1 min/max=0.7336/0.7420, loss2 min/max=0.0052/0.1486, integral time stamps=5000, sec/iter=0.2897
# Slot 0: 0 (no events), 1 (648 events): MAR=8.90+-4.19, HITS_10=0.537+-0.363, Com (648 events): MAR=8.90+-4.19, HITS_10=0.537+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.90+-4.19	 HITS_10=0.537+-0.363
# ====== Com       	 (648     events): 	MAR=8.90+-4.19	 HITS_10=0.537+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4268421052631579, Test Loss: 296.7906494140625
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=290.072, psi=[0.5009691119194031, 0.49749183654785156], loss1 min/max=0.6519/0.6584, loss2 min/max=0.0056/0.1319, integral time stamps=5000, sec/iter=0.2882
# Slot 0: 0 (no events), 1 (648 events): MAR=8.90+-4.21, HITS_10=0.544+-0.374, Com (648 events): MAR=8.90+-4.21, HITS_10=0.544+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.90+-4.21	 HITS_10=0.544+-0.374
# ====== Com       	 (648     events): 	MAR=8.90+-4.21	 HITS_10=0.544+-0.374
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4268421052631579, Test Loss: 293.43138885498047
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=286.887, psi=[0.5015221238136292, 0.49637913703918457], loss1 min/max=0.5894/0.5949, loss2 min/max=0.0061/0.1194, integral time stamps=5000, sec/iter=0.2999
# Slot 0: 0 (no events), 1 (648 events): MAR=8.89+-4.20, HITS_10=0.549+-0.368, Com (648 events): MAR=8.89+-4.20, HITS_10=0.549+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.89+-4.20	 HITS_10=0.549+-0.368
# ====== Com       	 (648     events): 	MAR=8.89+-4.20	 HITS_10=0.549+-0.368
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4268421052631579, Test Loss: 291.2499656677246
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=286.056, psi=[0.5020855069160461, 0.4954591393470764], loss1 min/max=0.5441/0.5494, loss2 min/max=0.0067/0.1099, integral time stamps=5000, sec/iter=0.2898
# Slot 0: 0 (no events), 1 (648 events): MAR=8.89+-4.22, HITS_10=0.546+-0.365, Com (648 events): MAR=8.89+-4.22, HITS_10=0.546+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.89+-4.22	 HITS_10=0.546+-0.365
# ====== Com       	 (648     events): 	MAR=8.89+-4.22	 HITS_10=0.546+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.4268421052631579, Test Loss: 289.95159673690796
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=286.565, psi=[0.5026503801345825, 0.4947371184825897], loss1 min/max=0.5132/0.5183, loss2 min/max=0.0073/0.1038, integral time stamps=5000, sec/iter=0.2883
# Slot 0: 0 (no events), 1 (648 events): MAR=8.89+-4.23, HITS_10=0.546+-0.366, Com (648 events): MAR=8.89+-4.23, HITS_10=0.546+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.89+-4.23	 HITS_10=0.546+-0.366
# ====== Com       	 (648     events): 	MAR=8.89+-4.23	 HITS_10=0.546+-0.366
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.4268421052631579, Test Loss: 289.274365234375
# Testing decay_rate: 0.4789473684210527
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=621.243, psi=[0.500426709651947, 0.5012105107307434], loss1 min/max=0.1292/0.1342, loss2 min/max=0.0258/0.1550, integral time stamps=5000, sec/iter=0.2877
# Slot 0: 0 (no events), 1 (648 events): MAR=8.81+-4.12, HITS_10=0.541+-0.367, Com (648 events): MAR=8.81+-4.12, HITS_10=0.541+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.81+-4.12	 HITS_10=0.541+-0.367
# ====== Com       	 (648     events): 	MAR=8.81+-4.12	 HITS_10=0.541+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.4789473684210527, Test Loss: 621.242546081543
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=601.484, psi=[0.500803530216217, 0.502476692199707], loss1 min/max=0.1622/0.1680, loss2 min/max=0.0324/0.1587, integral time stamps=5000, sec/iter=0.2899
# Slot 0: 0 (no events), 1 (648 events): MAR=8.80+-4.15, HITS_10=0.544+-0.367, Com (648 events): MAR=8.80+-4.15, HITS_10=0.544+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.80+-4.15	 HITS_10=0.544+-0.367
# ====== Com       	 (648     events): 	MAR=8.80+-4.15	 HITS_10=0.544+-0.367
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.4789473684210527, Test Loss: 611.3633422851562
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=587.982, psi=[0.5012343525886536, 0.5035534501075745], loss1 min/max=0.1975/0.2041, loss2 min/max=0.0394/0.1629, integral time stamps=5000, sec/iter=0.2940
# Slot 0: 0 (no events), 1 (648 events): MAR=8.78+-4.11, HITS_10=0.545+-0.365, Com (648 events): MAR=8.78+-4.11, HITS_10=0.545+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.78+-4.11	 HITS_10=0.545+-0.365
# ====== Com       	 (648     events): 	MAR=8.78+-4.11	 HITS_10=0.545+-0.365
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.4789473684210527, Test Loss: 603.5694961547852
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# ...
# ====== 1         	 (648     events): 	MAR=9.20+-4.21	 HITS_10=0.501+-0.383
# ====== Com       	 (648     events): 	MAR=9.20+-4.21	 HITS_10=0.501+-0.383
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8436842105263158, Test Loss: 522.3491678237915
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=544.778, psi=[0.5024640560150146, 0.49635228514671326], loss1 min/max=0.4724/0.4770, loss2 min/max=0.0943/0.1674, integral time stamps=5000, sec/iter=0.2932
# Slot 0: 0 (no events), 1 (648 events): MAR=9.20+-4.19, HITS_10=0.504+-0.382, Com (648 events): MAR=9.20+-4.19, HITS_10=0.504+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.20+-4.19	 HITS_10=0.504+-0.382
# ====== Com       	 (648     events): 	MAR=9.20+-4.19	 HITS_10=0.504+-0.382
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8436842105263158, Test Loss: 526.8349708557129
# Testing decay_rate: 0.8957894736842106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=353.907, psi=[0.500432014465332, 0.5002392530441284], loss1 min/max=0.4360/0.4471, loss2 min/max=0.0483/0.0897, integral time stamps=5000, sec/iter=0.2931
# Slot 0: 0 (no events), 1 (648 events): MAR=8.81+-4.17, HITS_10=0.539+-0.362, Com (648 events): MAR=8.81+-4.17, HITS_10=0.539+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.81+-4.17	 HITS_10=0.539+-0.362
# ====== Com       	 (648     events): 	MAR=8.81+-4.17	 HITS_10=0.539+-0.362
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.8957894736842106, Test Loss: 353.9067192077637
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=360.779, psi=[0.5008166432380676, 0.5003185868263245], loss1 min/max=0.4473/0.4568, loss2 min/max=0.0527/0.0922, integral time stamps=5000, sec/iter=0.2995
# Slot 0: 0 (no events), 1 (648 events): MAR=8.84+-4.14, HITS_10=0.535+-0.360, Com (648 events): MAR=8.84+-4.14, HITS_10=0.535+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.84+-4.14	 HITS_10=0.535+-0.360
# ====== Com       	 (648     events): 	MAR=8.84+-4.14	 HITS_10=0.535+-0.360
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.8957894736842106, Test Loss: 357.34305000305176
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=368.514, psi=[0.5012455582618713, 0.500299334526062], loss1 min/max=0.4523/0.4616, loss2 min/max=0.0576/0.0928, integral time stamps=5000, sec/iter=0.2930
# Slot 0: 0 (no events), 1 (648 events): MAR=8.84+-4.15, HITS_10=0.538+-0.363, Com (648 events): MAR=8.84+-4.15, HITS_10=0.538+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.84+-4.15	 HITS_10=0.538+-0.363
# ====== Com       	 (648     events): 	MAR=8.84+-4.15	 HITS_10=0.538+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.8957894736842106, Test Loss: 361.0668182373047
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=376.827, psi=[0.5016884207725525, 0.5002303123474121], loss1 min/max=0.4551/0.4643, loss2 min/max=0.0627/0.0933, integral time stamps=5000, sec/iter=0.3153
# Slot 0: 0 (no events), 1 (648 events): MAR=8.84+-4.17, HITS_10=0.538+-0.364, Com (648 events): MAR=8.84+-4.17, HITS_10=0.538+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.84+-4.17	 HITS_10=0.538+-0.364
# ====== Com       	 (648     events): 	MAR=8.84+-4.17	 HITS_10=0.538+-0.364
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.8957894736842106, Test Loss: 365.0068254470825
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=385.611, psi=[0.5021317601203918, 0.5001352429389954], loss1 min/max=0.4565/0.4658, loss2 min/max=0.0682/0.0934, integral time stamps=5000, sec/iter=0.3597
# Slot 0: 0 (no events), 1 (648 events): MAR=8.84+-4.15, HITS_10=0.539+-0.363, Com (648 events): MAR=8.84+-4.15, HITS_10=0.539+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.84+-4.15	 HITS_10=0.539+-0.363
# ====== Com       	 (648     events): 	MAR=8.84+-4.15	 HITS_10=0.539+-0.363
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.8957894736842106, Test Loss: 369.12763862609864
# Testing decay_rate: 0.9478947368421053
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=380.243, psi=[0.5004426836967468, 0.49873828887939453], loss1 min/max=0.8804/0.8885, loss2 min/max=0.0448/0.1779, integral time stamps=5000, sec/iter=0.4205
# Slot 0: 0 (no events), 1 (648 events): MAR=8.89+-4.06, HITS_10=0.535+-0.378, Com (648 events): MAR=8.89+-4.06, HITS_10=0.535+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.89+-4.06	 HITS_10=0.535+-0.378
# ====== Com       	 (648     events): 	MAR=8.89+-4.06	 HITS_10=0.535+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 0.9478947368421053, Test Loss: 380.24311447143555
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=372.396, psi=[0.5009375214576721, 0.49738484621047974], loss1 min/max=0.7967/0.8033, loss2 min/max=0.0467/0.1608, integral time stamps=5000, sec/iter=0.3355
# Slot 0: 0 (no events), 1 (648 events): MAR=8.90+-4.08, HITS_10=0.540+-0.378, Com (648 events): MAR=8.90+-4.08, HITS_10=0.540+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.90+-4.08	 HITS_10=0.540+-0.378
# ====== Com       	 (648     events): 	MAR=8.90+-4.08	 HITS_10=0.540+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 0.9478947368421053, Test Loss: 376.3196487426758
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=368.018, psi=[0.501468300819397, 0.49603113532066345], loss1 min/max=0.7253/0.7306, loss2 min/max=0.0487/0.1463, integral time stamps=5000, sec/iter=0.2953
# Slot 0: 0 (no events), 1 (648 events): MAR=8.90+-4.12, HITS_10=0.538+-0.376, Com (648 events): MAR=8.90+-4.12, HITS_10=0.538+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.90+-4.12	 HITS_10=0.538+-0.376
# ====== Com       	 (648     events): 	MAR=8.90+-4.12	 HITS_10=0.538+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 0.9478947368421053, Test Loss: 373.55244700113934
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=366.618, psi=[0.5020095109939575, 0.4947441518306732], loss1 min/max=0.6658/0.6702, loss2 min/max=0.0514/0.1341, integral time stamps=5000, sec/iter=0.4197
# Slot 0: 0 (no events), 1 (648 events): MAR=8.94+-4.13, HITS_10=0.529+-0.376, Com (648 events): MAR=8.94+-4.13, HITS_10=0.529+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=8.94+-4.13	 HITS_10=0.529+-0.376
# ====== Com       	 (648     events): 	MAR=8.94+-4.13	 HITS_10=0.529+-0.376
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 0.9478947368421053, Test Loss: 371.8187894821167
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=367.695, psi=[0.5025510191917419, 0.4935648441314697], loss1 min/max=0.6174/0.6210, loss2 min/max=0.0541/0.1243, integral time stamps=5000, sec/iter=0.3299
# Slot 0: 0 (no events), 1 (648 events): MAR=9.00+-4.15, HITS_10=0.525+-0.381, Com (648 events): MAR=9.00+-4.15, HITS_10=0.525+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.00+-4.15	 HITS_10=0.525+-0.381
# ====== Com       	 (648     events): 	MAR=9.00+-4.15	 HITS_10=0.525+-0.381
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 0.9478947368421053, Test Loss: 370.9940055847168
# Testing decay_rate: 1.0
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=570.802, psi=[0.5004491209983826, 0.5012013912200928], loss1 min/max=0.1591/0.1633, loss2 min/max=0.0317/0.1384, integral time stamps=5000, sec/iter=0.3821
# Slot 0: 0 (no events), 1 (648 events): MAR=9.21+-4.21, HITS_10=0.501+-0.375, Com (648 events): MAR=9.21+-4.21, HITS_10=0.501+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.21+-4.21	 HITS_10=0.501+-0.375
# ====== Com       	 (648     events): 	MAR=9.21+-4.21	 HITS_10=0.501+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 1, Decay Rate 1.0, Test Loss: 570.8022384643555
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=558.325, psi=[0.5009963512420654, 0.5024189949035645], loss1 min/max=0.1964/0.2010, loss2 min/max=0.0391/0.1439, integral time stamps=5000, sec/iter=0.3341
# Slot 0: 0 (no events), 1 (648 events): MAR=9.23+-4.24, HITS_10=0.505+-0.379, Com (648 events): MAR=9.23+-4.24, HITS_10=0.505+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.23+-4.24	 HITS_10=0.505+-0.379
# ====== Com       	 (648     events): 	MAR=9.23+-4.24	 HITS_10=0.505+-0.379
# ----------------------------------------------------------------------------------------------------
# Epoch 2, Decay Rate 1.0, Test Loss: 564.563591003418
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=552.291, psi=[0.501552164554596, 0.5034283995628357], loss1 min/max=0.2346/0.2396, loss2 min/max=0.0468/0.1500, integral time stamps=5000, sec/iter=0.3391
# Slot 0: 0 (no events), 1 (648 events): MAR=9.22+-4.27, HITS_10=0.510+-0.378, Com (648 events): MAR=9.22+-4.27, HITS_10=0.510+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.22+-4.27	 HITS_10=0.510+-0.378
# ====== Com       	 (648     events): 	MAR=9.22+-4.27	 HITS_10=0.510+-0.378
# ----------------------------------------------------------------------------------------------------
# Epoch 3, Decay Rate 1.0, Test Loss: 560.4728253682455
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=551.482, psi=[0.5020992755889893, 0.5042450428009033], loss1 min/max=0.2718/0.2770, loss2 min/max=0.0542/0.1566, integral time stamps=5000, sec/iter=0.2998
# Slot 0: 0 (no events), 1 (648 events): MAR=9.19+-4.29, HITS_10=0.511+-0.377, Com (648 events): MAR=9.19+-4.29, HITS_10=0.511+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.19+-4.29	 HITS_10=0.511+-0.377
# ====== Com       	 (648     events): 	MAR=9.19+-4.29	 HITS_10=0.511+-0.377
# ----------------------------------------------------------------------------------------------------
# Epoch 4, Decay Rate 1.0, Test Loss: 558.2251176834106
# initialize models node embeddings and adjacency matrices for 20 nodes
# A_initial (20, 20, 1)
# Warning: time_keys is empty. No operations performed.
# test 0
#
# TEST batch=4/4, loss=554.690, psi=[0.5026319622993469, 0.5048904418945312], loss1 min/max=0.3061/0.3116, loss2 min/max=0.0611/0.1635, integral time stamps=5000, sec/iter=0.3052
# Slot 0: 0 (no events), 1 (648 events): MAR=9.20+-4.30, HITS_10=0.504+-0.375, Com (648 events): MAR=9.20+-4.30, HITS_10=0.504+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 5: results per event type for all test time slots:
# ====== 0         	 (no events)
# ====== 1         	 (648     events): 	MAR=9.20+-4.30	 HITS_10=0.504+-0.375
# ====== Com       	 (648     events): 	MAR=9.20+-4.30	 HITS_10=0.504+-0.375
# ----------------------------------------------------------------------------------------------------
# Epoch 5, Decay Rate 1.0, Test Loss: 557.5180320739746
# Best decay_rate: 0.4268421052631579 with loss: 289.274365234375
